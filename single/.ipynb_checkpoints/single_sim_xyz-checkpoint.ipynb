# %% [markdown]
# # Single Chromosome Simulation

# %%
from OpenMiChroM.ChromDynamics import MiChroM
from OpenMiChroM.CndbTools import cndbTools

import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

from openmm.app import *

# %%
block = 3*10**2
n_blocks = 2*10**3

# %% [markdown]
# **{ chr 10 } simulation**

# %%
sim = MiChroM(temperature=1.0, time_step=0.01)
sim.setup(platform="cuda") # Double-check CUDA installation in your system 
sim.saveFolder('single_op_chr10_xyz')
Chrom10 = sim.createSpringSpiral(ChromSeq='../inputs/chr10_beads.txt', isRing=False)
sim.loadStructure(Chrom10, center=True)
sim.saveStructure(mode='pdb')
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.5 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************

# %%
sim.addFENEBonds(kfb=30.0)
sim.addAngles(ka=2.0)
sim.addRepulsiveSoftCore(Ecut=4.0)
sim.addTypetoType(mu=3.22, rc = 1.78)
sim.addIdealChromosome(mu=3.22, rc = 1.78, dinit=3, dend=500)
sim.addFlatBottomHarmonic( kr=5*10**-3, n_rad=15.0)

# %% [markdown]
# **collapse simulation**

# %%
print('GENERATING INITIAL SIM STRUCTURE', '\n---\n')
for _ in range(n_blocks):
    sim.runSimBlock(block, increment=False) 
    print('1st loop', '\n---\n')
# Out:
# GENERATING INITIAL SIM STRUCTURE
# ---
#
# Number of exceptions: 2711
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# Add exclusions for TypetoType force
# adding force  TypetoType 3
# Add exclusions for IdealChromosome force
# adding force  IdealChromosome 4
# adding force  FlatBottomHarmonic 5
# Positions...
#  loaded!
# potential energy is 64.292854
# bl=0 pos[1]=[209.0 -11.1 -0.8] dr=0.60 t=0.0ps kin=1.29 pot=64.78 Rg=146.824 SPS=826
# 1st loop
# ---
#
# bl=0 pos[1]=[207.8 -10.4 0.4] dr=1.11 t=0.0ps kin=1.89 pot=64.12 Rg=145.968 SPS=4685
# 1st loop
# ---
#
# bl=0 pos[1]=[206.3 -9.6 1.2] dr=1.48 t=0.0ps kin=2.38 pot=63.26 Rg=144.739 SPS=4769
# 1st loop
# ---
#
# bl=0 pos[1]=[204.7 -10.0 2.3] dr=1.70 t=0.0ps kin=2.70 pot=62.26 Rg=143.267 SPS=4577
# 1st loop
# ---
#
# bl=0 pos[1]=[203.5 -9.0 4.3] dr=1.85 t=0.0ps kin=2.91 pot=61.26 Rg=141.632 SPS=4718
# 1st loop
# ---
#
# bl=0 pos[1]=[201.3 -7.6 6.5] dr=1.92 t=0.0ps kin=3.03 pot=60.20 Rg=139.917 SPS=4720
# 1st loop
# ---
#
# bl=0 pos[1]=[198.7 -5.7 7.8] dr=1.96 t=0.0ps kin=3.16 pot=59.13 Rg=138.148 SPS=4560
# 1st loop
# ---
#
# bl=0 pos[1]=[195.1 -5.0 7.5] dr=2.00 t=0.0ps kin=3.21 pot=58.06 Rg=136.330 SPS=4318
# 1st loop
# ---
#
# bl=0 pos[1]=[191.6 -5.3 8.7] dr=2.00 t=0.0ps kin=3.23 pot=57.01 Rg=134.508 SPS=3722
# 1st loop
# ---
#
# bl=0 pos[1]=[188.7 -5.3 9.2] dr=2.02 t=0.0ps kin=3.26 pot=55.96 Rg=132.679 SPS=3325
# 1st loop
# ---
#
# bl=0 pos[1]=[185.8 -4.5 9.2] dr=2.02 t=0.0ps kin=3.29 pot=54.89 Rg=130.853 SPS=3492
# 1st loop
# ---
#
# bl=0 pos[1]=[183.9 -4.0 9.6] dr=2.01 t=0.0ps kin=3.23 pot=53.88 Rg=129.039 SPS=3527
# 1st loop
# ---
#
# bl=0 pos[1]=[181.2 -3.9 10.8] dr=2.00 t=0.0ps kin=3.18 pot=52.87 Rg=127.246 SPS=3514
# 1st loop
# ---
#
# bl=0 pos[1]=[178.6 -4.4 11.3] dr=1.97 t=0.0ps kin=3.19 pot=51.90 Rg=125.483 SPS=3535
# 1st loop
# ---
#
# bl=0 pos[1]=[176.1 -4.1 11.2] dr=1.96 t=0.0ps kin=3.18 pot=50.93 Rg=123.737 SPS=3373
# 1st loop
# ---
#
# bl=0 pos[1]=[173.0 -3.1 11.6] dr=1.95 t=0.0ps kin=3.13 pot=50.03 Rg=122.009 SPS=3476
# 1st loop
# ---
#
# bl=0 pos[1]=[169.7 -2.2 11.6] dr=1.94 t=0.0ps kin=3.06 pot=49.13 Rg=120.286 SPS=3670
# 1st loop
# ---
#
# bl=0 pos[1]=[167.7 -1.1 10.9] dr=1.92 t=0.0ps kin=3.03 pot=48.24 Rg=118.591 SPS=3723
# 1st loop
# ---
#
# bl=0 pos[1]=[165.4 -0.8 10.1] dr=1.89 t=0.0ps kin=2.97 pot=47.37 Rg=116.925 SPS=3749
# 1st loop
# ---
#
# bl=0 pos[1]=[164.0 -1.0 9.7] dr=1.87 t=0.0ps kin=2.96 pot=46.51 Rg=115.295 SPS=3383
# 1st loop
# ---
#
# bl=0 pos[1]=[162.2 -1.2 9.8] dr=1.85 t=0.0ps kin=2.91 pot=45.75 Rg=113.683 SPS=3751
# 1st loop
# ---
#
# bl=0 pos[1]=[159.9 -2.1 9.7] dr=1.84 t=0.0ps kin=2.86 pot=44.96 Rg=112.090 SPS=3655
# 1st loop
# ---
#
# bl=0 pos[1]=[156.9 -3.0 8.7] dr=1.82 t=0.0ps kin=2.83 pot=44.20 Rg=110.515 SPS=3939
# 1st loop
# ---
#
# bl=0 pos[1]=[154.6 -3.8 8.0] dr=1.81 t=0.0ps kin=2.83 pot=43.45 Rg=108.960 SPS=3842
# 1st loop
# ---
#
# bl=0 pos[1]=[152.4 -3.9 6.5] dr=1.80 t=0.0ps kin=2.81 pot=42.73 Rg=107.420 SPS=3592
# 1st loop
# ---
#
# bl=0 pos[1]=[149.5 -3.8 5.4] dr=1.78 t=0.0ps kin=2.74 pot=42.03 Rg=105.903 SPS=3693
# 1st loop
# ---
#
# bl=0 pos[1]=[147.1 -3.1 4.8] dr=1.74 t=0.0ps kin=2.63 pot=41.39 Rg=104.422 SPS=3806
# 1st loop
# ---
#
# bl=0 pos[1]=[145.2 -3.3 4.5] dr=1.71 t=0.0ps kin=2.63 pot=40.68 Rg=102.969 SPS=4190
# 1st loop
# ---
#
# bl=0 pos[1]=[143.4 -3.0 4.1] dr=1.69 t=0.0ps kin=2.60 pot=40.06 Rg=101.544 SPS=3989
# 1st loop
# ---
#
# bl=0 pos[1]=[142.0 -2.9 4.3] dr=1.69 t=0.0ps kin=2.54 pot=39.45 Rg=100.125 SPS=3892
# 1st loop
# ---
#
# bl=0 pos[1]=[140.4 -2.6 5.1] dr=1.64 t=0.0ps kin=2.47 pot=38.84 Rg=98.758 SPS=3800
# 1st loop
# ---
#
# bl=0 pos[1]=[137.9 -2.8 6.3] dr=1.61 t=0.0ps kin=2.46 pot=38.28 Rg=97.424 SPS=3280
# 1st loop
# ---
#
# bl=0 pos[1]=[134.6 -2.5 7.7] dr=1.60 t=0.0ps kin=2.42 pot=37.73 Rg=96.112 SPS=3851
# 1st loop
# ---
#
# bl=0 pos[1]=[132.6 -2.3 8.4] dr=1.57 t=0.0ps kin=2.41 pot=37.21 Rg=94.825 SPS=3703
# 1st loop
# ---
#
# bl=0 pos[1]=[131.4 -3.8 9.4] dr=1.57 t=0.0ps kin=2.36 pot=36.70 Rg=93.545 SPS=3666
# 1st loop
# ---
#
# bl=0 pos[1]=[129.7 -3.5 10.0] dr=1.55 t=0.0ps kin=2.34 pot=36.20 Rg=92.282 SPS=3678
# 1st loop
# ---
#
# bl=0 pos[1]=[127.8 -2.8 10.2] dr=1.53 t=0.0ps kin=2.34 pot=35.71 Rg=91.054 SPS=3736
# 1st loop
# ---
#
# bl=0 pos[1]=[125.4 -1.9 10.7] dr=1.51 t=0.0ps kin=2.27 pot=35.27 Rg=89.865 SPS=3566
# 1st loop
# ---
#
# bl=0 pos[1]=[123.4 -2.4 9.8] dr=1.49 t=0.0ps kin=2.26 pot=34.83 Rg=88.693 SPS=3942
# 1st loop
# ---
#
# bl=0 pos[1]=[122.2 -2.1 9.6] dr=1.46 t=0.0ps kin=2.16 pot=34.38 Rg=87.555 SPS=3638
# 1st loop
# ---
#
# bl=0 pos[1]=[120.3 -2.0 10.2] dr=1.46 t=0.0ps kin=2.17 pot=33.98 Rg=86.435 SPS=3663
# 1st loop
# ---
#
# bl=0 pos[1]=[118.7 -1.9 10.1] dr=1.46 t=0.0ps kin=2.22 pot=33.52 Rg=85.314 SPS=3738
# 1st loop
# ---
#
# bl=0 pos[1]=[117.1 -2.1 9.5] dr=1.45 t=0.0ps kin=2.16 pot=33.16 Rg=84.190 SPS=3867
# 1st loop
# ---
#
# bl=0 pos[1]=[114.6 -2.6 9.5] dr=1.43 t=0.0ps kin=2.17 pot=32.75 Rg=83.084 SPS=3526
# 1st loop
# ---
#
# bl=0 pos[1]=[112.0 -2.2 8.6] dr=1.43 t=0.0ps kin=2.15 pot=32.39 Rg=81.992 SPS=3716
# 1st loop
# ---
#
# bl=0 pos[1]=[109.5 -1.2 8.5] dr=1.42 t=0.0ps kin=2.17 pot=32.02 Rg=80.913 SPS=3769
# 1st loop
# ---
#
# bl=0 pos[1]=[107.6 -1.0 7.7] dr=1.42 t=0.0ps kin=2.18 pot=31.66 Rg=79.850 SPS=3650
# 1st loop
# ---
#
# bl=0 pos[1]=[106.0 -1.9 7.8] dr=1.40 t=0.0ps kin=2.13 pot=31.34 Rg=78.787 SPS=3807
# 1st loop
# ---
#
# bl=0 pos[1]=[103.8 -1.8 7.3] dr=1.40 t=0.0ps kin=2.13 pot=30.98 Rg=77.738 SPS=3825
# 1st loop
# ---
#
# bl=0 pos[1]=[101.8 -2.1 6.5] dr=1.39 t=0.0ps kin=2.12 pot=30.61 Rg=76.702 SPS=3701
# 1st loop
# ---
#
# bl=0 pos[1]=[100.5 -2.5 6.2] dr=1.37 t=0.0ps kin=2.08 pot=30.31 Rg=75.692 SPS=3813
# 1st loop
# ---
#
# bl=0 pos[1]=[99.8 -2.0 6.4] dr=1.35 t=0.0ps kin=2.06 pot=29.98 Rg=74.705 SPS=3803
# 1st loop
# ---
#
# bl=0 pos[1]=[99.7 -0.5 6.1] dr=1.34 t=0.0ps kin=2.04 pot=29.68 Rg=73.730 SPS=3785
# 1st loop
# ---
#
# bl=0 pos[1]=[99.3 -0.6 6.3] dr=1.31 t=0.0ps kin=2.04 pot=29.38 Rg=72.783 SPS=3330
# 1st loop
# ---
#
# bl=0 pos[1]=[98.2 -0.7 6.2] dr=1.30 t=0.0ps kin=1.99 pot=29.10 Rg=71.854 SPS=3787
# 1st loop
# ---
#
# bl=0 pos[1]=[97.0 -0.6 7.0] dr=1.28 t=0.0ps kin=1.91 pot=28.84 Rg=70.949 SPS=3555
# 1st loop
# ---
#
# bl=0 pos[1]=[95.8 -0.6 6.4] dr=1.27 t=0.0ps kin=1.94 pot=28.56 Rg=70.046 SPS=3916
# 1st loop
# ---
#
# bl=0 pos[1]=[94.5 -1.6 6.1] dr=1.26 t=0.0ps kin=1.92 pot=28.30 Rg=69.168 SPS=3733
# 1st loop
# ---
#
# bl=0 pos[1]=[93.2 -1.2 6.1] dr=1.25 t=0.0ps kin=1.88 pot=28.10 Rg=68.308 SPS=3721
# 1st loop
# ---
#
# bl=0 pos[1]=[91.1 -0.4 5.9] dr=1.25 t=0.0ps kin=1.93 pot=27.84 Rg=67.445 SPS=3634
# 1st loop
# ---
#
# bl=0 pos[1]=[89.5 -1.5 4.9] dr=1.25 t=0.0ps kin=1.93 pot=27.60 Rg=66.597 SPS=3521
# 1st loop
# ---
#
# bl=0 pos[1]=[87.3 -2.6 5.4] dr=1.24 t=0.0ps kin=1.90 pot=27.39 Rg=65.769 SPS=3472
# 1st loop
# ---
#
# bl=0 pos[1]=[84.8 -2.9 6.4] dr=1.22 t=0.0ps kin=1.91 pot=27.16 Rg=64.942 SPS=3610
# 1st loop
# ---
#
# bl=0 pos[1]=[83.8 -1.8 7.3] dr=1.23 t=0.0ps kin=1.87 pot=27.00 Rg=64.122 SPS=3642
# 1st loop
# ---
#
# bl=0 pos[1]=[82.2 -2.7 8.4] dr=1.21 t=0.0ps kin=1.86 pot=26.82 Rg=63.329 SPS=3364
# 1st loop
# ---
#
# bl=0 pos[1]=[81.5 -2.3 9.3] dr=1.19 t=0.0ps kin=1.89 pot=26.57 Rg=62.547 SPS=3631
# 1st loop
# ---
#
# bl=0 pos[1]=[80.2 -2.2 9.7] dr=1.17 t=0.0ps kin=1.85 pot=26.38 Rg=61.781 SPS=3367
# 1st loop
# ---
#
# bl=0 pos[1]=[78.7 -1.7 10.1] dr=1.16 t=0.0ps kin=1.83 pot=26.21 Rg=61.023 SPS=3271
# 1st loop
# ---
#
# bl=0 pos[1]=[78.3 -1.7 10.4] dr=1.15 t=0.0ps kin=1.79 pot=26.00 Rg=60.294 SPS=3681
# 1st loop
# ---
#
# bl=0 pos[1]=[77.4 -1.6 9.7] dr=1.13 t=0.0ps kin=1.77 pot=25.82 Rg=59.578 SPS=3711
# 1st loop
# ---
#
# bl=0 pos[1]=[76.5 -0.7 9.0] dr=1.13 t=0.0ps kin=1.81 pot=25.62 Rg=58.869 SPS=3509
# 1st loop
# ---
#
# bl=0 pos[1]=[75.8 -0.8 8.4] dr=1.14 t=0.0ps kin=1.81 pot=25.50 Rg=58.151 SPS=3565
# 1st loop
# ---
#
# bl=0 pos[1]=[75.1 -1.7 7.8] dr=1.14 t=0.0ps kin=1.81 pot=25.32 Rg=57.430 SPS=3530
# 1st loop
# ---
#
# bl=0 pos[1]=[73.5 -3.3 7.4] dr=1.14 t=0.0ps kin=1.77 pot=25.19 Rg=56.736 SPS=3289
# 1st loop
# ---
#
# bl=0 pos[1]=[72.9 -3.8 6.7] dr=1.12 t=0.0ps kin=1.80 pot=25.05 Rg=56.060 SPS=3834
# 1st loop
# ---
#
# bl=0 pos[1]=[72.7 -3.8 6.4] dr=1.12 t=0.0ps kin=1.77 pot=24.89 Rg=55.385 SPS=3568
# 1st loop
# ---
#
# bl=0 pos[1]=[71.7 -4.4 7.6] dr=1.10 t=0.0ps kin=1.73 pot=24.74 Rg=54.730 SPS=3478
# 1st loop
# ---
#
# bl=0 pos[1]=[70.2 -4.7 7.3] dr=1.09 t=0.0ps kin=1.74 pot=24.58 Rg=54.091 SPS=3649
# 1st loop
# ---
#
# bl=0 pos[1]=[68.6 -4.7 7.3] dr=1.07 t=0.0ps kin=1.70 pot=24.48 Rg=53.470 SPS=3762
# 1st loop
# ---
#
# bl=0 pos[1]=[67.4 -4.6 5.8] dr=1.08 t=0.0ps kin=1.72 pot=24.31 Rg=52.861 SPS=3963
# 1st loop
# ---
#
# bl=0 pos[1]=[65.4 -3.4 6.0] dr=1.06 t=0.0ps kin=1.66 pot=24.20 Rg=52.267 SPS=4322
# 1st loop
# ---
#
# bl=0 pos[1]=[64.2 -2.7 5.8] dr=1.07 t=0.0ps kin=1.70 pot=24.08 Rg=51.668 SPS=4309
# 1st loop
# ---
#
# bl=0 pos[1]=[62.7 -2.3 5.5] dr=1.06 t=0.0ps kin=1.70 pot=23.99 Rg=51.080 SPS=4342
# 1st loop
# ---
#
# bl=0 pos[1]=[61.4 -2.2 5.5] dr=1.05 t=0.0ps kin=1.71 pot=23.85 Rg=50.502 SPS=4230
# 1st loop
# ---
#
# bl=0 pos[1]=[61.5 -0.7 4.5] dr=1.04 t=0.0ps kin=1.70 pot=23.74 Rg=49.937 SPS=4290
# 1st loop
# ---
#
# bl=0 pos[1]=[61.6 1.1 4.9] dr=1.03 t=0.0ps kin=1.67 pot=23.66 Rg=49.386 SPS=4261
# 1st loop
# ---
#
# bl=0 pos[1]=[61.6 0.9 6.1] dr=1.03 t=0.0ps kin=1.71 pot=23.55 Rg=48.858 SPS=4231
# 1st loop
# ---
#
# bl=0 pos[1]=[61.0 0.6 4.4] dr=1.04 t=0.0ps kin=1.72 pot=23.42 Rg=48.330 SPS=4211
# 1st loop
# ---
#
# bl=0 pos[1]=[61.3 -1.2 4.0] dr=1.02 t=0.0ps kin=1.64 pot=23.38 Rg=47.814 SPS=4014
# 1st loop
# ---
#
# bl=0 pos[1]=[60.0 -3.4 4.7] dr=1.01 t=0.0ps kin=1.67 pot=23.24 Rg=47.299 SPS=4260
# 1st loop
# ---
#
# bl=0 pos[1]=[59.3 -4.3 5.1] dr=1.01 t=0.0ps kin=1.66 pot=23.18 Rg=46.788 SPS=4195
# 1st loop
# ---
#
# bl=0 pos[1]=[58.7 -4.8 6.1] dr=1.00 t=0.0ps kin=1.64 pot=23.07 Rg=46.303 SPS=4360
# 1st loop
# ---
#
# bl=0 pos[1]=[57.9 -4.4 6.1] dr=0.99 t=0.0ps kin=1.64 pot=23.00 Rg=45.819 SPS=4295
# 1st loop
# ---
#
# bl=0 pos[1]=[57.2 -5.0 6.2] dr=0.99 t=0.0ps kin=1.66 pot=22.89 Rg=45.331 SPS=4326
# 1st loop
# ---
#
# bl=0 pos[1]=[56.8 -5.4 5.8] dr=0.99 t=0.0ps kin=1.65 pot=22.82 Rg=44.835 SPS=4249
# 1st loop
# ---
#
# bl=0 pos[1]=[55.7 -5.6 5.3] dr=0.99 t=0.0ps kin=1.67 pot=22.74 Rg=44.328 SPS=4253
# 1st loop
# ---
#
# bl=0 pos[1]=[55.3 -5.0 4.5] dr=0.99 t=0.0ps kin=1.63 pot=22.66 Rg=43.832 SPS=4258
# 1st loop
# ---
#
# bl=0 pos[1]=[54.7 -3.4 3.7] dr=0.98 t=0.0ps kin=1.63 pot=22.57 Rg=43.356 SPS=4353
# 1st loop
# ---
#
# bl=0 pos[1]=[53.0 -1.8 4.1] dr=0.97 t=0.0ps kin=1.64 pot=22.50 Rg=42.883 SPS=4298
# 1st loop
# ---
#
# bl=0 pos[1]=[52.7 -0.9 5.5] dr=0.97 t=0.0ps kin=1.64 pot=22.42 Rg=42.435 SPS=4235
# 1st loop
# ---
#
# bl=0 pos[1]=[52.3 -0.8 4.8] dr=0.96 t=0.0ps kin=1.61 pot=22.40 Rg=42.022 SPS=4221
# 1st loop
# ---
#
# bl=0 pos[1]=[51.5 -0.4 5.0] dr=0.96 t=0.0ps kin=1.62 pot=22.36 Rg=41.602 SPS=4367
# 1st loop
# ---
#
# bl=0 pos[1]=[50.9 -0.1 5.7] dr=0.96 t=0.0ps kin=1.63 pot=22.32 Rg=41.185 SPS=4232
# 1st loop
# ---
#
# bl=0 pos[1]=[50.0 0.4 6.2] dr=0.96 t=0.0ps kin=1.67 pot=22.24 Rg=40.771 SPS=4230
# 1st loop
# ---
#
# bl=0 pos[1]=[49.8 -0.2 6.6] dr=0.96 t=0.0ps kin=1.67 pot=22.17 Rg=40.358 SPS=4282
# 1st loop
# ---
#
# bl=0 pos[1]=[49.9 -0.6 6.8] dr=0.96 t=0.0ps kin=1.64 pot=22.13 Rg=39.938 SPS=4232
# 1st loop
# ---
#
# bl=0 pos[1]=[49.7 -0.9 7.2] dr=0.96 t=0.0ps kin=1.62 pot=22.06 Rg=39.511 SPS=4274
# 1st loop
# ---
#
# bl=0 pos[1]=[48.8 -0.9 7.1] dr=0.95 t=0.0ps kin=1.63 pot=21.97 Rg=39.099 SPS=4131
# 1st loop
# ---
#
# bl=0 pos[1]=[49.0 -0.9 7.8] dr=0.95 t=0.0ps kin=1.62 pot=21.93 Rg=38.702 SPS=4287
# 1st loop
# ---
#
# bl=0 pos[1]=[49.0 -2.4 8.2] dr=0.94 t=0.0ps kin=1.63 pot=21.89 Rg=38.301 SPS=4230
# 1st loop
# ---
#
# bl=0 pos[1]=[48.1 -2.6 7.4] dr=0.94 t=0.0ps kin=1.62 pot=21.83 Rg=37.914 SPS=4213
# 1st loop
# ---
#
# bl=0 pos[1]=[47.7 -2.3 7.0] dr=0.92 t=0.0ps kin=1.63 pot=21.79 Rg=37.541 SPS=4219
# 1st loop
# ---
#
# bl=0 pos[1]=[46.8 -1.3 7.4] dr=0.92 t=0.0ps kin=1.57 pot=21.75 Rg=37.184 SPS=4171
# 1st loop
# ---
#
# bl=0 pos[1]=[44.7 -0.9 7.3] dr=0.94 t=0.0ps kin=1.64 pot=21.71 Rg=36.823 SPS=4234
# 1st loop
# ---
#
# bl=0 pos[1]=[43.4 -1.3 8.1] dr=0.93 t=0.0ps kin=1.63 pot=21.67 Rg=36.464 SPS=4320
# 1st loop
# ---
#
# bl=0 pos[1]=[42.0 -0.6 7.6] dr=0.94 t=0.0ps kin=1.62 pot=21.61 Rg=36.109 SPS=4285
# 1st loop
# ---
#
# bl=0 pos[1]=[41.7 0.1 7.1] dr=0.92 t=0.0ps kin=1.61 pot=21.57 Rg=35.770 SPS=4239
# 1st loop
# ---
#
# bl=0 pos[1]=[41.7 -0.2 6.6] dr=0.92 t=0.0ps kin=1.60 pot=21.52 Rg=35.446 SPS=4153
# 1st loop
# ---
#
# bl=0 pos[1]=[41.2 -0.1 6.7] dr=0.90 t=0.0ps kin=1.58 pot=21.48 Rg=35.135 SPS=4172
# 1st loop
# ---
#
# bl=0 pos[1]=[39.9 -0.8 6.5] dr=0.90 t=0.0ps kin=1.55 pot=21.44 Rg=34.826 SPS=4129
# 1st loop
# ---
#
# bl=0 pos[1]=[39.1 -1.0 7.7] dr=0.89 t=0.0ps kin=1.59 pot=21.36 Rg=34.516 SPS=4170
# 1st loop
# ---
#
# bl=0 pos[1]=[39.1 -1.6 7.6] dr=0.89 t=0.0ps kin=1.57 pot=21.31 Rg=34.222 SPS=4222
# 1st loop
# ---
#
# bl=0 pos[1]=[38.7 -1.8 7.1] dr=0.88 t=0.0ps kin=1.53 pot=21.32 Rg=33.946 SPS=4155
# 1st loop
# ---
#
# bl=0 pos[1]=[37.3 -2.0 6.5] dr=0.88 t=0.0ps kin=1.52 pot=21.28 Rg=33.658 SPS=4243
# 1st loop
# ---
#
# bl=0 pos[1]=[37.1 -2.0 6.8] dr=0.87 t=0.0ps kin=1.56 pot=21.21 Rg=33.360 SPS=4264
# 1st loop
# ---
#
# bl=0 pos[1]=[37.0 -2.2 7.2] dr=0.87 t=0.0ps kin=1.51 pot=21.22 Rg=33.066 SPS=4230
# 1st loop
# ---
#
# bl=0 pos[1]=[37.2 -2.5 7.1] dr=0.87 t=0.0ps kin=1.57 pot=21.15 Rg=32.764 SPS=4298
# 1st loop
# ---
#
# bl=0 pos[1]=[37.1 -2.5 6.4] dr=0.89 t=0.0ps kin=1.61 pot=21.09 Rg=32.457 SPS=3845
# 1st loop
# ---
#
# bl=0 pos[1]=[36.7 -1.9 5.9] dr=0.88 t=0.0ps kin=1.57 pot=21.05 Rg=32.159 SPS=4132
# 1st loop
# ---
#
# bl=0 pos[1]=[36.5 -1.8 5.7] dr=0.87 t=0.0ps kin=1.52 pot=21.04 Rg=31.869 SPS=4130
# 1st loop
# ---
#
# bl=0 pos[1]=[35.5 -1.8 6.7] dr=0.86 t=0.0ps kin=1.56 pot=21.02 Rg=31.596 SPS=4243
# 1st loop
# ---
#
# bl=0 pos[1]=[35.2 -1.4 6.7] dr=0.86 t=0.0ps kin=1.56 pot=20.99 Rg=31.333 SPS=4222
# 1st loop
# ---
#
# bl=0 pos[1]=[34.4 -1.9 6.9] dr=0.87 t=0.0ps kin=1.56 pot=20.95 Rg=31.071 SPS=4147
# 1st loop
# ---
#
# bl=0 pos[1]=[33.8 -1.7 7.2] dr=0.87 t=0.0ps kin=1.57 pot=20.91 Rg=30.807 SPS=4187
# 1st loop
# ---
#
# bl=0 pos[1]=[33.3 -2.0 6.9] dr=0.86 t=0.0ps kin=1.52 pot=20.94 Rg=30.541 SPS=4164
# 1st loop
# ---
#
# bl=0 pos[1]=[32.5 -2.3 6.8] dr=0.85 t=0.0ps kin=1.54 pot=20.89 Rg=30.301 SPS=4226
# 1st loop
# ---
#
# bl=0 pos[1]=[32.0 -1.6 6.1] dr=0.83 t=0.0ps kin=1.52 pot=20.84 Rg=30.097 SPS=4216
# 1st loop
# ---
#
# bl=0 pos[1]=[32.3 -2.9 5.8] dr=0.84 t=0.0ps kin=1.54 pot=20.81 Rg=29.892 SPS=4132
# 1st loop
# ---
#
# bl=0 pos[1]=[32.8 -4.2 6.5] dr=0.86 t=0.0ps kin=1.55 pot=20.76 Rg=29.674 SPS=4144
# 1st loop
# ---
#
# bl=0 pos[1]=[32.7 -4.4 5.9] dr=0.84 t=0.0ps kin=1.52 pot=20.72 Rg=29.467 SPS=4208
# 1st loop
# ---
#
# bl=0 pos[1]=[32.2 -4.5 4.9] dr=0.82 t=0.0ps kin=1.47 pot=20.75 Rg=29.275 SPS=4179
# 1st loop
# ---
#
# bl=0 pos[1]=[31.4 -5.1 4.4] dr=0.82 t=0.0ps kin=1.54 pot=20.71 Rg=29.070 SPS=4082
# 1st loop
# ---
#
# bl=0 pos[1]=[30.5 -6.4 3.7] dr=0.84 t=0.0ps kin=1.49 pot=20.71 Rg=28.868 SPS=4181
# 1st loop
# ---
#
# bl=0 pos[1]=[30.1 -6.8 2.7] dr=0.83 t=0.0ps kin=1.51 pot=20.71 Rg=28.685 SPS=4172
# 1st loop
# ---
#
# bl=0 pos[1]=[30.5 -6.6 1.5] dr=0.84 t=0.0ps kin=1.51 pot=20.66 Rg=28.499 SPS=4088
# 1st loop
# ---
#
# bl=0 pos[1]=[30.8 -5.3 0.1] dr=0.83 t=0.0ps kin=1.51 pot=20.68 Rg=28.300 SPS=4218
# 1st loop
# ---
#
# bl=0 pos[1]=[30.8 -4.9 -0.3] dr=0.82 t=0.0ps kin=1.52 pot=20.67 Rg=28.093 SPS=4340
# 1st loop
# ---
#
# bl=0 pos[1]=[29.9 -4.5 -0.4] dr=0.84 t=0.0ps kin=1.57 pot=20.62 Rg=27.891 SPS=4164
# 1st loop
# ---
#
# bl=0 pos[1]=[28.5 -4.2 0.3] dr=0.84 t=0.0ps kin=1.52 pot=20.63 Rg=27.689 SPS=4202
# 1st loop
# ---
#
# bl=0 pos[1]=[27.3 -3.2 0.9] dr=0.84 t=0.0ps kin=1.52 pot=20.61 Rg=27.474 SPS=3306
# 1st loop
# ---
#
# bl=0 pos[1]=[26.5 -2.9 2.5] dr=0.84 t=0.0ps kin=1.52 pot=20.58 Rg=27.270 SPS=2676
# 1st loop
# ---
#
# bl=0 pos[1]=[26.5 -2.0 3.5] dr=0.81 t=0.0ps kin=1.51 pot=20.55 Rg=27.070 SPS=2695
# 1st loop
# ---
#
# bl=0 pos[1]=[26.4 -2.0 3.8] dr=0.81 t=0.0ps kin=1.49 pot=20.52 Rg=26.880 SPS=2781
# 1st loop
# ---
#
# bl=0 pos[1]=[26.3 -3.8 3.0] dr=0.80 t=0.0ps kin=1.50 pot=20.51 Rg=26.704 SPS=2924
# 1st loop
# ---
#
# bl=0 pos[1]=[26.1 -3.9 2.4] dr=0.81 t=0.0ps kin=1.48 pot=20.53 Rg=26.528 SPS=2882
# 1st loop
# ---
#
# bl=0 pos[1]=[25.7 -3.8 3.3] dr=0.81 t=0.0ps kin=1.52 pot=20.49 Rg=26.352 SPS=2721
# 1st loop
# ---
#
# bl=0 pos[1]=[26.0 -2.9 3.5] dr=0.81 t=0.0ps kin=1.51 pot=20.48 Rg=26.183 SPS=2559
# 1st loop
# ---
#
# bl=0 pos[1]=[26.4 -2.8 2.8] dr=0.81 t=0.0ps kin=1.47 pot=20.45 Rg=26.014 SPS=2751
# 1st loop
# ---
#
# bl=0 pos[1]=[26.4 -3.1 0.9] dr=0.80 t=0.0ps kin=1.49 pot=20.46 Rg=25.844 SPS=2724
# 1st loop
# ---
#
# bl=0 pos[1]=[27.3 -2.7 2.1] dr=0.80 t=0.0ps kin=1.49 pot=20.46 Rg=25.683 SPS=2673
# 1st loop
# ---
#
# bl=0 pos[1]=[26.6 -2.9 2.2] dr=0.81 t=0.0ps kin=1.53 pot=20.42 Rg=25.521 SPS=2893
# 1st loop
# ---
#
# bl=0 pos[1]=[25.2 -1.9 2.1] dr=0.82 t=0.0ps kin=1.55 pot=20.41 Rg=25.339 SPS=2723
# 1st loop
# ---
#
# bl=0 pos[1]=[24.1 -0.6 1.4] dr=0.81 t=0.0ps kin=1.55 pot=20.44 Rg=25.161 SPS=2990
# 1st loop
# ---
#
# bl=0 pos[1]=[24.4 -0.7 1.4] dr=0.82 t=0.0ps kin=1.54 pot=20.42 Rg=24.999 SPS=2747
# 1st loop
# ---
#
# bl=0 pos[1]=[24.7 -1.9 2.3] dr=0.81 t=0.0ps kin=1.51 pot=20.43 Rg=24.832 SPS=2647
# 1st loop
# ---
#
# bl=0 pos[1]=[24.6 -2.6 2.8] dr=0.81 t=0.0ps kin=1.51 pot=20.38 Rg=24.657 SPS=2650
# 1st loop
# ---
#
# bl=0 pos[1]=[24.7 -2.4 4.1] dr=0.80 t=0.0ps kin=1.49 pot=20.39 Rg=24.482 SPS=2845
# 1st loop
# ---
#
# bl=0 pos[1]=[24.2 -2.7 3.7] dr=0.79 t=0.0ps kin=1.50 pot=20.36 Rg=24.310 SPS=2649
# 1st loop
# ---
#
# bl=0 pos[1]=[23.0 -1.1 3.6] dr=0.81 t=0.0ps kin=1.52 pot=20.36 Rg=24.140 SPS=2771
# 1st loop
# ---
#
# bl=0 pos[1]=[23.2 -1.1 2.3] dr=0.82 t=0.0ps kin=1.50 pot=20.34 Rg=23.974 SPS=2823
# 1st loop
# ---
#
# bl=0 pos[1]=[23.5 -0.4 2.3] dr=0.80 t=0.0ps kin=1.47 pot=20.36 Rg=23.811 SPS=2780
# 1st loop
# ---
#
# bl=0 pos[1]=[22.9 -1.7 2.6] dr=0.80 t=0.0ps kin=1.49 pot=20.30 Rg=23.656 SPS=2688
# 1st loop
# ---
#
# bl=0 pos[1]=[22.4 -3.0 4.0] dr=0.79 t=0.0ps kin=1.48 pot=20.32 Rg=23.507 SPS=2629
# 1st loop
# ---
#
# bl=0 pos[1]=[22.2 -4.7 3.3] dr=0.81 t=0.0ps kin=1.51 pot=20.31 Rg=23.365 SPS=2652
# 1st loop
# ---
#
# bl=0 pos[1]=[21.8 -4.6 2.7] dr=0.83 t=0.0ps kin=1.54 pot=20.27 Rg=23.215 SPS=3074
# 1st loop
# ---
#
# bl=0 pos[1]=[21.7 -5.5 2.6] dr=0.80 t=0.0ps kin=1.50 pot=20.31 Rg=23.073 SPS=2652
# 1st loop
# ---
#
# bl=0 pos[1]=[21.4 -5.0 2.7] dr=0.80 t=0.0ps kin=1.52 pot=20.28 Rg=22.928 SPS=2821
# 1st loop
# ---
#
# bl=0 pos[1]=[21.7 -4.3 2.6] dr=0.82 t=0.0ps kin=1.52 pot=20.26 Rg=22.791 SPS=2594
# 1st loop
# ---
#
# bl=0 pos[1]=[21.9 -3.9 3.2] dr=0.78 t=0.0ps kin=1.51 pot=20.26 Rg=22.671 SPS=2591
# 1st loop
# ---
#
# bl=0 pos[1]=[21.6 -3.7 3.7] dr=0.79 t=0.0ps kin=1.53 pot=20.24 Rg=22.556 SPS=2536
# 1st loop
# ---
#
# bl=0 pos[1]=[22.0 -4.0 3.5] dr=0.77 t=0.0ps kin=1.47 pot=20.26 Rg=22.432 SPS=2697
# 1st loop
# ---
#
# bl=0 pos[1]=[23.0 -3.1 2.7] dr=0.79 t=0.0ps kin=1.55 pot=20.22 Rg=22.298 SPS=2597
# 1st loop
# ---
#
# bl=0 pos[1]=[22.6 -1.9 2.6] dr=0.79 t=0.0ps kin=1.52 pot=20.24 Rg=22.162 SPS=2617
# 1st loop
# ---
#
# bl=0 pos[1]=[22.6 -3.9 2.6] dr=0.80 t=0.0ps kin=1.52 pot=20.25 Rg=22.030 SPS=2664
# 1st loop
# ---
#
# bl=0 pos[1]=[23.5 -4.4 2.8] dr=0.81 t=0.0ps kin=1.53 pot=20.26 Rg=21.899 SPS=2817
# 1st loop
# ---
#
# bl=0 pos[1]=[23.6 -3.8 2.8] dr=0.81 t=0.0ps kin=1.53 pot=20.24 Rg=21.765 SPS=2798
# 1st loop
# ---
#
# bl=0 pos[1]=[23.9 -3.5 1.8] dr=0.80 t=0.0ps kin=1.55 pot=20.21 Rg=21.625 SPS=2731
# 1st loop
# ---
#
# bl=0 pos[1]=[23.1 -3.7 1.1] dr=0.79 t=0.0ps kin=1.58 pot=20.20 Rg=21.485 SPS=2704
# 1st loop
# ---
#
# bl=0 pos[1]=[21.9 -3.4 0.9] dr=0.80 t=0.0ps kin=1.53 pot=20.26 Rg=21.348 SPS=2599
# 1st loop
# ---
#
# bl=0 pos[1]=[22.5 -2.5 0.5] dr=0.81 t=0.0ps kin=1.53 pot=20.25 Rg=21.222 SPS=2849
# 1st loop
# ---
#
# bl=0 pos[1]=[21.8 -2.9 0.7] dr=0.79 t=0.0ps kin=1.55 pot=20.19 Rg=21.104 SPS=2585
# 1st loop
# ---
#
# bl=0 pos[1]=[20.9 -2.4 0.2] dr=0.79 t=0.0ps kin=1.52 pot=20.20 Rg=21.005 SPS=2694
# 1st loop
# ---
#
# bl=0 pos[1]=[20.5 -1.6 0.3] dr=0.79 t=0.0ps kin=1.60 pot=20.16 Rg=20.906 SPS=2644
# 1st loop
# ---
#
# bl=0 pos[1]=[20.5 -1.3 0.8] dr=0.80 t=0.0ps kin=1.50 pot=20.20 Rg=20.808 SPS=2672
# 1st loop
# ---
#
# bl=0 pos[1]=[19.6 -1.4 0.5] dr=0.78 t=0.0ps kin=1.49 pot=20.19 Rg=20.706 SPS=2718
# 1st loop
# ---
#
# bl=0 pos[1]=[19.9 -2.1 0.5] dr=0.79 t=0.0ps kin=1.52 pot=20.18 Rg=20.599 SPS=2838
# 1st loop
# ---
#
# bl=0 pos[1]=[18.9 -2.2 0.4] dr=0.79 t=0.0ps kin=1.52 pot=20.20 Rg=20.480 SPS=2760
# 1st loop
# ---
#
# bl=0 pos[1]=[19.8 -2.2 -0.0] dr=0.81 t=0.0ps kin=1.56 pot=20.15 Rg=20.375 SPS=2689
# 1st loop
# ---
#
# bl=0 pos[1]=[20.7 -1.6 0.0] dr=0.80 t=0.0ps kin=1.53 pot=20.18 Rg=20.288 SPS=2695
# 1st loop
# ---
#
# bl=0 pos[1]=[21.4 -1.1 -0.1] dr=0.79 t=0.0ps kin=1.55 pot=20.20 Rg=20.201 SPS=2713
# 1st loop
# ---
#
# bl=0 pos[1]=[21.1 -1.2 -1.0] dr=0.79 t=0.0ps kin=1.57 pot=20.15 Rg=20.121 SPS=2728
# 1st loop
# ---
#
# bl=0 pos[1]=[20.6 -2.1 -0.9] dr=0.80 t=0.0ps kin=1.54 pot=20.13 Rg=20.032 SPS=2707
# 1st loop
# ---
#
# bl=0 pos[1]=[20.6 -2.5 -0.1] dr=0.79 t=0.0ps kin=1.54 pot=20.13 Rg=19.944 SPS=2675
# 1st loop
# ---
#
# bl=0 pos[1]=[20.2 -3.4 0.3] dr=0.80 t=0.0ps kin=1.54 pot=20.12 Rg=19.871 SPS=2932
# 1st loop
# ---
#
# bl=0 pos[1]=[19.6 -3.5 1.0] dr=0.80 t=0.0ps kin=1.52 pot=20.14 Rg=19.775 SPS=2670
# 1st loop
# ---
#
# bl=0 pos[1]=[19.5 -3.6 2.7] dr=0.79 t=0.0ps kin=1.48 pot=20.14 Rg=19.688 SPS=2626
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 -2.9 2.2] dr=0.79 t=0.0ps kin=1.50 pot=20.15 Rg=19.596 SPS=2866
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 -2.7 1.9] dr=0.79 t=0.0ps kin=1.52 pot=20.12 Rg=19.513 SPS=2714
# 1st loop
# ---
#
# bl=0 pos[1]=[16.6 -2.1 1.7] dr=0.78 t=0.0ps kin=1.50 pot=20.09 Rg=19.419 SPS=2833
# 1st loop
# ---
#
# bl=0 pos[1]=[17.5 -3.5 1.9] dr=0.77 t=0.0ps kin=1.51 pot=20.08 Rg=19.321 SPS=2690
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 -4.2 1.7] dr=0.78 t=0.0ps kin=1.50 pot=20.09 Rg=19.223 SPS=2811
# 1st loop
# ---
#
# bl=0 pos[1]=[17.7 -3.8 1.1] dr=0.79 t=0.0ps kin=1.52 pot=20.09 Rg=19.149 SPS=2812
# 1st loop
# ---
#
# bl=0 pos[1]=[17.7 -3.7 1.1] dr=0.78 t=0.0ps kin=1.52 pot=20.10 Rg=19.072 SPS=2597
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 -2.7 2.0] dr=0.79 t=0.0ps kin=1.51 pot=20.11 Rg=19.010 SPS=2786
# 1st loop
# ---
#
# bl=0 pos[1]=[19.5 -2.9 1.7] dr=0.77 t=0.0ps kin=1.51 pot=20.10 Rg=18.954 SPS=2977
# 1st loop
# ---
#
# bl=0 pos[1]=[18.4 -3.6 2.1] dr=0.76 t=0.0ps kin=1.51 pot=20.06 Rg=18.901 SPS=3563
# 1st loop
# ---
#
# bl=0 pos[1]=[18.4 -3.7 0.5] dr=0.78 t=0.0ps kin=1.48 pot=20.09 Rg=18.852 SPS=3533
# 1st loop
# ---
#
# bl=0 pos[1]=[19.4 -3.8 0.0] dr=0.78 t=0.0ps kin=1.50 pot=20.07 Rg=18.804 SPS=3653
# 1st loop
# ---
#
# bl=0 pos[1]=[19.8 -3.5 0.3] dr=0.78 t=0.0ps kin=1.51 pot=20.07 Rg=18.760 SPS=3694
# 1st loop
# ---
#
# bl=0 pos[1]=[20.6 -2.5 1.0] dr=0.77 t=0.0ps kin=1.52 pot=20.08 Rg=18.720 SPS=3751
# 1st loop
# ---
#
# bl=0 pos[1]=[21.2 -0.7 0.2] dr=0.78 t=0.0ps kin=1.55 pot=20.07 Rg=18.683 SPS=3831
# 1st loop
# ---
#
# bl=0 pos[1]=[20.2 0.5 -0.8] dr=0.79 t=0.0ps kin=1.49 pot=20.12 Rg=18.638 SPS=3870
# 1st loop
# ---
#
# bl=0 pos[1]=[19.6 0.5 -0.3] dr=0.78 t=0.0ps kin=1.49 pot=20.09 Rg=18.604 SPS=3949
# 1st loop
# ---
#
# bl=0 pos[1]=[20.2 0.3 0.2] dr=0.78 t=0.0ps kin=1.54 pot=20.04 Rg=18.581 SPS=3932
# 1st loop
# ---
#
# bl=0 pos[1]=[21.0 0.1 -0.0] dr=0.78 t=0.0ps kin=1.53 pot=20.06 Rg=18.549 SPS=3914
# 1st loop
# ---
#
# bl=0 pos[1]=[21.0 1.1 -0.4] dr=0.78 t=0.0ps kin=1.48 pot=20.11 Rg=18.526 SPS=3949
# 1st loop
# ---
#
# bl=0 pos[1]=[21.7 1.0 -0.5] dr=0.77 t=0.0ps kin=1.50 pot=20.08 Rg=18.503 SPS=3849
# 1st loop
# ---
#
# bl=0 pos[1]=[22.9 0.9 -0.8] dr=0.78 t=0.0ps kin=1.51 pot=20.07 Rg=18.475 SPS=3899
# 1st loop
# ---
#
# bl=0 pos[1]=[23.1 1.4 -0.6] dr=0.79 t=0.0ps kin=1.49 pot=20.07 Rg=18.424 SPS=3837
# 1st loop
# ---
#
# bl=0 pos[1]=[22.8 2.2 -0.7] dr=0.78 t=0.0ps kin=1.54 pot=20.01 Rg=18.358 SPS=3903
# 1st loop
# ---
#
# bl=0 pos[1]=[21.7 2.8 -0.4] dr=0.77 t=0.0ps kin=1.48 pot=20.03 Rg=18.298 SPS=3895
# 1st loop
# ---
#
# bl=0 pos[1]=[22.6 3.2 -0.1] dr=0.76 t=0.0ps kin=1.47 pot=20.05 Rg=18.228 SPS=3837
# 1st loop
# ---
#
# bl=0 pos[1]=[22.5 3.1 0.3] dr=0.77 t=0.0ps kin=1.49 pot=20.05 Rg=18.169 SPS=3944
# 1st loop
# ---
#
# bl=0 pos[1]=[21.6 2.4 0.1] dr=0.76 t=0.0ps kin=1.48 pot=20.06 Rg=18.111 SPS=3864
# 1st loop
# ---
#
# bl=0 pos[1]=[21.7 2.3 0.9] dr=0.78 t=0.0ps kin=1.51 pot=20.06 Rg=18.042 SPS=3851
# 1st loop
# ---
#
# bl=0 pos[1]=[21.5 2.5 1.2] dr=0.77 t=0.0ps kin=1.50 pot=20.04 Rg=17.970 SPS=3801
# 1st loop
# ---
#
# bl=0 pos[1]=[20.7 2.7 1.7] dr=0.77 t=0.0ps kin=1.49 pot=20.01 Rg=17.892 SPS=3879
# 1st loop
# ---
#
# bl=0 pos[1]=[21.2 2.8 1.9] dr=0.77 t=0.0ps kin=1.49 pot=20.03 Rg=17.811 SPS=3562
# 1st loop
# ---
#
# bl=0 pos[1]=[21.0 1.7 2.2] dr=0.76 t=0.0ps kin=1.47 pot=20.02 Rg=17.727 SPS=3923
# 1st loop
# ---
#
# bl=0 pos[1]=[21.5 1.5 2.4] dr=0.77 t=0.0ps kin=1.48 pot=20.04 Rg=17.658 SPS=3916
# 1st loop
# ---
#
# bl=0 pos[1]=[21.3 1.8 2.5] dr=0.77 t=0.0ps kin=1.49 pot=20.03 Rg=17.592 SPS=3832
# 1st loop
# ---
#
# bl=0 pos[1]=[21.0 1.3 1.9] dr=0.77 t=0.0ps kin=1.52 pot=20.03 Rg=17.543 SPS=3897
# 1st loop
# ---
#
# bl=0 pos[1]=[19.8 1.2 0.9] dr=0.78 t=0.0ps kin=1.53 pot=20.04 Rg=17.507 SPS=3881
# 1st loop
# ---
#
# bl=0 pos[1]=[20.4 1.1 0.9] dr=0.77 t=0.0ps kin=1.51 pot=20.05 Rg=17.479 SPS=3866
# 1st loop
# ---
#
# bl=0 pos[1]=[21.5 1.9 0.7] dr=0.78 t=0.0ps kin=1.53 pot=20.06 Rg=17.445 SPS=3842
# 1st loop
# ---
#
# bl=0 pos[1]=[21.4 3.0 0.7] dr=0.79 t=0.0ps kin=1.54 pot=20.07 Rg=17.392 SPS=3832
# 1st loop
# ---
#
# bl=0 pos[1]=[20.9 4.0 0.1] dr=0.78 t=0.0ps kin=1.54 pot=20.03 Rg=17.347 SPS=3833
# 1st loop
# ---
#
# bl=0 pos[1]=[20.6 3.1 -0.0] dr=0.79 t=0.0ps kin=1.49 pot=20.05 Rg=17.305 SPS=3944
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 0.8 -0.5] dr=0.78 t=0.0ps kin=1.49 pot=20.05 Rg=17.264 SPS=3878
# 1st loop
# ---
#
# bl=0 pos[1]=[18.9 1.7 -0.4] dr=0.78 t=0.0ps kin=1.53 pot=20.02 Rg=17.210 SPS=3860
# 1st loop
# ---
#
# bl=0 pos[1]=[18.6 2.0 -1.2] dr=0.79 t=0.0ps kin=1.52 pot=20.02 Rg=17.149 SPS=3809
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 2.4 -0.9] dr=0.79 t=0.0ps kin=1.54 pot=20.00 Rg=17.089 SPS=3822
# 1st loop
# ---
#
# bl=0 pos[1]=[17.7 3.0 -1.4] dr=0.78 t=0.0ps kin=1.52 pot=20.02 Rg=17.033 SPS=3795
# 1st loop
# ---
#
# bl=0 pos[1]=[18.2 2.5 -1.3] dr=0.78 t=0.0ps kin=1.52 pot=20.04 Rg=16.962 SPS=3833
# 1st loop
# ---
#
# bl=0 pos[1]=[19.1 2.1 -0.7] dr=0.78 t=0.0ps kin=1.53 pot=20.01 Rg=16.897 SPS=3912
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 1.8 -0.3] dr=0.78 t=0.0ps kin=1.52 pot=20.03 Rg=16.846 SPS=3894
# 1st loop
# ---
#
# bl=0 pos[1]=[19.7 2.0 0.1] dr=0.78 t=0.0ps kin=1.52 pot=20.00 Rg=16.790 SPS=3893
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 1.6 -0.4] dr=0.77 t=0.0ps kin=1.50 pot=20.00 Rg=16.730 SPS=4009
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 1.1 -0.8] dr=0.77 t=0.0ps kin=1.49 pot=19.99 Rg=16.665 SPS=3864
# 1st loop
# ---
#
# bl=0 pos[1]=[19.1 1.4 -0.8] dr=0.75 t=0.0ps kin=1.49 pot=20.00 Rg=16.604 SPS=3880
# 1st loop
# ---
#
# bl=0 pos[1]=[19.4 2.8 -0.9] dr=0.77 t=0.0ps kin=1.50 pot=19.99 Rg=16.532 SPS=3923
# 1st loop
# ---
#
# bl=0 pos[1]=[20.0 3.3 -0.8] dr=0.77 t=0.0ps kin=1.49 pot=19.99 Rg=16.466 SPS=3834
# 1st loop
# ---
#
# bl=0 pos[1]=[20.4 4.3 -0.9] dr=0.76 t=0.0ps kin=1.51 pot=19.97 Rg=16.397 SPS=3855
# 1st loop
# ---
#
# bl=0 pos[1]=[21.2 4.3 -0.3] dr=0.77 t=0.0ps kin=1.50 pot=19.98 Rg=16.342 SPS=3884
# 1st loop
# ---
#
# bl=0 pos[1]=[20.5 4.7 0.5] dr=0.76 t=0.0ps kin=1.47 pot=20.00 Rg=16.284 SPS=3930
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 5.4 0.6] dr=0.76 t=0.0ps kin=1.49 pot=19.97 Rg=16.237 SPS=3938
# 1st loop
# ---
#
# bl=0 pos[1]=[19.7 5.7 0.3] dr=0.77 t=0.0ps kin=1.50 pot=19.96 Rg=16.171 SPS=3862
# 1st loop
# ---
#
# bl=0 pos[1]=[20.2 5.3 1.2] dr=0.75 t=0.0ps kin=1.48 pot=19.98 Rg=16.109 SPS=3936
# 1st loop
# ---
#
# bl=0 pos[1]=[20.1 4.2 1.9] dr=0.77 t=0.0ps kin=1.49 pot=20.01 Rg=16.077 SPS=3887
# 1st loop
# ---
#
# bl=0 pos[1]=[20.3 3.0 1.5] dr=0.76 t=0.0ps kin=1.50 pot=20.01 Rg=16.042 SPS=3877
# 1st loop
# ---
#
# bl=0 pos[1]=[20.7 2.7 0.1] dr=0.76 t=0.0ps kin=1.50 pot=19.97 Rg=16.000 SPS=3870
# 1st loop
# ---
#
# bl=0 pos[1]=[21.8 2.8 -0.2] dr=0.76 t=0.0ps kin=1.48 pot=20.00 Rg=15.967 SPS=3848
# 1st loop
# ---
#
# bl=0 pos[1]=[21.9 2.5 -0.2] dr=0.76 t=0.0ps kin=1.47 pot=19.98 Rg=15.945 SPS=3766
# 1st loop
# ---
#
# bl=0 pos[1]=[22.0 2.8 0.3] dr=0.77 t=0.0ps kin=1.51 pot=19.97 Rg=15.921 SPS=3899
# 1st loop
# ---
#
# bl=0 pos[1]=[21.0 3.3 0.7] dr=0.77 t=0.0ps kin=1.48 pot=20.01 Rg=15.881 SPS=3894
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 3.8 1.3] dr=0.77 t=0.0ps kin=1.48 pot=19.99 Rg=15.843 SPS=3897
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 2.9 1.7] dr=0.76 t=0.0ps kin=1.48 pot=19.98 Rg=15.812 SPS=3897
# 1st loop
# ---
#
# bl=0 pos[1]=[18.2 2.6 0.9] dr=0.76 t=0.0ps kin=1.49 pot=19.99 Rg=15.778 SPS=3891
# 1st loop
# ---
#
# bl=0 pos[1]=[18.8 2.7 1.4] dr=0.76 t=0.0ps kin=1.49 pot=20.00 Rg=15.742 SPS=3723
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 2.7 2.4] dr=0.76 t=0.0ps kin=1.52 pot=19.96 Rg=15.697 SPS=3761
# 1st loop
# ---
#
# bl=0 pos[1]=[18.8 2.4 2.9] dr=0.76 t=0.0ps kin=1.51 pot=20.03 Rg=15.634 SPS=3778
# 1st loop
# ---
#
# bl=0 pos[1]=[18.1 2.6 2.3] dr=0.76 t=0.0ps kin=1.54 pot=20.00 Rg=15.590 SPS=3699
# 1st loop
# ---
#
# bl=0 pos[1]=[17.6 3.1 2.1] dr=0.77 t=0.0ps kin=1.52 pot=19.98 Rg=15.549 SPS=3478
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 3.2 1.6] dr=0.77 t=0.0ps kin=1.52 pot=20.02 Rg=15.514 SPS=3437
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 3.0 1.6] dr=0.78 t=0.0ps kin=1.56 pot=19.98 Rg=15.481 SPS=3733
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 3.6 1.0] dr=0.77 t=0.0ps kin=1.54 pot=19.99 Rg=15.448 SPS=3653
# 1st loop
# ---
#
# bl=0 pos[1]=[19.2 3.7 1.9] dr=0.78 t=0.0ps kin=1.48 pot=20.03 Rg=15.407 SPS=3766
# 1st loop
# ---
#
# bl=0 pos[1]=[20.0 3.5 3.3] dr=0.78 t=0.0ps kin=1.50 pot=20.03 Rg=15.369 SPS=3780
# 1st loop
# ---
#
# bl=0 pos[1]=[20.2 3.8 3.4] dr=0.78 t=0.0ps kin=1.51 pot=20.00 Rg=15.355 SPS=3625
# 1st loop
# ---
#
# bl=0 pos[1]=[19.9 3.8 2.5] dr=0.77 t=0.0ps kin=1.51 pot=20.00 Rg=15.343 SPS=3705
# 1st loop
# ---
#
# bl=0 pos[1]=[18.7 4.6 2.9] dr=0.77 t=0.0ps kin=1.53 pot=20.01 Rg=15.320 SPS=3693
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 5.2 2.8] dr=0.79 t=0.0ps kin=1.52 pot=20.02 Rg=15.314 SPS=3610
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 5.9 2.7] dr=0.80 t=0.0ps kin=1.50 pot=20.03 Rg=15.303 SPS=3706
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 6.0 2.2] dr=0.78 t=0.0ps kin=1.50 pot=20.02 Rg=15.290 SPS=3797
# 1st loop
# ---
#
# bl=0 pos[1]=[17.7 6.4 2.3] dr=0.79 t=0.0ps kin=1.53 pot=20.00 Rg=15.274 SPS=3518
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 6.1 2.3] dr=0.77 t=0.0ps kin=1.45 pot=20.00 Rg=15.260 SPS=3629
# 1st loop
# ---
#
# bl=0 pos[1]=[18.2 5.4 2.9] dr=0.77 t=0.0ps kin=1.47 pot=20.00 Rg=15.232 SPS=3705
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 5.1 3.7] dr=0.76 t=0.0ps kin=1.49 pot=19.97 Rg=15.203 SPS=3639
# 1st loop
# ---
#
# bl=0 pos[1]=[19.1 4.8 2.9] dr=0.76 t=0.0ps kin=1.48 pot=19.98 Rg=15.189 SPS=3600
# 1st loop
# ---
#
# bl=0 pos[1]=[19.2 5.2 2.8] dr=0.76 t=0.0ps kin=1.49 pot=19.95 Rg=15.180 SPS=3720
# 1st loop
# ---
#
# bl=0 pos[1]=[19.3 6.0 1.7] dr=0.77 t=0.0ps kin=1.50 pot=19.95 Rg=15.169 SPS=3802
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 6.1 1.4] dr=0.77 t=0.0ps kin=1.53 pot=19.93 Rg=15.139 SPS=3548
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 6.7 1.4] dr=0.77 t=0.0ps kin=1.49 pot=19.93 Rg=15.097 SPS=3632
# 1st loop
# ---
#
# bl=0 pos[1]=[17.2 7.1 1.9] dr=0.76 t=0.0ps kin=1.48 pot=19.92 Rg=15.044 SPS=3726
# 1st loop
# ---
#
# bl=0 pos[1]=[15.9 7.0 1.6] dr=0.76 t=0.0ps kin=1.45 pot=19.95 Rg=14.991 SPS=3757
# 1st loop
# ---
#
# bl=0 pos[1]=[16.1 7.1 1.4] dr=0.76 t=0.0ps kin=1.51 pot=19.91 Rg=14.924 SPS=3809
# 1st loop
# ---
#
# bl=0 pos[1]=[16.4 7.2 1.1] dr=0.76 t=0.0ps kin=1.50 pot=19.92 Rg=14.866 SPS=3785
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 7.7 2.0] dr=0.76 t=0.0ps kin=1.49 pot=19.94 Rg=14.836 SPS=3740
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 7.7 1.5] dr=0.77 t=0.0ps kin=1.50 pot=19.96 Rg=14.805 SPS=3616
# 1st loop
# ---
#
# bl=0 pos[1]=[17.7 7.1 0.8] dr=0.76 t=0.0ps kin=1.51 pot=19.92 Rg=14.784 SPS=3712
# 1st loop
# ---
#
# bl=0 pos[1]=[17.1 6.8 1.9] dr=0.75 t=0.0ps kin=1.52 pot=19.95 Rg=14.781 SPS=3749
# 1st loop
# ---
#
# bl=0 pos[1]=[18.1 7.1 2.8] dr=0.78 t=0.0ps kin=1.51 pot=19.99 Rg=14.783 SPS=3770
# 1st loop
# ---
#
# bl=0 pos[1]=[17.4 6.0 2.8] dr=0.79 t=0.0ps kin=1.52 pot=19.96 Rg=14.790 SPS=3358
# 1st loop
# ---
#
# bl=0 pos[1]=[16.4 4.6 3.7] dr=0.77 t=0.0ps kin=1.50 pot=19.98 Rg=14.785 SPS=3692
# 1st loop
# ---
#
# bl=0 pos[1]=[16.7 5.0 4.1] dr=0.76 t=0.0ps kin=1.52 pot=19.97 Rg=14.786 SPS=3663
# 1st loop
# ---
#
# bl=0 pos[1]=[16.2 4.9 3.8] dr=0.76 t=0.0ps kin=1.51 pot=19.96 Rg=14.775 SPS=3781
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 4.9 3.3] dr=0.78 t=0.0ps kin=1.55 pot=19.95 Rg=14.767 SPS=3546
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 4.6 4.4] dr=0.77 t=0.0ps kin=1.52 pot=19.98 Rg=14.765 SPS=3875
# 1st loop
# ---
#
# bl=0 pos[1]=[19.2 5.3 4.5] dr=0.77 t=0.0ps kin=1.54 pot=19.95 Rg=14.743 SPS=3711
# 1st loop
# ---
#
# bl=0 pos[1]=[19.2 5.4 4.5] dr=0.77 t=0.0ps kin=1.52 pot=19.98 Rg=14.722 SPS=3673
# 1st loop
# ---
#
# bl=0 pos[1]=[18.6 5.4 3.8] dr=0.77 t=0.0ps kin=1.55 pot=19.96 Rg=14.705 SPS=3791
# 1st loop
# ---
#
# bl=0 pos[1]=[18.9 7.4 3.2] dr=0.77 t=0.0ps kin=1.56 pot=19.98 Rg=14.692 SPS=3743
# 1st loop
# ---
#
# bl=0 pos[1]=[18.3 7.2 1.6] dr=0.77 t=0.0ps kin=1.55 pot=19.99 Rg=14.687 SPS=3809
# 1st loop
# ---
#
# bl=0 pos[1]=[19.0 7.5 2.2] dr=0.76 t=0.0ps kin=1.50 pot=20.00 Rg=14.682 SPS=3786
# 1st loop
# ---
#
# bl=0 pos[1]=[18.7 7.3 3.7] dr=0.75 t=0.0ps kin=1.51 pot=20.02 Rg=14.673 SPS=3676
# 1st loop
# ---
#
# bl=0 pos[1]=[18.1 6.5 3.6] dr=0.78 t=0.0ps kin=1.55 pot=20.00 Rg=14.642 SPS=3606
# 1st loop
# ---
#
# bl=0 pos[1]=[18.1 6.5 4.2] dr=0.79 t=0.0ps kin=1.54 pot=20.02 Rg=14.608 SPS=3650
# 1st loop
# ---
#
# bl=0 pos[1]=[18.1 6.7 4.5] dr=0.78 t=0.0ps kin=1.50 pot=20.02 Rg=14.584 SPS=3710
# 1st loop
# ---
#
# bl=0 pos[1]=[17.3 7.6 5.1] dr=0.78 t=0.0ps kin=1.50 pot=20.01 Rg=14.540 SPS=3840
# 1st loop
# ---
#
# bl=0 pos[1]=[15.8 7.1 5.4] dr=0.77 t=0.0ps kin=1.53 pot=19.97 Rg=14.488 SPS=3799
# 1st loop
# ---
#
# bl=0 pos[1]=[15.1 6.5 4.4] dr=0.78 t=0.0ps kin=1.53 pot=19.98 Rg=14.439 SPS=3668
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 6.1 4.5] dr=0.76 t=0.0ps kin=1.52 pot=19.98 Rg=14.399 SPS=3626
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 6.7 4.4] dr=0.77 t=0.0ps kin=1.54 pot=19.95 Rg=14.355 SPS=3792
# 1st loop
# ---
#
# bl=0 pos[1]=[14.7 7.0 3.6] dr=0.78 t=0.0ps kin=1.53 pot=19.97 Rg=14.321 SPS=3798
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 7.8 2.7] dr=0.76 t=0.0ps kin=1.52 pot=20.00 Rg=14.284 SPS=3813
# 1st loop
# ---
#
# bl=0 pos[1]=[15.7 8.5 1.0] dr=0.78 t=0.0ps kin=1.55 pot=19.97 Rg=14.247 SPS=3832
# 1st loop
# ---
#
# bl=0 pos[1]=[17.3 7.8 1.2] dr=0.78 t=0.0ps kin=1.51 pot=19.97 Rg=14.222 SPS=3802
# 1st loop
# ---
#
# bl=0 pos[1]=[17.6 7.7 1.0] dr=0.78 t=0.0ps kin=1.51 pot=19.97 Rg=14.201 SPS=3630
# 1st loop
# ---
#
# bl=0 pos[1]=[17.5 7.8 0.9] dr=0.75 t=0.0ps kin=1.53 pot=19.97 Rg=14.160 SPS=3734
# 1st loop
# ---
#
# bl=0 pos[1]=[17.1 8.8 0.7] dr=0.76 t=0.0ps kin=1.52 pot=19.95 Rg=14.121 SPS=3739
# 1st loop
# ---
#
# bl=0 pos[1]=[16.6 8.5 0.8] dr=0.74 t=0.0ps kin=1.46 pot=19.97 Rg=14.081 SPS=3549
# 1st loop
# ---
#
# bl=0 pos[1]=[16.7 7.2 1.0] dr=0.77 t=0.0ps kin=1.51 pot=19.96 Rg=14.046 SPS=3666
# 1st loop
# ---
#
# bl=0 pos[1]=[18.5 7.2 1.4] dr=0.77 t=0.0ps kin=1.51 pot=19.96 Rg=14.020 SPS=3676
# 1st loop
# ---
#
# bl=0 pos[1]=[18.0 6.3 0.6] dr=0.76 t=0.0ps kin=1.48 pot=19.99 Rg=13.983 SPS=3672
# 1st loop
# ---
#
# bl=0 pos[1]=[17.1 6.5 0.3] dr=0.78 t=0.0ps kin=1.55 pot=19.93 Rg=13.960 SPS=3440
# 1st loop
# ---
#
# bl=0 pos[1]=[16.7 6.9 -0.1] dr=0.78 t=0.0ps kin=1.50 pot=19.99 Rg=13.946 SPS=3640
# 1st loop
# ---
#
# bl=0 pos[1]=[16.6 7.5 0.2] dr=0.77 t=0.0ps kin=1.53 pot=19.95 Rg=13.925 SPS=3596
# 1st loop
# ---
#
# bl=0 pos[1]=[16.6 8.7 0.9] dr=0.78 t=0.0ps kin=1.53 pot=19.97 Rg=13.898 SPS=3588
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 10.4 2.1] dr=0.78 t=0.0ps kin=1.50 pot=20.01 Rg=13.872 SPS=3610
# 1st loop
# ---
#
# bl=0 pos[1]=[13.7 10.7 3.1] dr=0.79 t=0.0ps kin=1.53 pot=19.98 Rg=13.855 SPS=3573
# 1st loop
# ---
#
# bl=0 pos[1]=[13.2 11.0 4.1] dr=0.78 t=0.0ps kin=1.55 pot=19.97 Rg=13.837 SPS=3930
# 1st loop
# ---
#
# bl=0 pos[1]=[13.5 10.9 4.8] dr=0.76 t=0.0ps kin=1.53 pot=19.94 Rg=13.806 SPS=3960
# 1st loop
# ---
#
# bl=0 pos[1]=[13.7 10.1 4.0] dr=0.77 t=0.0ps kin=1.53 pot=19.96 Rg=13.771 SPS=3899
# 1st loop
# ---
#
# bl=0 pos[1]=[14.6 9.8 4.1] dr=0.77 t=0.0ps kin=1.53 pot=19.96 Rg=13.747 SPS=4012
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 10.7 4.5] dr=0.78 t=0.0ps kin=1.52 pot=19.95 Rg=13.740 SPS=4061
# 1st loop
# ---
#
# bl=0 pos[1]=[14.8 11.0 4.2] dr=0.77 t=0.0ps kin=1.51 pot=19.97 Rg=13.726 SPS=3979
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 9.8 3.6] dr=0.77 t=0.0ps kin=1.48 pot=19.96 Rg=13.715 SPS=4042
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 10.5 3.5] dr=0.74 t=0.0ps kin=1.51 pot=19.93 Rg=13.697 SPS=4108
# 1st loop
# ---
#
# bl=0 pos[1]=[14.7 10.1 3.1] dr=0.77 t=0.0ps kin=1.51 pot=19.97 Rg=13.668 SPS=4056
# 1st loop
# ---
#
# bl=0 pos[1]=[13.6 10.8 5.3] dr=0.76 t=0.0ps kin=1.52 pot=19.94 Rg=13.635 SPS=4110
# 1st loop
# ---
#
# bl=0 pos[1]=[12.9 10.5 5.5] dr=0.75 t=0.0ps kin=1.50 pot=19.94 Rg=13.606 SPS=4118
# 1st loop
# ---
#
# bl=0 pos[1]=[12.5 9.6 4.5] dr=0.76 t=0.0ps kin=1.50 pot=19.93 Rg=13.570 SPS=4111
# 1st loop
# ---
#
# bl=0 pos[1]=[12.7 10.1 3.8] dr=0.75 t=0.0ps kin=1.55 pot=19.92 Rg=13.543 SPS=4066
# 1st loop
# ---
#
# bl=0 pos[1]=[12.3 10.3 3.9] dr=0.77 t=0.0ps kin=1.47 pot=19.96 Rg=13.500 SPS=4046
# 1st loop
# ---
#
# bl=0 pos[1]=[12.0 10.6 4.1] dr=0.75 t=0.0ps kin=1.53 pot=19.89 Rg=13.453 SPS=4103
# 1st loop
# ---
#
# bl=0 pos[1]=[11.2 9.4 4.3] dr=0.75 t=0.0ps kin=1.49 pot=19.91 Rg=13.422 SPS=4140
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 9.6 4.5] dr=0.75 t=0.0ps kin=1.47 pot=19.91 Rg=13.386 SPS=4174
# 1st loop
# ---
#
# bl=0 pos[1]=[10.2 9.4 4.2] dr=0.76 t=0.0ps kin=1.49 pot=19.88 Rg=13.353 SPS=4121
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 10.1 4.3] dr=0.76 t=0.0ps kin=1.50 pot=19.92 Rg=13.323 SPS=4111
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 11.5 3.5] dr=0.76 t=0.0ps kin=1.50 pot=19.90 Rg=13.285 SPS=4179
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 11.6 2.9] dr=0.75 t=0.0ps kin=1.49 pot=19.92 Rg=13.264 SPS=4214
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 11.7 3.2] dr=0.74 t=0.0ps kin=1.46 pot=19.92 Rg=13.240 SPS=4135
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 11.5 3.9] dr=0.73 t=0.0ps kin=1.44 pot=19.90 Rg=13.233 SPS=4151
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 11.5 3.6] dr=0.76 t=0.0ps kin=1.48 pot=19.87 Rg=13.231 SPS=4132
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 11.0 3.1] dr=0.77 t=0.0ps kin=1.49 pot=19.88 Rg=13.225 SPS=4038
# 1st loop
# ---
#
# bl=0 pos[1]=[10.2 10.9 2.6] dr=0.75 t=0.0ps kin=1.50 pot=19.88 Rg=13.224 SPS=4052
# 1st loop
# ---
#
# bl=0 pos[1]=[10.5 10.2 3.3] dr=0.76 t=0.0ps kin=1.50 pot=19.90 Rg=13.241 SPS=4143
# 1st loop
# ---
#
# bl=0 pos[1]=[11.3 8.8 3.9] dr=0.76 t=0.0ps kin=1.45 pot=19.95 Rg=13.242 SPS=4164
# 1st loop
# ---
#
# bl=0 pos[1]=[12.3 7.8 3.5] dr=0.76 t=0.0ps kin=1.46 pot=19.93 Rg=13.233 SPS=4111
# 1st loop
# ---
#
# bl=0 pos[1]=[12.4 6.6 4.0] dr=0.73 t=0.0ps kin=1.47 pot=19.91 Rg=13.197 SPS=4141
# 1st loop
# ---
#
# bl=0 pos[1]=[11.9 5.5 4.6] dr=0.76 t=0.0ps kin=1.48 pot=19.90 Rg=13.179 SPS=4150
# 1st loop
# ---
#
# bl=0 pos[1]=[12.5 5.4 4.7] dr=0.76 t=0.0ps kin=1.48 pot=19.92 Rg=13.171 SPS=4158
# 1st loop
# ---
#
# bl=0 pos[1]=[12.6 4.3 3.8] dr=0.76 t=0.0ps kin=1.51 pot=19.90 Rg=13.130 SPS=4082
# 1st loop
# ---
#
# bl=0 pos[1]=[13.2 4.1 3.4] dr=0.76 t=0.0ps kin=1.48 pot=19.93 Rg=13.105 SPS=4161
# 1st loop
# ---
#
# bl=0 pos[1]=[12.7 3.5 4.3] dr=0.75 t=0.0ps kin=1.50 pot=19.92 Rg=13.090 SPS=4125
# 1st loop
# ---
#
# bl=0 pos[1]=[12.4 3.4 3.8] dr=0.75 t=0.0ps kin=1.48 pot=19.96 Rg=13.059 SPS=4176
# 1st loop
# ---
#
# bl=0 pos[1]=[12.4 4.0 4.6] dr=0.75 t=0.0ps kin=1.50 pot=19.92 Rg=13.029 SPS=4203
# 1st loop
# ---
#
# bl=0 pos[1]=[12.4 4.4 4.2] dr=0.74 t=0.0ps kin=1.50 pot=19.89 Rg=12.993 SPS=4172
# 1st loop
# ---
#
# bl=0 pos[1]=[12.6 3.9 4.3] dr=0.76 t=0.0ps kin=1.50 pot=19.92 Rg=12.968 SPS=4160
# 1st loop
# ---
#
# bl=0 pos[1]=[13.0 3.7 4.0] dr=0.76 t=0.0ps kin=1.52 pot=19.89 Rg=12.959 SPS=4158
# 1st loop
# ---
#
# bl=0 pos[1]=[13.1 4.1 4.4] dr=0.76 t=0.0ps kin=1.51 pot=19.94 Rg=12.963 SPS=4025
# 1st loop
# ---
#
# bl=0 pos[1]=[13.5 5.1 4.4] dr=0.76 t=0.0ps kin=1.54 pot=19.93 Rg=12.949 SPS=4208
# 1st loop
# ---
#
# bl=0 pos[1]=[13.0 5.8 4.5] dr=0.77 t=0.0ps kin=1.53 pot=19.93 Rg=12.923 SPS=4163
# 1st loop
# ---
#
# bl=0 pos[1]=[13.5 6.3 4.4] dr=0.76 t=0.0ps kin=1.49 pot=19.96 Rg=12.899 SPS=4210
# 1st loop
# ---
#
# bl=0 pos[1]=[14.3 7.3 3.8] dr=0.76 t=0.0ps kin=1.49 pot=19.93 Rg=12.880 SPS=4143
# 1st loop
# ---
#
# bl=0 pos[1]=[14.7 7.1 4.2] dr=0.77 t=0.0ps kin=1.47 pot=19.98 Rg=12.874 SPS=4146
# 1st loop
# ---
#
# bl=0 pos[1]=[14.4 5.6 4.9] dr=0.76 t=0.0ps kin=1.52 pot=19.93 Rg=12.874 SPS=4150
# 1st loop
# ---
#
# bl=0 pos[1]=[14.5 5.4 5.1] dr=0.76 t=0.0ps kin=1.51 pot=19.94 Rg=12.882 SPS=4123
# 1st loop
# ---
#
# bl=0 pos[1]=[14.1 5.5 4.7] dr=0.77 t=0.0ps kin=1.51 pot=19.95 Rg=12.897 SPS=4098
# 1st loop
# ---
#
# bl=0 pos[1]=[15.5 5.7 4.6] dr=0.77 t=0.0ps kin=1.50 pot=19.95 Rg=12.904 SPS=4051
# 1st loop
# ---
#
# bl=0 pos[1]=[16.9 6.1 3.4] dr=0.76 t=0.0ps kin=1.53 pot=19.94 Rg=12.902 SPS=4176
# 1st loop
# ---
#
# bl=0 pos[1]=[15.8 6.1 3.0] dr=0.77 t=0.0ps kin=1.53 pot=19.96 Rg=12.914 SPS=4181
# 1st loop
# ---
#
# bl=0 pos[1]=[17.6 5.8 2.3] dr=0.76 t=0.0ps kin=1.53 pot=19.96 Rg=12.934 SPS=4151
# 1st loop
# ---
#
# bl=0 pos[1]=[18.9 5.5 2.5] dr=0.77 t=0.0ps kin=1.49 pot=19.92 Rg=12.948 SPS=4143
# 1st loop
# ---
#
# bl=0 pos[1]=[18.2 5.3 2.5] dr=0.76 t=0.0ps kin=1.49 pot=19.94 Rg=12.941 SPS=4165
# 1st loop
# ---
#
# bl=0 pos[1]=[17.8 4.9 0.6] dr=0.76 t=0.0ps kin=1.49 pot=19.93 Rg=12.921 SPS=4134
# 1st loop
# ---
#
# bl=0 pos[1]=[17.2 4.9 1.4] dr=0.76 t=0.0ps kin=1.49 pot=19.96 Rg=12.903 SPS=4091
# 1st loop
# ---
#
# bl=0 pos[1]=[16.5 5.6 1.5] dr=0.75 t=0.0ps kin=1.46 pot=19.97 Rg=12.901 SPS=4137
# 1st loop
# ---
#
# bl=0 pos[1]=[16.5 5.2 1.8] dr=0.75 t=0.0ps kin=1.48 pot=19.94 Rg=12.892 SPS=4150
# 1st loop
# ---
#
# bl=0 pos[1]=[16.4 6.2 2.6] dr=0.76 t=0.0ps kin=1.51 pot=19.92 Rg=12.889 SPS=4149
# 1st loop
# ---
#
# bl=0 pos[1]=[15.9 7.2 2.6] dr=0.77 t=0.0ps kin=1.48 pot=19.93 Rg=12.885 SPS=4152
# 1st loop
# ---
#
# bl=0 pos[1]=[15.8 6.9 2.9] dr=0.77 t=0.0ps kin=1.53 pot=19.91 Rg=12.870 SPS=4074
# 1st loop
# ---
#
# bl=0 pos[1]=[15.1 7.9 3.1] dr=0.76 t=0.0ps kin=1.50 pot=19.92 Rg=12.840 SPS=4177
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 8.2 3.6] dr=0.74 t=0.0ps kin=1.46 pot=19.90 Rg=12.818 SPS=4175
# 1st loop
# ---
#
# bl=0 pos[1]=[14.1 7.1 4.4] dr=0.75 t=0.0ps kin=1.48 pot=19.87 Rg=12.801 SPS=4127
# 1st loop
# ---
#
# bl=0 pos[1]=[13.9 6.4 4.6] dr=0.76 t=0.0ps kin=1.50 pot=19.85 Rg=12.755 SPS=4113
# 1st loop
# ---
#
# bl=0 pos[1]=[13.8 7.9 4.9] dr=0.75 t=0.0ps kin=1.50 pot=19.86 Rg=12.703 SPS=4103
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 9.2 4.6] dr=0.74 t=0.0ps kin=1.49 pot=19.85 Rg=12.664 SPS=4161
# 1st loop
# ---
#
# bl=0 pos[1]=[14.4 8.9 3.8] dr=0.74 t=0.0ps kin=1.49 pot=19.87 Rg=12.625 SPS=4177
# 1st loop
# ---
#
# bl=0 pos[1]=[14.7 8.1 3.8] dr=0.74 t=0.0ps kin=1.47 pot=19.86 Rg=12.612 SPS=4148
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 8.3 4.6] dr=0.75 t=0.0ps kin=1.47 pot=19.86 Rg=12.604 SPS=4133
# 1st loop
# ---
#
# bl=0 pos[1]=[15.7 7.9 4.6] dr=0.76 t=0.0ps kin=1.49 pot=19.87 Rg=12.601 SPS=4173
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 7.5 5.4] dr=0.77 t=0.0ps kin=1.46 pot=19.91 Rg=12.600 SPS=4107
# 1st loop
# ---
#
# bl=0 pos[1]=[14.2 7.6 6.2] dr=0.77 t=0.0ps kin=1.50 pot=19.89 Rg=12.602 SPS=4083
# 1st loop
# ---
#
# bl=0 pos[1]=[14.0 7.1 6.4] dr=0.76 t=0.0ps kin=1.48 pot=19.90 Rg=12.608 SPS=4232
# 1st loop
# ---
#
# bl=0 pos[1]=[14.1 6.1 5.6] dr=0.74 t=0.0ps kin=1.49 pot=19.90 Rg=12.612 SPS=4137
# 1st loop
# ---
#
# bl=0 pos[1]=[14.2 7.0 5.4] dr=0.75 t=0.0ps kin=1.51 pot=19.88 Rg=12.619 SPS=3829
# 1st loop
# ---
#
# bl=0 pos[1]=[14.3 7.8 5.6] dr=0.75 t=0.0ps kin=1.52 pot=19.86 Rg=12.633 SPS=4122
# 1st loop
# ---
#
# bl=0 pos[1]=[14.8 7.8 5.5] dr=0.77 t=0.0ps kin=1.52 pot=19.88 Rg=12.647 SPS=4155
# 1st loop
# ---
#
# bl=0 pos[1]=[15.7 7.3 5.3] dr=0.76 t=0.0ps kin=1.53 pot=19.89 Rg=12.663 SPS=4203
# 1st loop
# ---
#
# bl=0 pos[1]=[15.4 6.3 4.9] dr=0.77 t=0.0ps kin=1.50 pot=19.92 Rg=12.686 SPS=4178
# 1st loop
# ---
#
# bl=0 pos[1]=[14.8 6.3 5.0] dr=0.76 t=0.0ps kin=1.53 pot=19.93 Rg=12.711 SPS=4046
# 1st loop
# ---
#
# bl=0 pos[1]=[13.8 6.9 4.6] dr=0.77 t=0.0ps kin=1.52 pot=19.95 Rg=12.719 SPS=4176
# 1st loop
# ---
#
# bl=0 pos[1]=[12.3 7.6 4.1] dr=0.77 t=0.0ps kin=1.47 pot=19.99 Rg=12.725 SPS=4074
# 1st loop
# ---
#
# bl=0 pos[1]=[12.2 8.1 4.1] dr=0.76 t=0.0ps kin=1.53 pot=19.94 Rg=12.702 SPS=4166
# 1st loop
# ---
#
# bl=0 pos[1]=[11.9 7.5 3.8] dr=0.77 t=0.0ps kin=1.51 pot=19.99 Rg=12.684 SPS=4080
# 1st loop
# ---
#
# bl=0 pos[1]=[12.6 8.6 4.4] dr=0.77 t=0.0ps kin=1.54 pot=19.96 Rg=12.667 SPS=4143
# 1st loop
# ---
#
# bl=0 pos[1]=[13.7 7.9 3.8] dr=0.77 t=0.0ps kin=1.53 pot=19.96 Rg=12.673 SPS=4111
# 1st loop
# ---
#
# bl=0 pos[1]=[13.8 7.9 3.4] dr=0.77 t=0.0ps kin=1.51 pot=19.97 Rg=12.686 SPS=4154
# 1st loop
# ---
#
# bl=0 pos[1]=[14.1 8.6 3.6] dr=0.78 t=0.0ps kin=1.55 pot=19.91 Rg=12.690 SPS=3937
# 1st loop
# ---
#
# bl=0 pos[1]=[14.3 8.6 2.3] dr=0.76 t=0.0ps kin=1.49 pot=19.94 Rg=12.700 SPS=4135
# 1st loop
# ---
#
# bl=0 pos[1]=[14.4 8.8 2.4] dr=0.75 t=0.0ps kin=1.49 pot=19.95 Rg=12.694 SPS=4143
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 8.3 3.2] dr=0.75 t=0.0ps kin=1.49 pot=19.96 Rg=12.693 SPS=4126
# 1st loop
# ---
#
# bl=0 pos[1]=[14.4 7.8 4.0] dr=0.77 t=0.0ps kin=1.50 pot=19.94 Rg=12.686 SPS=4119
# 1st loop
# ---
#
# bl=0 pos[1]=[15.3 8.3 4.5] dr=0.77 t=0.0ps kin=1.49 pot=19.94 Rg=12.669 SPS=4161
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 8.3 4.6] dr=0.76 t=0.0ps kin=1.56 pot=19.91 Rg=12.632 SPS=4138
# 1st loop
# ---
#
# bl=0 pos[1]=[14.6 7.5 4.9] dr=0.76 t=0.0ps kin=1.49 pot=19.95 Rg=12.589 SPS=4048
# 1st loop
# ---
#
# bl=0 pos[1]=[14.5 6.1 3.9] dr=0.74 t=0.0ps kin=1.49 pot=19.94 Rg=12.549 SPS=4179
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 6.4 4.2] dr=0.76 t=0.0ps kin=1.48 pot=19.93 Rg=12.538 SPS=4274
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 5.9 4.5] dr=0.75 t=0.0ps kin=1.49 pot=19.93 Rg=12.521 SPS=4017
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 5.4 4.8] dr=0.75 t=0.0ps kin=1.49 pot=19.96 Rg=12.496 SPS=4157
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 5.4 4.4] dr=0.75 t=0.0ps kin=1.48 pot=19.94 Rg=12.470 SPS=4166
# 1st loop
# ---
#
# bl=0 pos[1]=[15.3 4.9 3.4] dr=0.76 t=0.0ps kin=1.50 pot=19.93 Rg=12.435 SPS=4125
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 5.1 3.3] dr=0.76 t=0.0ps kin=1.51 pot=19.92 Rg=12.399 SPS=4039
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 5.7 3.8] dr=0.75 t=0.0ps kin=1.54 pot=19.92 Rg=12.363 SPS=4225
# 1st loop
# ---
#
# bl=0 pos[1]=[15.0 5.7 4.2] dr=0.77 t=0.0ps kin=1.55 pot=19.92 Rg=12.328 SPS=4128
# 1st loop
# ---
#
# bl=0 pos[1]=[15.2 5.9 4.2] dr=0.78 t=0.0ps kin=1.55 pot=19.93 Rg=12.305 SPS=4163
# 1st loop
# ---
#
# bl=0 pos[1]=[14.4 6.2 3.5] dr=0.77 t=0.0ps kin=1.54 pot=19.92 Rg=12.304 SPS=4229
# 1st loop
# ---
#
# bl=0 pos[1]=[14.5 5.8 3.0] dr=0.77 t=0.0ps kin=1.53 pot=19.93 Rg=12.290 SPS=4228
# 1st loop
# ---
#
# bl=0 pos[1]=[15.4 5.5 2.9] dr=0.77 t=0.0ps kin=1.51 pot=19.90 Rg=12.274 SPS=4227
# 1st loop
# ---
#
# bl=0 pos[1]=[14.9 5.4 2.3] dr=0.75 t=0.0ps kin=1.48 pot=19.92 Rg=12.259 SPS=4116
# 1st loop
# ---
#
# bl=0 pos[1]=[15.5 6.3 2.2] dr=0.76 t=0.0ps kin=1.49 pot=19.92 Rg=12.248 SPS=4162
# 1st loop
# ---
#
# bl=0 pos[1]=[16.4 6.5 1.6] dr=0.77 t=0.0ps kin=1.53 pot=19.89 Rg=12.229 SPS=4249
# 1st loop
# ---
#
# bl=0 pos[1]=[16.7 6.5 1.1] dr=0.77 t=0.0ps kin=1.51 pot=19.90 Rg=12.208 SPS=4229
# 1st loop
# ---
#
# bl=0 pos[1]=[16.6 7.1 1.0] dr=0.74 t=0.0ps kin=1.50 pot=19.89 Rg=12.201 SPS=4090
# 1st loop
# ---
#
# bl=0 pos[1]=[16.1 7.8 0.8] dr=0.75 t=0.0ps kin=1.48 pot=19.91 Rg=12.190 SPS=4118
# 1st loop
# ---
#
# bl=0 pos[1]=[15.5 7.9 0.7] dr=0.74 t=0.0ps kin=1.51 pot=19.86 Rg=12.182 SPS=3955
# 1st loop
# ---
#
# bl=0 pos[1]=[14.8 7.1 0.3] dr=0.76 t=0.0ps kin=1.51 pot=19.89 Rg=12.179 SPS=4218
# 1st loop
# ---
#
# bl=0 pos[1]=[13.5 7.3 0.8] dr=0.76 t=0.0ps kin=1.48 pot=19.93 Rg=12.186 SPS=4187
# 1st loop
# ---
#
# bl=0 pos[1]=[13.5 7.4 1.1] dr=0.74 t=0.0ps kin=1.51 pot=19.92 Rg=12.191 SPS=4303
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 7.7 0.5] dr=0.75 t=0.0ps kin=1.53 pot=19.91 Rg=12.196 SPS=4188
# 1st loop
# ---
#
# bl=0 pos[1]=[13.7 7.4 -0.1] dr=0.77 t=0.0ps kin=1.52 pot=19.91 Rg=12.206 SPS=4113
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 7.4 0.1] dr=0.75 t=0.0ps kin=1.47 pot=19.93 Rg=12.193 SPS=4005
# 1st loop
# ---
#
# bl=0 pos[1]=[13.8 7.2 0.5] dr=0.75 t=0.0ps kin=1.50 pot=19.90 Rg=12.175 SPS=4142
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 7.8 0.9] dr=0.75 t=0.0ps kin=1.49 pot=19.90 Rg=12.175 SPS=4148
# 1st loop
# ---
#
# bl=0 pos[1]=[13.9 8.1 0.8] dr=0.77 t=0.0ps kin=1.50 pot=19.88 Rg=12.157 SPS=4142
# 1st loop
# ---
#
# bl=0 pos[1]=[13.8 7.7 0.9] dr=0.75 t=0.0ps kin=1.48 pot=19.90 Rg=12.135 SPS=4177
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 7.0 0.2] dr=0.75 t=0.0ps kin=1.49 pot=19.90 Rg=12.112 SPS=4017
# 1st loop
# ---
#
# bl=0 pos[1]=[13.4 6.8 0.1] dr=0.76 t=0.0ps kin=1.52 pot=19.87 Rg=12.079 SPS=4159
# 1st loop
# ---
#
# bl=0 pos[1]=[12.9 7.3 -0.7] dr=0.76 t=0.0ps kin=1.52 pot=19.87 Rg=12.042 SPS=4178
# 1st loop
# ---
#
# bl=0 pos[1]=[13.1 7.1 -1.4] dr=0.76 t=0.0ps kin=1.53 pot=19.83 Rg=11.996 SPS=4164
# 1st loop
# ---
#
# bl=0 pos[1]=[12.9 6.0 -1.4] dr=0.76 t=0.0ps kin=1.48 pot=19.87 Rg=11.953 SPS=4175
# 1st loop
# ---
#
# bl=0 pos[1]=[12.4 6.0 -1.0] dr=0.77 t=0.0ps kin=1.50 pot=19.85 Rg=11.896 SPS=4156
# 1st loop
# ---
#
# bl=0 pos[1]=[12.2 5.8 -1.7] dr=0.75 t=0.0ps kin=1.54 pot=19.87 Rg=11.860 SPS=4216
# 1st loop
# ---
#
# bl=0 pos[1]=[12.3 6.2 -1.3] dr=0.76 t=0.0ps kin=1.45 pot=19.91 Rg=11.838 SPS=4084
# 1st loop
# ---
#
# bl=0 pos[1]=[11.7 6.5 0.2] dr=0.75 t=0.0ps kin=1.50 pot=19.87 Rg=11.806 SPS=4088
# 1st loop
# ---
#
# ...
# 1st loop
# ---
#
# bl=0 pos[1]=[10.5 2.3 2.7] dr=0.75 t=0.0ps kin=1.55 pot=19.82 Rg=7.969 SPS=2505
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 3.4 3.1] dr=0.76 t=0.0ps kin=1.53 pot=19.81 Rg=7.986 SPS=2469
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 4.0 2.4] dr=0.75 t=0.0ps kin=1.49 pot=19.83 Rg=8.006 SPS=2423
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 3.6 2.8] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=8.014 SPS=2529
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 3.4 3.0] dr=0.76 t=0.0ps kin=1.53 pot=19.79 Rg=7.983 SPS=2484
# 1st loop
# ---
#
# bl=0 pos[1]=[9.8 3.5 3.9] dr=0.76 t=0.0ps kin=1.49 pot=19.80 Rg=7.962 SPS=2469
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 3.7 3.4] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=7.945 SPS=2420
# 1st loop
# ---
#
# bl=0 pos[1]=[10.5 2.8 3.1] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.942 SPS=2599
# 1st loop
# ---
#
# bl=0 pos[1]=[10.2 1.8 3.2] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=7.976 SPS=2505
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 1.9 3.9] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=8.000 SPS=2561
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 2.0 3.0] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=8.010 SPS=2579
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 1.4 2.4] dr=0.75 t=0.0ps kin=1.52 pot=19.74 Rg=7.999 SPS=2600
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 0.9 3.0] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.999 SPS=2483
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 0.7 2.3] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=7.996 SPS=2744
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 0.7 1.0] dr=0.74 t=0.0ps kin=1.50 pot=19.83 Rg=7.972 SPS=2447
# 1st loop
# ---
#
# bl=0 pos[1]=[11.3 0.9 0.0] dr=0.75 t=0.0ps kin=1.51 pot=19.80 Rg=7.946 SPS=2550
# 1st loop
# ---
#
# bl=0 pos[1]=[11.3 -0.0 0.2] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=7.936 SPS=2498
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 -0.1 1.2] dr=0.75 t=0.0ps kin=1.52 pot=19.82 Rg=7.936 SPS=3295
# 1st loop
# ---
#
# bl=0 pos[1]=[11.5 0.2 2.2] dr=0.75 t=0.0ps kin=1.53 pot=19.79 Rg=7.931 SPS=3304
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 0.7 2.1] dr=0.74 t=0.0ps kin=1.51 pot=19.79 Rg=7.913 SPS=3448
# 1st loop
# ---
#
# bl=0 pos[1]=[10.4 1.6 1.9] dr=0.73 t=0.0ps kin=1.51 pot=19.78 Rg=7.917 SPS=3602
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 1.2 2.4] dr=0.74 t=0.0ps kin=1.48 pot=19.79 Rg=7.936 SPS=3609
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 0.9 3.6] dr=0.73 t=0.0ps kin=1.47 pot=19.80 Rg=7.952 SPS=3738
# 1st loop
# ---
#
# bl=0 pos[1]=[12.0 0.6 2.7] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=7.973 SPS=3691
# 1st loop
# ---
#
# bl=0 pos[1]=[11.4 1.3 2.3] dr=0.74 t=0.0ps kin=1.51 pot=19.76 Rg=7.984 SPS=3856
# 1st loop
# ---
#
# bl=0 pos[1]=[10.5 0.6 3.1] dr=0.74 t=0.0ps kin=1.51 pot=19.76 Rg=8.000 SPS=3816
# 1st loop
# ---
#
# bl=0 pos[1]=[10.4 0.1 3.5] dr=0.74 t=0.0ps kin=1.51 pot=19.76 Rg=8.007 SPS=3935
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 -0.6 3.3] dr=0.72 t=0.0ps kin=1.50 pot=19.74 Rg=7.993 SPS=3949
# 1st loop
# ---
#
# bl=0 pos[1]=[9.5 1.0 4.0] dr=0.73 t=0.0ps kin=1.46 pot=19.77 Rg=7.977 SPS=3851
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 0.8 3.6] dr=0.73 t=0.0ps kin=1.45 pot=19.76 Rg=7.975 SPS=3837
# 1st loop
# ---
#
# bl=0 pos[1]=[10.4 1.3 3.7] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=7.970 SPS=3900
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 0.3 3.0] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=7.984 SPS=3842
# 1st loop
# ---
#
# bl=0 pos[1]=[9.1 -0.3 2.7] dr=0.74 t=0.0ps kin=1.47 pot=19.80 Rg=7.965 SPS=3667
# 1st loop
# ---
#
# bl=0 pos[1]=[9.2 0.1 3.1] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=7.975 SPS=3893
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 0.7 3.7] dr=0.72 t=0.0ps kin=1.49 pot=19.76 Rg=7.985 SPS=3907
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 0.7 3.3] dr=0.75 t=0.0ps kin=1.50 pot=19.77 Rg=7.988 SPS=3873
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 0.5 3.4] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=7.983 SPS=3881
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 1.0 2.9] dr=0.74 t=0.0ps kin=1.53 pot=19.75 Rg=7.971 SPS=3912
# 1st loop
# ---
#
# bl=0 pos[1]=[9.3 1.3 2.7] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.961 SPS=3858
# 1st loop
# ---
#
# bl=0 pos[1]=[9.3 1.6 3.0] dr=0.74 t=0.0ps kin=1.51 pot=19.78 Rg=7.958 SPS=3914
# 1st loop
# ---
#
# bl=0 pos[1]=[9.2 1.6 3.7] dr=0.74 t=0.0ps kin=1.50 pot=19.80 Rg=7.930 SPS=3901
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 2.1 3.4] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=7.909 SPS=3916
# 1st loop
# ---
#
# bl=0 pos[1]=[11.0 2.5 4.0] dr=0.75 t=0.0ps kin=1.52 pot=19.71 Rg=7.908 SPS=3877
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 2.3 3.4] dr=0.74 t=0.0ps kin=1.48 pot=19.76 Rg=7.919 SPS=3818
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 2.2 3.8] dr=0.74 t=0.0ps kin=1.52 pot=19.78 Rg=7.936 SPS=3898
# 1st loop
# ---
#
# bl=0 pos[1]=[11.0 3.1 4.7] dr=0.73 t=0.0ps kin=1.50 pot=19.80 Rg=7.960 SPS=3917
# 1st loop
# ---
#
# bl=0 pos[1]=[10.2 4.0 3.3] dr=0.75 t=0.0ps kin=1.50 pot=19.85 Rg=7.973 SPS=3831
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 3.9 2.5] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=7.980 SPS=3850
# 1st loop
# ---
#
# bl=0 pos[1]=[9.5 3.5 2.6] dr=0.74 t=0.0ps kin=1.47 pot=19.80 Rg=8.007 SPS=3903
# 1st loop
# ---
#
# bl=0 pos[1]=[8.7 3.0 3.0] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=8.014 SPS=3909
# 1st loop
# ---
#
# bl=0 pos[1]=[8.2 3.4 3.2] dr=0.73 t=0.0ps kin=1.52 pot=19.72 Rg=8.015 SPS=3839
# 1st loop
# ---
#
# bl=0 pos[1]=[8.7 4.1 4.2] dr=0.75 t=0.0ps kin=1.50 pot=19.73 Rg=8.016 SPS=3872
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 3.8 4.3] dr=0.74 t=0.0ps kin=1.47 pot=19.75 Rg=8.020 SPS=3896
# 1st loop
# ---
#
# bl=0 pos[1]=[9.2 2.9 4.0] dr=0.72 t=0.0ps kin=1.45 pot=19.75 Rg=8.027 SPS=3872
# 1st loop
# ---
#
# bl=0 pos[1]=[9.3 2.5 3.8] dr=0.72 t=0.0ps kin=1.47 pot=19.73 Rg=8.043 SPS=3933
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 3.2 4.3] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=8.046 SPS=3613
# 1st loop
# ---
#
# bl=0 pos[1]=[10.1 3.2 4.5] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=8.052 SPS=3913
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 3.3 4.3] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=8.066 SPS=3955
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 3.2 4.1] dr=0.72 t=0.0ps kin=1.51 pot=19.75 Rg=8.089 SPS=4008
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 3.0 4.3] dr=0.73 t=0.0ps kin=1.47 pot=19.77 Rg=8.113 SPS=3923
# 1st loop
# ---
#
# bl=0 pos[1]=[11.3 3.0 4.8] dr=0.73 t=0.0ps kin=1.44 pot=19.79 Rg=8.121 SPS=3845
# 1st loop
# ---
#
# bl=0 pos[1]=[10.8 3.7 5.7] dr=0.72 t=0.0ps kin=1.48 pot=19.71 Rg=8.125 SPS=3918
# 1st loop
# ---
#
# bl=0 pos[1]=[9.0 4.4 6.1] dr=0.73 t=0.0ps kin=1.46 pot=19.71 Rg=8.105 SPS=3911
# 1st loop
# ---
#
# bl=0 pos[1]=[8.4 5.0 5.8] dr=0.72 t=0.0ps kin=1.49 pot=19.72 Rg=8.083 SPS=3892
# 1st loop
# ---
#
# bl=0 pos[1]=[8.0 4.0 5.0] dr=0.71 t=0.0ps kin=1.50 pot=19.69 Rg=8.079 SPS=3850
# 1st loop
# ---
#
# bl=0 pos[1]=[8.1 3.4 4.7] dr=0.74 t=0.0ps kin=1.51 pot=19.72 Rg=8.079 SPS=3921
# 1st loop
# ---
#
# bl=0 pos[1]=[7.9 2.9 4.5] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=8.091 SPS=3883
# 1st loop
# ---
#
# bl=0 pos[1]=[7.6 2.3 3.4] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=8.082 SPS=3931
# 1st loop
# ---
#
# bl=0 pos[1]=[7.1 1.9 4.0] dr=0.74 t=0.0ps kin=1.49 pot=19.82 Rg=8.073 SPS=3978
# 1st loop
# ---
#
# bl=0 pos[1]=[6.8 2.8 4.5] dr=0.73 t=0.0ps kin=1.50 pot=19.81 Rg=8.080 SPS=3933
# 1st loop
# ---
#
# bl=0 pos[1]=[6.9 2.6 4.1] dr=0.73 t=0.0ps kin=1.49 pot=19.80 Rg=8.080 SPS=3833
# 1st loop
# ---
#
# bl=0 pos[1]=[6.5 2.7 3.4] dr=0.74 t=0.0ps kin=1.54 pot=19.77 Rg=8.073 SPS=3915
# 1st loop
# ---
#
# bl=0 pos[1]=[6.3 3.2 3.1] dr=0.73 t=0.0ps kin=1.51 pot=19.82 Rg=8.071 SPS=3895
# 1st loop
# ---
#
# bl=0 pos[1]=[6.7 3.8 3.1] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=8.059 SPS=3920
# 1st loop
# ---
#
# bl=0 pos[1]=[6.9 4.0 3.6] dr=0.72 t=0.0ps kin=1.56 pot=19.77 Rg=8.075 SPS=3871
# 1st loop
# ---
#
# bl=0 pos[1]=[7.0 3.5 2.8] dr=0.72 t=0.0ps kin=1.48 pot=19.83 Rg=8.119 SPS=3884
# 1st loop
# ---
#
# bl=0 pos[1]=[6.7 3.4 3.0] dr=0.75 t=0.0ps kin=1.53 pot=19.77 Rg=8.119 SPS=3909
# 1st loop
# ---
#
# bl=0 pos[1]=[6.7 3.3 3.2] dr=0.74 t=0.0ps kin=1.54 pot=19.79 Rg=8.110 SPS=3789
# 1st loop
# ---
#
# bl=0 pos[1]=[6.9 3.2 3.2] dr=0.75 t=0.0ps kin=1.55 pot=19.76 Rg=8.101 SPS=3656
# 1st loop
# ---
#
# bl=0 pos[1]=[7.9 2.6 3.3] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=8.117 SPS=3916
# 1st loop
# ---
#
# bl=0 pos[1]=[8.5 3.2 3.1] dr=0.74 t=0.0ps kin=1.47 pot=19.77 Rg=8.139 SPS=3890
# 1st loop
# ---
#
# bl=0 pos[1]=[8.4 3.0 3.1] dr=0.72 t=0.0ps kin=1.54 pot=19.72 Rg=8.146 SPS=3641
# 1st loop
# ---
#
# bl=0 pos[1]=[7.4 3.4 3.8] dr=0.73 t=0.0ps kin=1.46 pot=19.78 Rg=8.137 SPS=3601
# 1st loop
# ---
#
# bl=0 pos[1]=[8.0 3.5 3.8] dr=0.72 t=0.0ps kin=1.48 pot=19.78 Rg=8.118 SPS=3673
# 1st loop
# ---
#
# bl=0 pos[1]=[8.1 3.3 4.5] dr=0.74 t=0.0ps kin=1.52 pot=19.73 Rg=8.086 SPS=3750
# 1st loop
# ---
#
# bl=0 pos[1]=[8.2 3.2 4.7] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=8.073 SPS=3703
# 1st loop
# ---
#
# bl=0 pos[1]=[8.0 3.7 4.6] dr=0.73 t=0.0ps kin=1.54 pot=19.73 Rg=8.069 SPS=3656
# 1st loop
# ---
#
# bl=0 pos[1]=[8.7 4.1 5.7] dr=0.73 t=0.0ps kin=1.46 pot=19.76 Rg=8.076 SPS=3664
# 1st loop
# ---
#
# bl=0 pos[1]=[9.3 2.5 5.8] dr=0.72 t=0.0ps kin=1.51 pot=19.75 Rg=8.074 SPS=3478
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 2.9 4.5] dr=0.72 t=0.0ps kin=1.47 pot=19.77 Rg=8.074 SPS=3759
# 1st loop
# ---
#
# bl=0 pos[1]=[10.2 3.0 3.4] dr=0.73 t=0.0ps kin=1.48 pot=19.76 Rg=8.085 SPS=3759
# 1st loop
# ---
#
# bl=0 pos[1]=[10.1 2.9 3.8] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=8.088 SPS=3646
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 3.5 4.1] dr=0.72 t=0.0ps kin=1.54 pot=19.73 Rg=8.083 SPS=3754
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 3.6 4.6] dr=0.73 t=0.0ps kin=1.47 pot=19.79 Rg=8.074 SPS=3699
# 1st loop
# ---
#
# bl=0 pos[1]=[10.3 3.8 5.2] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=8.083 SPS=3769
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 2.5 5.8] dr=0.73 t=0.0ps kin=1.51 pot=19.78 Rg=8.081 SPS=3623
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 2.1 6.1] dr=0.73 t=0.0ps kin=1.56 pot=19.77 Rg=8.084 SPS=3610
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 0.9 5.4] dr=0.74 t=0.0ps kin=1.55 pot=19.78 Rg=8.104 SPS=3583
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 0.5 4.3] dr=0.75 t=0.0ps kin=1.50 pot=19.78 Rg=8.111 SPS=3629
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 0.3 3.8] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=8.138 SPS=3612
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 1.3 3.7] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=8.169 SPS=3279
# 1st loop
# ---
#
# bl=0 pos[1]=[11.0 1.7 4.4] dr=0.75 t=0.0ps kin=1.49 pot=19.79 Rg=8.184 SPS=3443
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 1.5 5.3] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=8.176 SPS=3685
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 1.7 6.0] dr=0.75 t=0.0ps kin=1.47 pot=19.78 Rg=8.175 SPS=3519
# 1st loop
# ---
#
# bl=0 pos[1]=[10.3 2.2 4.5] dr=0.74 t=0.0ps kin=1.55 pot=19.76 Rg=8.136 SPS=3452
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 3.2 5.0] dr=0.75 t=0.0ps kin=1.51 pot=19.79 Rg=8.107 SPS=3631
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 3.3 6.1] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=8.113 SPS=3499
# 1st loop
# ---
#
# bl=0 pos[1]=[9.3 2.8 6.7] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=8.120 SPS=3684
# 1st loop
# ---
#
# bl=0 pos[1]=[8.4 2.0 5.9] dr=0.74 t=0.0ps kin=1.48 pot=19.78 Rg=8.120 SPS=3489
# 1st loop
# ---
#
# bl=0 pos[1]=[9.8 1.5 5.9] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=8.092 SPS=3563
# 1st loop
# ---
#
# bl=0 pos[1]=[10.3 2.0 7.2] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=8.043 SPS=3563
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 1.9 7.5] dr=0.76 t=0.0ps kin=1.53 pot=19.75 Rg=8.021 SPS=3531
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 2.3 7.9] dr=0.75 t=0.0ps kin=1.51 pot=19.73 Rg=8.025 SPS=3450
# 1st loop
# ---
#
# bl=0 pos[1]=[10.3 1.9 7.6] dr=0.74 t=0.0ps kin=1.49 pot=19.76 Rg=8.051 SPS=3504
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 0.7 7.8] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=8.074 SPS=3559
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 0.8 7.9] dr=0.73 t=0.0ps kin=1.50 pot=19.73 Rg=8.088 SPS=3529
# 1st loop
# ---
#
# bl=0 pos[1]=[8.7 1.5 6.4] dr=0.76 t=0.0ps kin=1.50 pot=19.76 Rg=8.055 SPS=3571
# 1st loop
# ---
#
# bl=0 pos[1]=[9.0 1.9 5.3] dr=0.74 t=0.0ps kin=1.51 pot=19.74 Rg=8.029 SPS=3608
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 1.6 5.2] dr=0.77 t=0.0ps kin=1.51 pot=19.77 Rg=8.019 SPS=3700
# 1st loop
# ---
#
# bl=0 pos[1]=[9.7 1.5 5.4] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=8.024 SPS=3619
# 1st loop
# ---
#
# bl=0 pos[1]=[9.5 0.9 5.5] dr=0.74 t=0.0ps kin=1.49 pot=19.81 Rg=8.022 SPS=3745
# 1st loop
# ---
#
# bl=0 pos[1]=[8.8 1.1 6.5] dr=0.73 t=0.0ps kin=1.51 pot=19.79 Rg=8.010 SPS=3739
# 1st loop
# ---
#
# bl=0 pos[1]=[9.1 1.9 6.7] dr=0.76 t=0.0ps kin=1.52 pot=19.77 Rg=8.003 SPS=3287
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 2.3 4.8] dr=0.74 t=0.0ps kin=1.51 pot=19.78 Rg=8.011 SPS=3367
# 1st loop
# ---
#
# bl=0 pos[1]=[9.0 1.8 4.0] dr=0.76 t=0.0ps kin=1.54 pot=19.76 Rg=8.025 SPS=3659
# 1st loop
# ---
#
# bl=0 pos[1]=[8.8 3.3 5.5] dr=0.76 t=0.0ps kin=1.50 pot=19.79 Rg=8.020 SPS=3636
# 1st loop
# ---
#
# bl=0 pos[1]=[8.1 4.3 5.9] dr=0.74 t=0.0ps kin=1.50 pot=19.79 Rg=7.993 SPS=3720
# 1st loop
# ---
#
# bl=0 pos[1]=[7.4 5.1 4.9] dr=0.74 t=0.0ps kin=1.47 pot=19.80 Rg=7.965 SPS=3625
# 1st loop
# ---
#
# bl=0 pos[1]=[7.2 4.0 6.1] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=7.949 SPS=3478
# 1st loop
# ---
#
# bl=0 pos[1]=[6.9 3.9 5.8] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=7.953 SPS=3563
# 1st loop
# ---
#
# bl=0 pos[1]=[7.3 4.1 5.4] dr=0.72 t=0.0ps kin=1.49 pot=19.76 Rg=7.959 SPS=3541
# 1st loop
# ---
#
# bl=0 pos[1]=[8.9 3.8 4.4] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.991 SPS=3356
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 3.8 4.2] dr=0.75 t=0.0ps kin=1.49 pot=19.78 Rg=8.020 SPS=3668
# 1st loop
# ---
#
# bl=0 pos[1]=[8.8 4.5 5.3] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=8.034 SPS=3687
# 1st loop
# ---
#
# bl=0 pos[1]=[8.2 3.8 6.0] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=8.059 SPS=3534
# 1st loop
# ---
#
# bl=0 pos[1]=[8.4 3.2 5.9] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=8.052 SPS=3757
# 1st loop
# ---
#
# bl=0 pos[1]=[8.5 3.5 6.2] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=8.026 SPS=3699
# 1st loop
# ---
#
# bl=0 pos[1]=[7.8 3.4 5.4] dr=0.74 t=0.0ps kin=1.52 pot=19.73 Rg=7.991 SPS=3421
# 1st loop
# ---
#
# bl=0 pos[1]=[8.8 3.0 5.4] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.997 SPS=3661
# 1st loop
# ---
#
# bl=0 pos[1]=[10.4 2.2 3.7] dr=0.74 t=0.0ps kin=1.48 pot=19.76 Rg=8.029 SPS=3412
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 1.8 3.1] dr=0.73 t=0.0ps kin=1.47 pot=19.75 Rg=8.038 SPS=2330
# 1st loop
# ---
#
# bl=0 pos[1]=[9.9 1.7 3.5] dr=0.73 t=0.0ps kin=1.47 pot=19.76 Rg=8.025 SPS=2329
# 1st loop
# ---
#
# bl=0 pos[1]=[10.9 1.6 3.6] dr=0.74 t=0.0ps kin=1.48 pot=19.75 Rg=7.984 SPS=3476
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 1.2 4.2] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.963 SPS=3612
# 1st loop
# ---
#
# bl=0 pos[1]=[11.0 1.6 4.3] dr=0.74 t=0.0ps kin=1.51 pot=19.74 Rg=7.942 SPS=3572
# 1st loop
# ---
#
# bl=0 pos[1]=[10.7 1.9 4.0] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.934 SPS=3539
# 1st loop
# ---
#
# bl=0 pos[1]=[10.0 1.8 5.6] dr=0.73 t=0.0ps kin=1.47 pot=19.79 Rg=7.952 SPS=3478
# 1st loop
# ---
#
# bl=0 pos[1]=[8.8 2.3 5.4] dr=0.73 t=0.0ps kin=1.47 pot=19.77 Rg=7.970 SPS=3539
# 1st loop
# ---
#
# bl=0 pos[1]=[8.4 1.2 5.6] dr=0.72 t=0.0ps kin=1.48 pot=19.75 Rg=7.977 SPS=3574
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 -0.1 6.0] dr=0.74 t=0.0ps kin=1.47 pot=19.77 Rg=7.969 SPS=3491
# 1st loop
# ---
#
# bl=0 pos[1]=[10.1 -0.2 4.5] dr=0.74 t=0.0ps kin=1.52 pot=19.77 Rg=7.987 SPS=3929
# 1st loop
# ---
#
# bl=0 pos[1]=[10.6 -0.5 3.8] dr=0.74 t=0.0ps kin=1.53 pot=19.79 Rg=7.994 SPS=3984
# 1st loop
# ---
#
# bl=0 pos[1]=[10.5 -1.4 3.4] dr=0.75 t=0.0ps kin=1.55 pot=19.78 Rg=8.009 SPS=3679
# 1st loop
# ---
#
# bl=0 pos[1]=[11.1 -1.6 2.7] dr=0.73 t=0.0ps kin=1.52 pot=19.80 Rg=8.006 SPS=3971
# 1st loop
# ---
#
# bl=0 pos[1]=[10.3 -2.4 2.3] dr=0.74 t=0.0ps kin=1.54 pot=19.76 Rg=8.026 SPS=3935
# 1st loop
# ---
#
# bl=0 pos[1]=[9.8 -2.3 2.2] dr=0.74 t=0.0ps kin=1.48 pot=19.81 Rg=8.048 SPS=4044
# 1st loop
# ---
#
# bl=0 pos[1]=[8.2 -2.4 2.7] dr=0.75 t=0.0ps kin=1.52 pot=19.81 Rg=8.053 SPS=4046
# 1st loop
# ---
#
# bl=0 pos[1]=[7.8 -2.7 2.0] dr=0.75 t=0.0ps kin=1.51 pot=19.81 Rg=8.048 SPS=4060
# 1st loop
# ---
#
# bl=0 pos[1]=[7.6 -3.0 1.4] dr=0.74 t=0.0ps kin=1.53 pot=19.79 Rg=8.025 SPS=4001
# 1st loop
# ---
#
# bl=0 pos[1]=[7.7 -2.5 1.5] dr=0.73 t=0.0ps kin=1.53 pot=19.81 Rg=8.005 SPS=3911
# 1st loop
# ---
#
# bl=0 pos[1]=[8.3 -2.3 2.4] dr=0.74 t=0.0ps kin=1.51 pot=19.83 Rg=8.000 SPS=4150
# 1st loop
# ---
#
# bl=0 pos[1]=[8.5 -3.2 3.1] dr=0.74 t=0.0ps kin=1.52 pot=19.82 Rg=7.995 SPS=4098
# 1st loop
# ---
#
# bl=0 pos[1]=[9.4 -4.1 3.0] dr=0.73 t=0.0ps kin=1.53 pot=19.79 Rg=7.984 SPS=3993
# 1st loop
# ---
#
# bl=0 pos[1]=[9.6 -4.1 1.8] dr=0.74 t=0.0ps kin=1.53 pot=19.76 Rg=7.972 SPS=4103
# 1st loop
# ---
#
# bl=0 pos[1]=[8.3 -4.9 2.2] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=7.942 SPS=4066
# 1st loop
# ---
#
# bl=0 pos[1]=[7.6 -4.7 2.9] dr=0.73 t=0.0ps kin=1.49 pot=19.73 Rg=7.913 SPS=4053
# 1st loop
# ---
#
# bl=0 pos[1]=[7.8 -4.3 2.8] dr=0.74 t=0.0ps kin=1.51 pot=19.76 Rg=7.920 SPS=4000
# 1st loop
# ---

# %%
print(sim.chromRG())
sim.saveStructure(mode='xyz')
# Out:
# 7.919855

# %%
# sim.system.getForces()      # WHY GET FORCES ??
sim.system.removeForce(5)
sim.initStorage(filename="traj_chr10_xyz")

# %%
pdb = PDBFile('single_op_chr10_xyz/chromosome_0_block0.pdb')
top = pdb.getTopology()
top_file = 'single_top_xyz.dcd'

# %% [markdown]
# **production simulation**

# %%
with open(top_file, 'wb') as f:
    dcd = DCDFile(f, top, 0.01)
    print('RUNNING SIMULATION', '\n---\n')
    for _ in range(n_blocks):
        sim.runSimBlock(block, increment=True) 
        sim.saveStructure()
        sim.saveStructure(mode='xyz')
        dcd.writeModel(sim.getPositions())
        print('2nd loop', '\n---\n')
# Out:
# RUNNING SIMULATION
# ---
#
# bl=1 pos[1]=[8.0 -4.7 3.0] dr=0.75 t=0.0ps kin=1.52 pot=19.75 Rg=7.929 SPS=1162
# 2nd loop
# ---
#
# bl=2 pos[1]=[8.1 -5.0 2.4] dr=0.74 t=0.0ps kin=1.50 pot=19.74 Rg=7.911 SPS=3561
# 2nd loop
# ---
#
# bl=3 pos[1]=[7.5 -3.6 2.4] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.894 SPS=3573
# 2nd loop
# ---
#
# bl=4 pos[1]=[7.7 -4.1 1.8] dr=0.74 t=0.0ps kin=1.50 pot=19.74 Rg=7.893 SPS=3605
# 2nd loop
# ---
#
# bl=5 pos[1]=[7.9 -5.0 2.0] dr=0.72 t=0.0ps kin=1.48 pot=19.77 Rg=7.906 SPS=3615
# 2nd loop
# ---
#
# bl=6 pos[1]=[7.7 -5.0 2.1] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=7.920 SPS=3555
# 2nd loop
# ---
#
# bl=7 pos[1]=[7.3 -3.5 1.8] dr=0.75 t=0.0ps kin=1.46 pot=19.81 Rg=7.922 SPS=3586
# 2nd loop
# ---
#
# bl=8 pos[1]=[8.7 -3.4 1.7] dr=0.73 t=0.0ps kin=1.48 pot=19.77 Rg=7.926 SPS=3604
# 2nd loop
# ---
#
# bl=9 pos[1]=[8.5 -3.3 1.3] dr=0.74 t=0.0ps kin=1.47 pot=19.78 Rg=7.921 SPS=3609
# 2nd loop
# ---
#
# bl=10 pos[1]=[8.2 -3.5 1.3] dr=0.71 t=0.0ps kin=1.45 pot=19.78 Rg=7.926 SPS=3598
# 2nd loop
# ---
#
# bl=11 pos[1]=[8.1 -4.3 2.4] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=7.915 SPS=3597
# 2nd loop
# ---
#
# bl=12 pos[1]=[7.9 -4.7 3.4] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.906 SPS=3611
# 2nd loop
# ---
#
# bl=13 pos[1]=[7.8 -5.0 4.6] dr=0.73 t=0.0ps kin=1.50 pot=19.74 Rg=7.912 SPS=3514
# 2nd loop
# ---
#
# bl=14 pos[1]=[7.8 -5.5 4.5] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.925 SPS=3553
# 2nd loop
# ---
#
# bl=15 pos[1]=[7.6 -3.7 4.1] dr=0.73 t=0.0ps kin=1.51 pot=19.72 Rg=7.952 SPS=3394
# 2nd loop
# ---
#
# bl=16 pos[1]=[7.0 -3.9 3.7] dr=0.74 t=0.0ps kin=1.50 pot=19.74 Rg=7.980 SPS=3434
# 2nd loop
# ---
#
# bl=17 pos[1]=[7.0 -4.0 4.4] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=8.013 SPS=3406
# 2nd loop
# ---
#
# bl=18 pos[1]=[6.8 -4.2 5.3] dr=0.75 t=0.0ps kin=1.47 pot=19.81 Rg=8.015 SPS=3377
# 2nd loop
# ---
#
# bl=19 pos[1]=[6.5 -4.6 5.0] dr=0.73 t=0.0ps kin=1.51 pot=19.80 Rg=8.010 SPS=3377
# 2nd loop
# ---
#
# bl=20 pos[1]=[7.3 -6.3 4.3] dr=0.75 t=0.0ps kin=1.54 pot=19.77 Rg=7.989 SPS=3450
# 2nd loop
# ---
#
# bl=21 pos[1]=[8.1 -5.5 3.5] dr=0.74 t=0.0ps kin=1.48 pot=19.81 Rg=7.988 SPS=3268
# 2nd loop
# ---
#
# bl=22 pos[1]=[8.0 -6.0 3.9] dr=0.73 t=0.0ps kin=1.48 pot=19.75 Rg=7.992 SPS=3379
# 2nd loop
# ---
#
# bl=23 pos[1]=[8.0 -5.6 4.4] dr=0.73 t=0.0ps kin=1.46 pot=19.79 Rg=7.988 SPS=3452
# 2nd loop
# ---
#
# bl=24 pos[1]=[7.3 -5.1 4.3] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=7.976 SPS=3446
# 2nd loop
# ---
#
# bl=25 pos[1]=[7.5 -4.8 4.7] dr=0.72 t=0.0ps kin=1.47 pot=19.79 Rg=7.963 SPS=3445
# 2nd loop
# ---
#
# bl=26 pos[1]=[8.0 -4.8 3.3] dr=0.74 t=0.0ps kin=1.52 pot=19.77 Rg=7.956 SPS=3485
# 2nd loop
# ---
#
# bl=27 pos[1]=[8.1 -5.5 2.9] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=7.940 SPS=3487
# 2nd loop
# ---
#
# bl=28 pos[1]=[7.8 -4.8 2.4] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=7.917 SPS=3547
# 2nd loop
# ---
#
# bl=29 pos[1]=[8.2 -4.8 2.9] dr=0.72 t=0.0ps kin=1.51 pot=19.73 Rg=7.912 SPS=3498
# 2nd loop
# ---
#
# bl=30 pos[1]=[7.5 -4.5 2.7] dr=0.73 t=0.0ps kin=1.48 pot=19.76 Rg=7.913 SPS=3516
# 2nd loop
# ---
#
# bl=31 pos[1]=[7.7 -4.3 2.5] dr=0.73 t=0.0ps kin=1.49 pot=19.73 Rg=7.913 SPS=3515
# 2nd loop
# ---
#
# bl=32 pos[1]=[8.3 -4.5 3.0] dr=0.74 t=0.0ps kin=1.45 pot=19.74 Rg=7.921 SPS=3389
# 2nd loop
# ---
#
# bl=33 pos[1]=[8.5 -4.9 2.5] dr=0.73 t=0.0ps kin=1.46 pot=19.74 Rg=7.916 SPS=3474
# 2nd loop
# ---
#
# bl=34 pos[1]=[7.2 -4.6 3.0] dr=0.73 t=0.0ps kin=1.47 pot=19.73 Rg=7.914 SPS=3378
# 2nd loop
# ---
#
# bl=35 pos[1]=[6.7 -5.2 2.9] dr=0.73 t=0.0ps kin=1.50 pot=19.73 Rg=7.947 SPS=3399
# 2nd loop
# ---
#
# bl=36 pos[1]=[7.5 -6.0 3.7] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=7.987 SPS=3382
# 2nd loop
# ---
#
# bl=37 pos[1]=[8.4 -6.2 3.9] dr=0.75 t=0.0ps kin=1.49 pot=19.79 Rg=8.005 SPS=3331
# 2nd loop
# ---
#
# bl=38 pos[1]=[8.7 -5.3 2.4] dr=0.72 t=0.0ps kin=1.47 pot=19.76 Rg=8.002 SPS=3398
# 2nd loop
# ---
#
# bl=39 pos[1]=[9.3 -5.0 2.8] dr=0.73 t=0.0ps kin=1.48 pot=19.72 Rg=8.006 SPS=3360
# 2nd loop
# ---
#
# bl=40 pos[1]=[9.6 -5.2 3.6] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=8.013 SPS=3196
# 2nd loop
# ---
#
# bl=41 pos[1]=[9.1 -5.3 4.2] dr=0.73 t=0.0ps kin=1.46 pot=19.81 Rg=8.008 SPS=3362
# 2nd loop
# ---
#
# bl=42 pos[1]=[8.4 -4.5 4.9] dr=0.73 t=0.0ps kin=1.54 pot=19.78 Rg=7.991 SPS=3418
# 2nd loop
# ---
#
# bl=43 pos[1]=[8.2 -4.1 4.3] dr=0.73 t=0.0ps kin=1.49 pot=19.82 Rg=8.001 SPS=3336
# 2nd loop
# ---
#
# bl=44 pos[1]=[8.1 -3.2 4.9] dr=0.74 t=0.0ps kin=1.52 pot=19.77 Rg=8.003 SPS=3308
# 2nd loop
# ---
#
# bl=45 pos[1]=[7.9 -3.9 4.1] dr=0.73 t=0.0ps kin=1.49 pot=19.79 Rg=8.006 SPS=3340
# 2nd loop
# ---
#
# bl=46 pos[1]=[7.9 -4.1 4.7] dr=0.73 t=0.0ps kin=1.50 pot=19.82 Rg=8.019 SPS=3442
# 2nd loop
# ---
#
# bl=47 pos[1]=[7.6 -3.9 4.7] dr=0.76 t=0.0ps kin=1.54 pot=19.78 Rg=8.022 SPS=3466
# 2nd loop
# ---
#
# bl=48 pos[1]=[7.3 -3.9 4.3] dr=0.74 t=0.0ps kin=1.50 pot=19.78 Rg=8.022 SPS=3412
# 2nd loop
# ---
#
# bl=49 pos[1]=[7.5 -4.3 4.8] dr=0.73 t=0.0ps kin=1.49 pot=19.79 Rg=8.021 SPS=3441
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.23414758  2.12381876 -2.11268759]   Rg =  8.020883
#      median bond size is  0.9619148467654197
#      three shortest/longest (<10)/ bonds are  [0.86996637 0.87318041 0.87641201]    [1.08137399 1.08137619 1.08488674]
#      95 percentile of distance to center is:    11.533121288166
#      density of closest 95% monomers is:    0.40094435493573893
#      density of the core monomers is:    0.7779851101391945
#      min/median/mean/max coordinates are:
#      x: -13.24, -0.05, -0.23, 11.85
#      y: -8.69, 1.98, 2.12, 13.60
#      z: -11.69, -2.02, -2.11, 7.65
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4942884368546823 should be: 1.5
#      fastest particles are (in kT):  [ 7.70566781  7.82256059  8.64440577  8.84189089 10.15177015]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.787882847068584
# bl=50 pos[1]=[7.7 -4.6 4.3] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=8.029 SPS=3401
# 2nd loop
# ---
#
# bl=51 pos[1]=[7.9 -4.4 5.0] dr=0.75 t=0.0ps kin=1.46 pot=19.81 Rg=8.029 SPS=3321
# 2nd loop
# ---
#
# bl=52 pos[1]=[7.0 -4.5 5.2] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=8.049 SPS=3457
# 2nd loop
# ---
#
# bl=53 pos[1]=[6.3 -4.1 4.4] dr=0.75 t=0.0ps kin=1.51 pot=19.79 Rg=8.065 SPS=3447
# 2nd loop
# ---
#
# bl=54 pos[1]=[7.3 -4.4 4.9] dr=0.74 t=0.0ps kin=1.46 pot=19.83 Rg=8.075 SPS=3481
# 2nd loop
# ---
#
# bl=55 pos[1]=[7.2 -5.1 4.4] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=8.081 SPS=3426
# 2nd loop
# ---
#
# bl=56 pos[1]=[7.8 -5.4 5.0] dr=0.72 t=0.0ps kin=1.49 pot=19.82 Rg=8.056 SPS=3497
# 2nd loop
# ---
#
# bl=57 pos[1]=[7.5 -5.1 5.1] dr=0.72 t=0.0ps kin=1.48 pot=19.76 Rg=8.074 SPS=3439
# 2nd loop
# ---
#
# bl=58 pos[1]=[8.0 -4.9 4.1] dr=0.72 t=0.0ps kin=1.45 pot=19.76 Rg=8.105 SPS=3412
# 2nd loop
# ---
#
# bl=59 pos[1]=[7.9 -3.7 4.6] dr=0.72 t=0.0ps kin=1.48 pot=19.77 Rg=8.137 SPS=3507
# 2nd loop
# ---
#
# bl=60 pos[1]=[8.3 -3.4 3.2] dr=0.72 t=0.0ps kin=1.49 pot=19.77 Rg=8.135 SPS=3300
# 2nd loop
# ---
#
# bl=61 pos[1]=[8.2 -2.9 3.8] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=8.118 SPS=3525
# 2nd loop
# ---
#
# bl=62 pos[1]=[8.5 -2.5 3.3] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=8.089 SPS=3497
# 2nd loop
# ---
#
# bl=63 pos[1]=[9.0 -3.3 2.7] dr=0.73 t=0.0ps kin=1.53 pot=19.77 Rg=8.040 SPS=3309
# 2nd loop
# ---
#
# bl=64 pos[1]=[9.8 -3.5 1.9] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=8.016 SPS=3365
# 2nd loop
# ---
#
# bl=65 pos[1]=[9.6 -4.0 2.0] dr=0.72 t=0.0ps kin=1.48 pot=19.79 Rg=8.035 SPS=3341
# 2nd loop
# ---
#
# bl=66 pos[1]=[9.4 -4.6 2.1] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=8.044 SPS=3260
# 2nd loop
# ---
#
# bl=67 pos[1]=[9.4 -4.0 2.1] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=8.052 SPS=3341
# 2nd loop
# ---
#
# bl=68 pos[1]=[9.0 -4.6 3.3] dr=0.73 t=0.0ps kin=1.46 pot=19.78 Rg=8.042 SPS=3371
# 2nd loop
# ---
#
# bl=69 pos[1]=[7.9 -5.2 3.5] dr=0.72 t=0.0ps kin=1.48 pot=19.78 Rg=8.024 SPS=3366
# 2nd loop
# ---
#
# bl=70 pos[1]=[7.2 -4.6 3.2] dr=0.74 t=0.0ps kin=1.51 pot=19.81 Rg=8.018 SPS=3362
# 2nd loop
# ---
#
# bl=71 pos[1]=[8.7 -5.0 3.1] dr=0.73 t=0.0ps kin=1.49 pot=19.80 Rg=8.024 SPS=3434
# 2nd loop
# ---
#
# bl=72 pos[1]=[9.9 -4.1 4.3] dr=0.74 t=0.0ps kin=1.52 pot=19.76 Rg=8.019 SPS=3446
# 2nd loop
# ---
#
# bl=73 pos[1]=[8.6 -3.8 6.0] dr=0.74 t=0.0ps kin=1.53 pot=19.74 Rg=8.030 SPS=3396
# 2nd loop
# ---
#
# bl=74 pos[1]=[8.2 -4.3 6.4] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=8.058 SPS=3410
# 2nd loop
# ---
#
# bl=75 pos[1]=[8.2 -4.2 6.3] dr=0.73 t=0.0ps kin=1.53 pot=19.78 Rg=8.066 SPS=3407
# 2nd loop
# ---
#
# bl=76 pos[1]=[8.5 -4.9 5.4] dr=0.73 t=0.0ps kin=1.52 pot=19.80 Rg=8.072 SPS=3454
# 2nd loop
# ---
#
# bl=77 pos[1]=[7.3 -5.2 3.3] dr=0.75 t=0.0ps kin=1.52 pot=19.79 Rg=8.070 SPS=3433
# 2nd loop
# ---
#
# bl=78 pos[1]=[5.4 -5.7 3.8] dr=0.74 t=0.0ps kin=1.50 pot=19.80 Rg=8.048 SPS=3431
# 2nd loop
# ---
#
# bl=79 pos[1]=[6.0 -5.6 3.5] dr=0.74 t=0.0ps kin=1.54 pot=19.78 Rg=8.040 SPS=3556
# 2nd loop
# ---
#
# bl=80 pos[1]=[7.7 -5.1 4.4] dr=0.73 t=0.0ps kin=1.48 pot=19.84 Rg=8.050 SPS=3379
# 2nd loop
# ---
#
# bl=81 pos[1]=[8.3 -4.0 4.9] dr=0.75 t=0.0ps kin=1.50 pot=19.78 Rg=8.046 SPS=3490
# 2nd loop
# ---
#
# bl=82 pos[1]=[7.9 -4.1 4.0] dr=0.75 t=0.0ps kin=1.51 pot=19.80 Rg=8.057 SPS=3484
# 2nd loop
# ---
#
# bl=83 pos[1]=[6.9 -4.5 4.7] dr=0.73 t=0.0ps kin=1.48 pot=19.80 Rg=8.071 SPS=3475
# 2nd loop
# ---
#
# bl=84 pos[1]=[6.0 -5.2 5.1] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=8.078 SPS=3480
# 2nd loop
# ---
#
# bl=85 pos[1]=[6.2 -5.0 5.2] dr=0.74 t=0.0ps kin=1.50 pot=19.80 Rg=8.057 SPS=3487
# 2nd loop
# ---
#
# bl=86 pos[1]=[7.0 -5.6 3.8] dr=0.74 t=0.0ps kin=1.50 pot=19.80 Rg=8.035 SPS=3432
# 2nd loop
# ---
#
# bl=87 pos[1]=[6.6 -6.2 3.3] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=8.020 SPS=3469
# 2nd loop
# ---
#
# bl=88 pos[1]=[6.1 -6.0 3.4] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=8.030 SPS=3483
# 2nd loop
# ---
#
# bl=89 pos[1]=[6.1 -6.7 3.2] dr=0.74 t=0.0ps kin=1.47 pot=19.78 Rg=8.057 SPS=3341
# 2nd loop
# ---
#
# bl=90 pos[1]=[5.5 -6.6 3.4] dr=0.73 t=0.0ps kin=1.47 pot=19.78 Rg=8.090 SPS=3364
# 2nd loop
# ---
#
# bl=91 pos[1]=[4.7 -6.2 3.3] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=8.099 SPS=3327
# 2nd loop
# ---
#
# bl=92 pos[1]=[4.6 -6.2 3.1] dr=0.73 t=0.0ps kin=1.46 pot=19.76 Rg=8.092 SPS=3430
# 2nd loop
# ---
#
# bl=93 pos[1]=[4.3 -6.2 2.8] dr=0.74 t=0.0ps kin=1.52 pot=19.73 Rg=8.097 SPS=3414
# 2nd loop
# ---
#
# bl=94 pos[1]=[4.0 -7.1 3.2] dr=0.73 t=0.0ps kin=1.47 pot=19.79 Rg=8.107 SPS=3384
# 2nd loop
# ---
#
# bl=95 pos[1]=[4.0 -6.3 4.0] dr=0.74 t=0.0ps kin=1.48 pot=19.76 Rg=8.121 SPS=3304
# 2nd loop
# ---
#
# bl=96 pos[1]=[4.1 -6.0 3.8] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=8.115 SPS=3324
# 2nd loop
# ---
#
# bl=97 pos[1]=[3.7 -5.6 2.6] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=8.102 SPS=3335
# 2nd loop
# ---
#
# bl=98 pos[1]=[3.2 -5.8 2.7] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=8.108 SPS=2003
# 2nd loop
# ---
#
# bl=99 pos[1]=[2.6 -6.5 2.9] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=8.123 SPS=2093
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.50063955  1.71233794 -2.17735523]   Rg =  8.122615
#      median bond size is  0.9644902220849234
#      three shortest/longest (<10)/ bonds are  [0.86847479 0.87991822 0.88084023]    [1.07848009 1.07975557 1.10440877]
#      95 percentile of distance to center is:    11.801197376843053
#      density of closest 95% monomers is:    0.37423677245794534
#      density of the core monomers is:    0.7648800870339547
#      min/median/mean/max coordinates are:
#      x: -14.29, -0.54, -0.50, 11.78
#      y: -8.39, 1.83, 1.71, 10.99
#      z: -12.83, -2.09, -2.18, 8.70
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4874059241824058 should be: 1.5
#      fastest particles are (in kT):  [7.48317775 7.4875939  7.65044524 8.27053439 9.20271832]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.779697294432154
# bl=100 pos[1]=[3.3 -7.1 1.8] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=8.140 SPS=1975
# 2nd loop
# ---
#
# bl=101 pos[1]=[3.5 -6.2 1.9] dr=0.75 t=0.0ps kin=1.51 pot=19.81 Rg=8.153 SPS=1911
# 2nd loop
# ---
#
# bl=102 pos[1]=[3.4 -6.1 3.4] dr=0.76 t=0.0ps kin=1.52 pot=19.83 Rg=8.149 SPS=1963
# 2nd loop
# ---
#
# bl=103 pos[1]=[3.7 -6.6 3.2] dr=0.74 t=0.0ps kin=1.48 pot=19.85 Rg=8.161 SPS=2080
# 2nd loop
# ---
#
# bl=104 pos[1]=[2.6 -7.1 3.0] dr=0.74 t=0.0ps kin=1.52 pot=19.81 Rg=8.171 SPS=2055
# 2nd loop
# ---
#
# bl=105 pos[1]=[2.1 -6.1 4.1] dr=0.75 t=0.0ps kin=1.50 pot=19.80 Rg=8.169 SPS=1894
# 2nd loop
# ---
#
# bl=106 pos[1]=[2.3 -5.1 5.2] dr=0.75 t=0.0ps kin=1.53 pot=19.80 Rg=8.166 SPS=1796
# 2nd loop
# ---
#
# bl=107 pos[1]=[2.8 -5.2 4.9] dr=0.75 t=0.0ps kin=1.52 pot=19.78 Rg=8.167 SPS=1828
# 2nd loop
# ---
#
# bl=108 pos[1]=[3.7 -4.3 4.5] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=8.176 SPS=1785
# 2nd loop
# ---
#
# bl=109 pos[1]=[3.3 -3.2 4.3] dr=0.74 t=0.0ps kin=1.46 pot=19.81 Rg=8.208 SPS=1873
# 2nd loop
# ---
#
# bl=110 pos[1]=[3.8 -3.2 4.3] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=8.195 SPS=1759
# 2nd loop
# ---
#
# bl=111 pos[1]=[4.3 -3.4 4.1] dr=0.73 t=0.0ps kin=1.48 pot=19.80 Rg=8.162 SPS=1740
# 2nd loop
# ---
#
# bl=112 pos[1]=[4.8 -3.9 4.3] dr=0.72 t=0.0ps kin=1.48 pot=19.81 Rg=8.137 SPS=1759
# 2nd loop
# ---
#
# bl=113 pos[1]=[5.5 -4.0 4.2] dr=0.73 t=0.0ps kin=1.53 pot=19.74 Rg=8.115 SPS=1728
# 2nd loop
# ---
#
# bl=114 pos[1]=[5.6 -3.7 3.5] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=8.095 SPS=1717
# 2nd loop
# ---
#
# bl=115 pos[1]=[7.2 -4.6 3.0] dr=0.74 t=0.0ps kin=1.46 pot=19.77 Rg=8.086 SPS=1726
# 2nd loop
# ---
#
# bl=116 pos[1]=[6.7 -4.7 3.3] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=8.080 SPS=1744
# 2nd loop
# ---
#
# bl=117 pos[1]=[5.9 -4.2 2.4] dr=0.74 t=0.0ps kin=1.49 pot=19.76 Rg=8.081 SPS=1732
# 2nd loop
# ---
#
# bl=118 pos[1]=[7.3 -4.2 2.4] dr=0.73 t=0.0ps kin=1.46 pot=19.78 Rg=8.071 SPS=1768
# 2nd loop
# ---
#
# bl=119 pos[1]=[8.1 -4.4 2.2] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=8.062 SPS=1724
# 2nd loop
# ---
#
# bl=120 pos[1]=[7.9 -3.9 3.0] dr=0.72 t=0.0ps kin=1.48 pot=19.74 Rg=8.065 SPS=1751
# 2nd loop
# ---
#
# bl=121 pos[1]=[8.1 -3.1 3.5] dr=0.73 t=0.0ps kin=1.45 pot=19.74 Rg=8.089 SPS=1737
# 2nd loop
# ---
#
# bl=122 pos[1]=[6.9 -3.1 3.7] dr=0.72 t=0.0ps kin=1.40 pot=19.79 Rg=8.110 SPS=1742
# 2nd loop
# ---
#
# bl=123 pos[1]=[6.5 -2.9 3.7] dr=0.73 t=0.0ps kin=1.47 pot=19.77 Rg=8.128 SPS=1767
# 2nd loop
# ---
#
# bl=124 pos[1]=[6.6 -2.7 3.1] dr=0.74 t=0.0ps kin=1.47 pot=19.80 Rg=8.129 SPS=1734
# 2nd loop
# ---
#
# bl=125 pos[1]=[6.2 -2.7 3.2] dr=0.74 t=0.0ps kin=1.51 pot=19.78 Rg=8.105 SPS=1717
# 2nd loop
# ---
#
# bl=126 pos[1]=[5.8 -2.8 3.7] dr=0.74 t=0.0ps kin=1.46 pot=19.77 Rg=8.097 SPS=1735
# 2nd loop
# ---
#
# bl=127 pos[1]=[5.3 -2.2 3.4] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=8.092 SPS=1772
# 2nd loop
# ---
#
# bl=128 pos[1]=[5.0 -2.1 2.6] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=8.088 SPS=1747
# 2nd loop
# ---
#
# bl=129 pos[1]=[4.6 -1.7 2.5] dr=0.75 t=0.0ps kin=1.49 pot=19.76 Rg=8.081 SPS=1801
# 2nd loop
# ---
#
# bl=130 pos[1]=[4.6 -0.8 2.6] dr=0.73 t=0.0ps kin=1.51 pot=19.75 Rg=8.066 SPS=2503
# 2nd loop
# ---
#
# bl=131 pos[1]=[5.1 -0.8 2.8] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=8.055 SPS=2516
# 2nd loop
# ---
#
# bl=132 pos[1]=[4.9 -1.0 3.0] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=8.056 SPS=2896
# 2nd loop
# ---
#
# bl=133 pos[1]=[4.7 -1.5 2.8] dr=0.73 t=0.0ps kin=1.52 pot=19.79 Rg=8.045 SPS=2961
# 2nd loop
# ---
#
# bl=134 pos[1]=[4.9 -1.8 3.2] dr=0.73 t=0.0ps kin=1.51 pot=19.78 Rg=8.041 SPS=2929
# 2nd loop
# ---
#
# bl=135 pos[1]=[5.3 -2.3 2.7] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=8.024 SPS=3130
# 2nd loop
# ---
#
# bl=136 pos[1]=[4.8 -2.3 2.6] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=8.029 SPS=3084
# 2nd loop
# ---
#
# bl=137 pos[1]=[4.6 -2.7 3.5] dr=0.72 t=0.0ps kin=1.50 pot=19.76 Rg=8.028 SPS=3074
# 2nd loop
# ---
#
# bl=138 pos[1]=[4.9 -2.3 3.7] dr=0.74 t=0.0ps kin=1.47 pot=19.79 Rg=8.039 SPS=3070
# 2nd loop
# ---
#
# bl=139 pos[1]=[5.1 -1.9 3.8] dr=0.72 t=0.0ps kin=1.46 pot=19.79 Rg=8.047 SPS=3004
# 2nd loop
# ---
#
# bl=140 pos[1]=[5.4 -1.7 4.1] dr=0.73 t=0.0ps kin=1.48 pot=19.80 Rg=8.028 SPS=3048
# 2nd loop
# ---
#
# bl=141 pos[1]=[5.6 -1.6 4.3] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=8.001 SPS=2877
# 2nd loop
# ---
#
# bl=142 pos[1]=[5.4 -1.1 3.6] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=7.973 SPS=3156
# 2nd loop
# ---
#
# bl=143 pos[1]=[5.5 -1.2 2.8] dr=0.74 t=0.0ps kin=1.47 pot=19.79 Rg=7.958 SPS=3169
# 2nd loop
# ---
#
# bl=144 pos[1]=[5.5 -1.5 2.9] dr=0.72 t=0.0ps kin=1.48 pot=19.80 Rg=7.943 SPS=3080
# 2nd loop
# ---
#
# bl=145 pos[1]=[4.6 -1.3 3.5] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.925 SPS=3177
# 2nd loop
# ---
#
# bl=146 pos[1]=[5.3 -1.8 2.9] dr=0.73 t=0.0ps kin=1.53 pot=19.75 Rg=7.908 SPS=3074
# 2nd loop
# ---
#
# bl=147 pos[1]=[5.1 -1.7 3.3] dr=0.72 t=0.0ps kin=1.47 pot=19.80 Rg=7.904 SPS=3192
# 2nd loop
# ---
#
# bl=148 pos[1]=[5.5 -1.5 3.3] dr=0.72 t=0.0ps kin=1.49 pot=19.76 Rg=7.887 SPS=3120
# 2nd loop
# ---
#
# bl=149 pos[1]=[5.3 -2.1 2.5] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=7.889 SPS=3147
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.00813885  1.57693787 -2.28175736]   Rg =  7.888549
#      median bond size is  0.9640585929341696
#      three shortest/longest (<10)/ bonds are  [0.87520705 0.8764097  0.87976177]    [1.08183751 1.09514931 1.09626309]
#      95 percentile of distance to center is:    11.163822220524374
#      density of closest 95% monomers is:    0.4420648106553641
#      density of the core monomers is:    0.6941675253589642
#      min/median/mean/max coordinates are:
#      x: -12.25, -0.09, -0.01, 12.17
#      y: -8.85, 1.55, 1.58, 12.40
#      z: -12.52, -2.28, -2.28, 7.28
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4917763756571774 should be: 1.5
#      fastest particles are (in kT):  [7.33132861 7.33960591 8.53829639 8.70681388 9.22420761]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.747004056047196
# bl=150 pos[1]=[5.3 -1.9 2.4] dr=0.73 t=0.0ps kin=1.46 pot=19.75 Rg=7.891 SPS=3057
# 2nd loop
# ---
#
# bl=151 pos[1]=[5.0 -1.5 3.2] dr=0.70 t=0.0ps kin=1.49 pot=19.72 Rg=7.904 SPS=3106
# 2nd loop
# ---
#
# bl=152 pos[1]=[4.8 -1.4 3.5] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=7.912 SPS=3144
# 2nd loop
# ---
#
# bl=153 pos[1]=[4.6 -1.3 3.9] dr=0.74 t=0.0ps kin=1.51 pot=19.72 Rg=7.920 SPS=3052
# 2nd loop
# ---
#
# bl=154 pos[1]=[4.3 -1.2 4.0] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.914 SPS=3033
# 2nd loop
# ---
#
# bl=155 pos[1]=[4.3 -2.0 3.7] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=7.908 SPS=3102
# 2nd loop
# ---
#
# bl=156 pos[1]=[5.4 -2.1 3.4] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=7.912 SPS=3012
# 2nd loop
# ---
#
# bl=157 pos[1]=[5.9 -2.1 3.0] dr=0.75 t=0.0ps kin=1.55 pot=19.77 Rg=7.918 SPS=3141
# 2nd loop
# ---
#
# bl=158 pos[1]=[6.6 -2.6 2.6] dr=0.74 t=0.0ps kin=1.49 pot=19.81 Rg=7.924 SPS=3073
# 2nd loop
# ---
#
# bl=159 pos[1]=[6.6 -1.8 2.8] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=7.934 SPS=3153
# 2nd loop
# ---
#
# bl=160 pos[1]=[7.0 -1.5 3.1] dr=0.74 t=0.0ps kin=1.49 pot=19.79 Rg=7.954 SPS=3084
# 2nd loop
# ---
#
# bl=161 pos[1]=[7.4 -2.0 3.7] dr=0.74 t=0.0ps kin=1.48 pot=19.80 Rg=7.968 SPS=3055
# 2nd loop
# ---
#
# bl=162 pos[1]=[8.5 -2.1 3.6] dr=0.74 t=0.0ps kin=1.48 pot=19.78 Rg=7.955 SPS=2979
# 2nd loop
# ---
#
# bl=163 pos[1]=[9.0 -2.4 4.0] dr=0.74 t=0.0ps kin=1.50 pot=19.79 Rg=7.937 SPS=3380
# 2nd loop
# ---
#
# bl=164 pos[1]=[9.2 -1.9 4.5] dr=0.73 t=0.0ps kin=1.51 pot=19.79 Rg=7.948 SPS=3362
# 2nd loop
# ---
#
# bl=165 pos[1]=[8.5 -1.9 4.5] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.957 SPS=3357
# 2nd loop
# ---
#
# bl=166 pos[1]=[9.2 -1.5 3.6] dr=0.75 t=0.0ps kin=1.50 pot=19.79 Rg=7.980 SPS=3291
# 2nd loop
# ---
#
# bl=167 pos[1]=[8.5 -1.9 5.2] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.989 SPS=3302
# 2nd loop
# ---
#
# bl=168 pos[1]=[9.1 -1.7 4.4] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=7.974 SPS=3193
# 2nd loop
# ---
#
# bl=169 pos[1]=[9.4 -2.1 4.5] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.946 SPS=3309
# 2nd loop
# ---
#
# bl=170 pos[1]=[9.7 -1.7 3.7] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=7.926 SPS=3387
# 2nd loop
# ---
#
# bl=171 pos[1]=[9.9 -1.7 3.1] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=7.924 SPS=3365
# 2nd loop
# ---
#
# bl=172 pos[1]=[10.6 -2.5 4.4] dr=0.74 t=0.0ps kin=1.50 pot=19.73 Rg=7.918 SPS=3302
# 2nd loop
# ---
#
# bl=173 pos[1]=[10.1 -3.3 5.1] dr=0.73 t=0.0ps kin=1.50 pot=19.72 Rg=7.914 SPS=3329
# 2nd loop
# ---
#
# bl=174 pos[1]=[10.4 -3.7 4.9] dr=0.73 t=0.0ps kin=1.46 pot=19.75 Rg=7.902 SPS=3317
# 2nd loop
# ---
#
# bl=175 pos[1]=[10.4 -3.7 4.0] dr=0.74 t=0.0ps kin=1.49 pot=19.75 Rg=7.889 SPS=3361
# 2nd loop
# ---
#
# bl=176 pos[1]=[10.8 -3.3 5.0] dr=0.73 t=0.0ps kin=1.47 pot=19.80 Rg=7.861 SPS=3268
# 2nd loop
# ---
#
# bl=177 pos[1]=[9.3 -2.7 5.3] dr=0.72 t=0.0ps kin=1.50 pot=19.75 Rg=7.846 SPS=3375
# 2nd loop
# ---
#
# bl=178 pos[1]=[9.1 -3.0 6.0] dr=0.73 t=0.0ps kin=1.51 pot=19.75 Rg=7.853 SPS=3480
# 2nd loop
# ---
#
# bl=179 pos[1]=[8.7 -4.0 7.4] dr=0.72 t=0.0ps kin=1.48 pot=19.77 Rg=7.871 SPS=3420
# 2nd loop
# ---
#
# bl=180 pos[1]=[7.4 -5.0 7.8] dr=0.75 t=0.0ps kin=1.49 pot=19.77 Rg=7.906 SPS=3422
# 2nd loop
# ---
#
# bl=181 pos[1]=[6.8 -4.6 8.5] dr=0.74 t=0.0ps kin=1.51 pot=19.80 Rg=7.915 SPS=3496
# 2nd loop
# ---
#
# bl=182 pos[1]=[7.6 -4.0 8.5] dr=0.74 t=0.0ps kin=1.49 pot=19.77 Rg=7.924 SPS=3349
# 2nd loop
# ---
#
# bl=183 pos[1]=[8.1 -3.2 7.6] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=7.912 SPS=3423
# 2nd loop
# ---
#
# bl=184 pos[1]=[7.9 -3.9 7.0] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.888 SPS=3411
# 2nd loop
# ---
#
# bl=185 pos[1]=[6.8 -5.3 4.8] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=7.858 SPS=3489
# 2nd loop
# ---
#
# bl=186 pos[1]=[6.8 -5.0 3.9] dr=0.73 t=0.0ps kin=1.53 pot=19.73 Rg=7.845 SPS=3563
# 2nd loop
# ---
#
# bl=187 pos[1]=[6.4 -6.7 3.2] dr=0.72 t=0.0ps kin=1.48 pot=19.78 Rg=7.873 SPS=3482
# 2nd loop
# ---
#
# bl=188 pos[1]=[6.2 -6.9 4.9] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.904 SPS=3542
# 2nd loop
# ---
#
# bl=189 pos[1]=[6.2 -4.8 5.7] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.934 SPS=3407
# 2nd loop
# ---
#
# bl=190 pos[1]=[6.0 -4.4 5.4] dr=0.72 t=0.0ps kin=1.47 pot=19.76 Rg=7.958 SPS=3471
# 2nd loop
# ---
#
# bl=191 pos[1]=[6.3 -5.2 4.9] dr=0.73 t=0.0ps kin=1.44 pot=19.74 Rg=7.960 SPS=3418
# 2nd loop
# ---
#
# bl=192 pos[1]=[6.8 -5.2 4.0] dr=0.74 t=0.0ps kin=1.48 pot=19.73 Rg=7.942 SPS=3439
# 2nd loop
# ---
#
# bl=193 pos[1]=[6.4 -5.6 3.7] dr=0.73 t=0.0ps kin=1.48 pot=19.75 Rg=7.935 SPS=3296
# 2nd loop
# ---
#
# bl=194 pos[1]=[6.6 -5.6 3.4] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=7.942 SPS=3241
# 2nd loop
# ---
#
# bl=195 pos[1]=[6.5 -5.3 3.2] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.971 SPS=3327
# 2nd loop
# ---
#
# bl=196 pos[1]=[6.4 -5.5 4.1] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.966 SPS=3279
# 2nd loop
# ---
#
# bl=197 pos[1]=[8.2 -6.5 4.3] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.940 SPS=3249
# 2nd loop
# ---
#
# bl=198 pos[1]=[8.3 -6.0 3.8] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=7.929 SPS=3378
# 2nd loop
# ---
#
# bl=199 pos[1]=[6.9 -6.3 2.9] dr=0.74 t=0.0ps kin=1.52 pot=19.76 Rg=7.915 SPS=3423
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.08311812  0.97167672 -2.31830184]   Rg =  7.915497
#      median bond size is  0.9652055861326645
#      three shortest/longest (<10)/ bonds are  [0.87928852 0.87947931 0.88237086]    [1.09777223 1.11413483 1.1312229 ]
#      95 percentile of distance to center is:    11.118634666142702
#      density of closest 95% monomers is:    0.4474765691784729
#      density of the core monomers is:    0.7162506663178477
#      min/median/mean/max coordinates are:
#      x: -12.81, -0.06, 0.08, 11.77
#      y: -9.25, 0.80, 0.97, 11.85
#      z: -12.82, -2.26, -2.32, 7.52
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5180200587634083 should be: 1.5
#      fastest particles are (in kT):  [6.73308509 6.77970447 6.86368703 7.67769434 7.89818659]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.75901231793879
# bl=200 pos[1]=[7.3 -6.4 2.7] dr=0.74 t=0.0ps kin=1.52 pot=19.75 Rg=7.917 SPS=3480
# 2nd loop
# ---
#
# bl=201 pos[1]=[7.7 -6.0 4.3] dr=0.74 t=0.0ps kin=1.48 pot=19.74 Rg=7.944 SPS=3389
# 2nd loop
# ---
#
# bl=202 pos[1]=[7.0 -4.0 5.1] dr=0.73 t=0.0ps kin=1.48 pot=19.74 Rg=7.980 SPS=3430
# 2nd loop
# ---
#
# bl=203 pos[1]=[7.9 -4.8 5.2] dr=0.74 t=0.0ps kin=1.49 pot=19.74 Rg=7.973 SPS=3419
# 2nd loop
# ---
#
# bl=204 pos[1]=[8.8 -5.1 4.3] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.976 SPS=3487
# 2nd loop
# ---
#
# bl=205 pos[1]=[8.5 -5.8 5.0] dr=0.73 t=0.0ps kin=1.50 pot=19.78 Rg=7.972 SPS=3343
# 2nd loop
# ---
#
# bl=206 pos[1]=[8.8 -5.4 5.3] dr=0.72 t=0.0ps kin=1.49 pot=19.76 Rg=7.957 SPS=3442
# 2nd loop
# ---
#
# bl=207 pos[1]=[8.5 -5.8 5.6] dr=0.73 t=0.0ps kin=1.52 pot=19.75 Rg=7.919 SPS=3390
# 2nd loop
# ---
#
# bl=208 pos[1]=[7.8 -5.6 5.3] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=7.913 SPS=3380
# 2nd loop
# ---
#
# bl=209 pos[1]=[7.6 -4.6 5.3] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=7.929 SPS=3368
# 2nd loop
# ---
#
# bl=210 pos[1]=[7.6 -3.7 5.5] dr=0.72 t=0.0ps kin=1.47 pot=19.78 Rg=7.957 SPS=3371
# 2nd loop
# ---
#
# bl=211 pos[1]=[7.7 -3.9 5.3] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=7.973 SPS=3313
# 2nd loop
# ---
#
# bl=212 pos[1]=[7.9 -5.1 5.0] dr=0.74 t=0.0ps kin=1.47 pot=19.77 Rg=7.979 SPS=3297
# 2nd loop
# ---
#
# bl=213 pos[1]=[8.4 -6.1 4.1] dr=0.73 t=0.0ps kin=1.46 pot=19.76 Rg=7.989 SPS=3320
# 2nd loop
# ---
#
# bl=214 pos[1]=[8.1 -6.5 4.2] dr=0.73 t=0.0ps kin=1.44 pot=19.75 Rg=7.980 SPS=3263
# 2nd loop
# ---
#
# bl=215 pos[1]=[7.8 -6.1 3.3] dr=0.72 t=0.0ps kin=1.49 pot=19.71 Rg=7.950 SPS=3307
# 2nd loop
# ---
#
# bl=216 pos[1]=[7.4 -6.0 2.6] dr=0.72 t=0.0ps kin=1.50 pot=19.72 Rg=7.925 SPS=3223
# 2nd loop
# ---
#
# bl=217 pos[1]=[7.9 -5.5 2.8] dr=0.72 t=0.0ps kin=1.48 pot=19.75 Rg=7.922 SPS=3347
# 2nd loop
# ---
#
# bl=218 pos[1]=[8.8 -4.7 2.9] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=7.937 SPS=3353
# 2nd loop
# ---
#
# bl=219 pos[1]=[8.7 -4.3 2.5] dr=0.74 t=0.0ps kin=1.53 pot=19.75 Rg=7.948 SPS=3199
# 2nd loop
# ---
#
# bl=220 pos[1]=[8.8 -4.6 2.2] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=7.956 SPS=3247
# 2nd loop
# ---
#
# bl=221 pos[1]=[9.3 -4.9 2.1] dr=0.74 t=0.0ps kin=1.53 pot=19.75 Rg=7.972 SPS=3303
# 2nd loop
# ---
#
# bl=222 pos[1]=[8.9 -4.6 1.0] dr=0.73 t=0.0ps kin=1.54 pot=19.76 Rg=7.952 SPS=3367
# 2nd loop
# ---
#
# bl=223 pos[1]=[8.9 -4.2 1.5] dr=0.74 t=0.0ps kin=1.50 pot=19.78 Rg=7.908 SPS=3374
# 2nd loop
# ---
#
# bl=224 pos[1]=[8.7 -4.8 1.9] dr=0.75 t=0.0ps kin=1.54 pot=19.75 Rg=7.877 SPS=3331
# 2nd loop
# ---
#
# bl=225 pos[1]=[9.4 -4.9 2.2] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.880 SPS=3405
# 2nd loop
# ---
#
# bl=226 pos[1]=[9.0 -4.5 2.0] dr=0.72 t=0.0ps kin=1.48 pot=19.76 Rg=7.886 SPS=3235
# 2nd loop
# ---
#
# bl=227 pos[1]=[9.9 -4.5 2.6] dr=0.74 t=0.0ps kin=1.49 pot=19.73 Rg=7.897 SPS=3450
# 2nd loop
# ---
#
# bl=228 pos[1]=[9.9 -3.5 2.9] dr=0.72 t=0.0ps kin=1.50 pot=19.75 Rg=7.918 SPS=2977
# 2nd loop
# ---
#
# bl=229 pos[1]=[9.8 -4.0 1.9] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.913 SPS=3291
# 2nd loop
# ---
#
# bl=230 pos[1]=[9.9 -5.3 1.7] dr=0.74 t=0.0ps kin=1.52 pot=19.78 Rg=7.905 SPS=3383
# 2nd loop
# ---
#
# bl=231 pos[1]=[9.3 -6.2 2.2] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.878 SPS=3505
# 2nd loop
# ---
#
# bl=232 pos[1]=[9.2 -7.1 2.7] dr=0.74 t=0.0ps kin=1.48 pot=19.81 Rg=7.849 SPS=3419
# 2nd loop
# ---
#
# bl=233 pos[1]=[9.6 -6.9 3.6] dr=0.72 t=0.0ps kin=1.51 pot=19.72 Rg=7.846 SPS=3431
# 2nd loop
# ---
#
# bl=234 pos[1]=[9.7 -6.2 3.1] dr=0.74 t=0.0ps kin=1.54 pot=19.70 Rg=7.869 SPS=3455
# 2nd loop
# ---
#
# bl=235 pos[1]=[9.0 -6.5 3.0] dr=0.74 t=0.0ps kin=1.48 pot=19.76 Rg=7.883 SPS=3492
# 2nd loop
# ---
#
# bl=236 pos[1]=[8.3 -5.0 3.2] dr=0.73 t=0.0ps kin=1.48 pot=19.73 Rg=7.902 SPS=3436
# 2nd loop
# ---
#
# bl=237 pos[1]=[7.5 -3.6 2.8] dr=0.74 t=0.0ps kin=1.46 pot=19.75 Rg=7.894 SPS=3212
# 2nd loop
# ---
#
# bl=238 pos[1]=[7.9 -4.2 1.5] dr=0.73 t=0.0ps kin=1.48 pot=19.74 Rg=7.858 SPS=3238
# 2nd loop
# ---
#
# bl=239 pos[1]=[7.9 -4.3 1.7] dr=0.73 t=0.0ps kin=1.47 pot=19.75 Rg=7.828 SPS=3011
# 2nd loop
# ---
#
# bl=240 pos[1]=[7.9 -2.8 1.2] dr=0.72 t=0.0ps kin=1.49 pot=19.73 Rg=7.816 SPS=2868
# 2nd loop
# ---
#
# bl=241 pos[1]=[7.5 -2.8 1.4] dr=0.74 t=0.0ps kin=1.49 pot=19.72 Rg=7.821 SPS=3019
# 2nd loop
# ---
#
# bl=242 pos[1]=[7.4 -2.5 1.7] dr=0.73 t=0.0ps kin=1.46 pot=19.75 Rg=7.819 SPS=2984
# 2nd loop
# ---
#
# bl=243 pos[1]=[8.2 -3.0 2.0] dr=0.73 t=0.0ps kin=1.46 pot=19.77 Rg=7.802 SPS=2965
# 2nd loop
# ---
#
# bl=244 pos[1]=[9.4 -4.3 2.3] dr=0.73 t=0.0ps kin=1.48 pot=19.74 Rg=7.794 SPS=3027
# 2nd loop
# ---
#
# bl=245 pos[1]=[8.3 -4.1 2.8] dr=0.72 t=0.0ps kin=1.51 pot=19.71 Rg=7.777 SPS=2654
# 2nd loop
# ---
#
# bl=246 pos[1]=[7.4 -3.4 2.7] dr=0.73 t=0.0ps kin=1.53 pot=19.72 Rg=7.777 SPS=2173
# 2nd loop
# ---
#
# bl=247 pos[1]=[6.7 -3.3 2.6] dr=0.74 t=0.0ps kin=1.49 pot=19.75 Rg=7.799 SPS=2657
# 2nd loop
# ---
#
# bl=248 pos[1]=[6.9 -3.6 3.3] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.834 SPS=2900
# 2nd loop
# ---
#
# bl=249 pos[1]=[7.2 -3.7 2.4] dr=0.73 t=0.0ps kin=1.50 pot=19.71 Rg=7.865 SPS=2925
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.35066131  0.86808345 -2.24916093]   Rg =  7.8647065
#      median bond size is  0.9637327054384761
#      three shortest/longest (<10)/ bonds are  [0.88898226 0.88911849 0.88942556]    [1.07734255 1.08770262 1.09648382]
#      95 percentile of distance to center is:    10.923235174194502
#      density of closest 95% monomers is:    0.4719226579644788
#      density of the core monomers is:    0.6951380639976746
#      min/median/mean/max coordinates are:
#      x: -13.11, -0.25, -0.35, 11.45
#      y: -9.12, 0.93, 0.87, 11.21
#      z: -12.55, -2.23, -2.25, 7.94
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5033961472570156 should be: 1.5
#      fastest particles are (in kT):  [ 8.18450389  8.62218983  8.96863622  9.55171377 10.26017126]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.713883031434367
# bl=250 pos[1]=[7.3 -4.4 3.0] dr=0.73 t=0.0ps kin=1.46 pot=19.73 Rg=7.875 SPS=2936
# 2nd loop
# ---
#
# bl=251 pos[1]=[7.1 -4.8 3.7] dr=0.72 t=0.0ps kin=1.48 pot=19.73 Rg=7.850 SPS=3002
# 2nd loop
# ---
#
# bl=252 pos[1]=[8.1 -5.9 3.7] dr=0.72 t=0.0ps kin=1.48 pot=19.76 Rg=7.838 SPS=2982
# 2nd loop
# ---
#
# bl=253 pos[1]=[9.4 -4.7 3.8] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.852 SPS=3067
# 2nd loop
# ---
#
# bl=254 pos[1]=[8.6 -3.7 3.2] dr=0.74 t=0.0ps kin=1.45 pot=19.80 Rg=7.888 SPS=3050
# 2nd loop
# ---
#
# bl=255 pos[1]=[7.9 -4.0 2.9] dr=0.73 t=0.0ps kin=1.45 pot=19.79 Rg=7.902 SPS=3018
# 2nd loop
# ---
#
# bl=256 pos[1]=[7.4 -4.3 2.5] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=7.901 SPS=3132
# 2nd loop
# ---
#
# bl=257 pos[1]=[7.7 -4.7 2.2] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.900 SPS=2743
# 2nd loop
# ---
#
# bl=258 pos[1]=[7.1 -5.4 3.9] dr=0.73 t=0.0ps kin=1.50 pot=19.81 Rg=7.893 SPS=3112
# 2nd loop
# ---
#
# bl=259 pos[1]=[6.5 -4.8 4.5] dr=0.75 t=0.0ps kin=1.50 pot=19.82 Rg=7.875 SPS=3101
# 2nd loop
# ---
#
# bl=260 pos[1]=[7.1 -4.2 5.0] dr=0.76 t=0.0ps kin=1.50 pot=19.76 Rg=7.856 SPS=3056
# 2nd loop
# ---
#
# bl=261 pos[1]=[6.5 -2.4 4.5] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=7.843 SPS=2799
# 2nd loop
# ---
#
# bl=262 pos[1]=[6.3 -2.8 4.5] dr=0.72 t=0.0ps kin=1.51 pot=19.76 Rg=7.840 SPS=2190
# 2nd loop
# ---
#
# bl=263 pos[1]=[6.7 -2.8 4.5] dr=0.73 t=0.0ps kin=1.51 pot=19.79 Rg=7.845 SPS=2832
# 2nd loop
# ---
#
# bl=264 pos[1]=[6.8 -2.8 4.5] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=7.861 SPS=3024
# 2nd loop
# ---
#
# bl=265 pos[1]=[6.6 -3.1 3.9] dr=0.74 t=0.0ps kin=1.49 pot=19.79 Rg=7.868 SPS=2957
# 2nd loop
# ---
#
# bl=266 pos[1]=[7.4 -3.2 3.5] dr=0.73 t=0.0ps kin=1.50 pot=19.80 Rg=7.890 SPS=2538
# 2nd loop
# ---
#
# bl=267 pos[1]=[8.5 -2.9 3.6] dr=0.75 t=0.0ps kin=1.51 pot=19.79 Rg=7.912 SPS=2776
# 2nd loop
# ---
#
# bl=268 pos[1]=[8.5 -2.6 3.8] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=7.930 SPS=2959
# 2nd loop
# ---
#
# bl=269 pos[1]=[8.0 -3.7 4.0] dr=0.75 t=0.0ps kin=1.50 pot=19.77 Rg=7.938 SPS=3053
# 2nd loop
# ---
#
# bl=270 pos[1]=[8.1 -4.6 4.4] dr=0.74 t=0.0ps kin=1.47 pot=19.75 Rg=7.937 SPS=2963
# 2nd loop
# ---
#
# bl=271 pos[1]=[7.3 -6.3 4.2] dr=0.73 t=0.0ps kin=1.47 pot=19.74 Rg=7.939 SPS=3154
# 2nd loop
# ---
#
# bl=272 pos[1]=[6.8 -6.2 3.7] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.930 SPS=3281
# 2nd loop
# ---
#
# bl=273 pos[1]=[6.1 -5.7 3.8] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=7.935 SPS=3204
# 2nd loop
# ---
#
# bl=274 pos[1]=[6.4 -5.7 2.9] dr=0.73 t=0.0ps kin=1.48 pot=19.83 Rg=7.944 SPS=3241
# 2nd loop
# ---
#
# bl=275 pos[1]=[6.1 -5.3 2.9] dr=0.74 t=0.0ps kin=1.52 pot=19.76 Rg=7.948 SPS=3214
# 2nd loop
# ---
#
# bl=276 pos[1]=[6.5 -5.8 1.8] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.933 SPS=3253
# 2nd loop
# ---
#
# bl=277 pos[1]=[6.5 -5.0 1.6] dr=0.75 t=0.0ps kin=1.57 pot=19.77 Rg=7.910 SPS=3277
# 2nd loop
# ---
#
# bl=278 pos[1]=[6.1 -6.5 1.6] dr=0.75 t=0.0ps kin=1.52 pot=19.84 Rg=7.897 SPS=3306
# 2nd loop
# ---
#
# bl=279 pos[1]=[5.3 -6.1 2.0] dr=0.75 t=0.0ps kin=1.56 pot=19.79 Rg=7.882 SPS=3376
# 2nd loop
# ---
#
# bl=280 pos[1]=[4.9 -5.1 2.4] dr=0.73 t=0.0ps kin=1.54 pot=19.80 Rg=7.889 SPS=3416
# 2nd loop
# ---
#
# bl=281 pos[1]=[4.7 -4.9 2.1] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=7.897 SPS=3377
# 2nd loop
# ---
#
# bl=282 pos[1]=[4.0 -5.0 2.7] dr=0.73 t=0.0ps kin=1.49 pot=19.80 Rg=7.891 SPS=3409
# 2nd loop
# ---
#
# bl=283 pos[1]=[4.2 -5.8 1.9] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=7.870 SPS=3479
# 2nd loop
# ---
#
# bl=284 pos[1]=[4.1 -5.9 1.7] dr=0.74 t=0.0ps kin=1.48 pot=19.80 Rg=7.870 SPS=3411
# 2nd loop
# ---
#
# bl=285 pos[1]=[4.1 -6.3 2.7] dr=0.75 t=0.0ps kin=1.52 pot=19.77 Rg=7.869 SPS=3480
# 2nd loop
# ---
#
# bl=286 pos[1]=[4.5 -6.2 3.5] dr=0.75 t=0.0ps kin=1.50 pot=19.77 Rg=7.868 SPS=3527
# 2nd loop
# ---
#
# bl=287 pos[1]=[4.7 -6.4 3.5] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=7.873 SPS=3425
# 2nd loop
# ---
#
# bl=288 pos[1]=[3.9 -6.3 3.7] dr=0.73 t=0.0ps kin=1.50 pot=19.79 Rg=7.865 SPS=3450
# 2nd loop
# ---
#
# bl=289 pos[1]=[3.6 -7.4 2.7] dr=0.74 t=0.0ps kin=1.52 pot=19.77 Rg=7.856 SPS=3461
# 2nd loop
# ---
#
# bl=290 pos[1]=[3.3 -6.8 3.3] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=7.872 SPS=3434
# 2nd loop
# ---
#
# bl=291 pos[1]=[2.9 -7.0 3.5] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=7.888 SPS=3440
# 2nd loop
# ---
#
# bl=292 pos[1]=[2.2 -7.6 3.5] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=7.922 SPS=3557
# 2nd loop
# ---
#
# bl=293 pos[1]=[1.8 -7.2 2.6] dr=0.75 t=0.0ps kin=1.48 pot=19.80 Rg=7.924 SPS=3403
# 2nd loop
# ---
#
# bl=294 pos[1]=[1.7 -7.9 3.1] dr=0.74 t=0.0ps kin=1.49 pot=19.81 Rg=7.892 SPS=3479
# 2nd loop
# ---
#
# bl=295 pos[1]=[0.9 -8.2 3.3] dr=0.73 t=0.0ps kin=1.52 pot=19.73 Rg=7.866 SPS=3383
# 2nd loop
# ---
#
# bl=296 pos[1]=[1.3 -8.1 3.2] dr=0.74 t=0.0ps kin=1.51 pot=19.76 Rg=7.853 SPS=3365
# 2nd loop
# ---
#
# bl=297 pos[1]=[2.3 -7.6 2.7] dr=0.74 t=0.0ps kin=1.54 pot=19.74 Rg=7.853 SPS=3331
# 2nd loop
# ---
#
# bl=298 pos[1]=[2.8 -6.9 3.4] dr=0.74 t=0.0ps kin=1.47 pot=19.81 Rg=7.863 SPS=3353
# 2nd loop
# ---
#
# bl=299 pos[1]=[3.0 -6.4 3.2] dr=0.73 t=0.0ps kin=1.49 pot=19.80 Rg=7.866 SPS=3394
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.47732667  0.80337801 -2.52996968]   Rg =  7.865767
#      median bond size is  0.9633789365251005
#      three shortest/longest (<10)/ bonds are  [0.84309541 0.87723135 0.8788969 ]    [1.08752553 1.08776006 1.08907714]
#      95 percentile of distance to center is:    10.980314384380232
#      density of closest 95% monomers is:    0.4646012314849266
#      density of the core monomers is:    0.7361956912091678
#      min/median/mean/max coordinates are:
#      x: -12.72, -0.62, -0.48, 12.22
#      y: -9.48, 0.70, 0.80, 11.89
#      z: -12.91, -2.49, -2.53, 8.12
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4960402597565787 should be: 1.5
#      fastest particles are (in kT):  [6.82816939 6.85783365 6.98468796 7.25807281 7.60516495]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.798139634033923
# bl=300 pos[1]=[2.8 -6.6 4.5] dr=0.72 t=0.0ps kin=1.51 pot=19.77 Rg=7.877 SPS=3087
# 2nd loop
# ---
#
# bl=301 pos[1]=[1.9 -6.7 5.0] dr=0.72 t=0.0ps kin=1.51 pot=19.80 Rg=7.894 SPS=3220
# 2nd loop
# ---
#
# bl=302 pos[1]=[0.9 -6.8 4.0] dr=0.74 t=0.0ps kin=1.51 pot=19.78 Rg=7.898 SPS=3407
# 2nd loop
# ---
#
# bl=303 pos[1]=[1.4 -7.6 4.1] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.872 SPS=3325
# 2nd loop
# ---
#
# bl=304 pos[1]=[1.2 -7.8 4.8] dr=0.74 t=0.0ps kin=1.50 pot=19.81 Rg=7.835 SPS=3385
# 2nd loop
# ---
#
# bl=305 pos[1]=[1.9 -7.8 4.9] dr=0.72 t=0.0ps kin=1.50 pot=19.81 Rg=7.835 SPS=3213
# 2nd loop
# ---
#
# bl=306 pos[1]=[2.5 -7.2 4.8] dr=0.72 t=0.0ps kin=1.48 pot=19.81 Rg=7.832 SPS=2911
# 2nd loop
# ---
#
# bl=307 pos[1]=[2.9 -7.8 5.1] dr=0.74 t=0.0ps kin=1.52 pot=19.82 Rg=7.835 SPS=2545
# 2nd loop
# ---
#
# bl=308 pos[1]=[4.5 -7.6 5.5] dr=0.74 t=0.0ps kin=1.51 pot=19.83 Rg=7.852 SPS=2176
# 2nd loop
# ---
#
# bl=309 pos[1]=[5.0 -7.0 4.0] dr=0.74 t=0.0ps kin=1.52 pot=19.82 Rg=7.866 SPS=2185
# 2nd loop
# ---
#
# bl=310 pos[1]=[5.5 -6.1 4.0] dr=0.77 t=0.0ps kin=1.51 pot=19.80 Rg=7.873 SPS=2323
# 2nd loop
# ---
#
# bl=311 pos[1]=[4.8 -4.6 4.5] dr=0.76 t=0.0ps kin=1.49 pot=19.79 Rg=7.895 SPS=2330
# 2nd loop
# ---
#
# bl=312 pos[1]=[4.3 -4.8 3.7] dr=0.76 t=0.0ps kin=1.51 pot=19.80 Rg=7.882 SPS=2259
# 2nd loop
# ---
#
# bl=313 pos[1]=[5.4 -5.4 3.3] dr=0.76 t=0.0ps kin=1.51 pot=19.81 Rg=7.849 SPS=2116
# 2nd loop
# ---
#
# bl=314 pos[1]=[4.9 -5.0 4.3] dr=0.73 t=0.0ps kin=1.52 pot=19.76 Rg=7.820 SPS=2107
# 2nd loop
# ---
#
# bl=315 pos[1]=[5.5 -4.2 4.8] dr=0.74 t=0.0ps kin=1.52 pot=19.74 Rg=7.811 SPS=2033
# 2nd loop
# ---
#
# bl=316 pos[1]=[6.3 -4.8 4.0] dr=0.75 t=0.0ps kin=1.51 pot=19.75 Rg=7.834 SPS=2172
# 2nd loop
# ---
#
# bl=317 pos[1]=[7.4 -5.1 2.0] dr=0.74 t=0.0ps kin=1.49 pot=19.76 Rg=7.849 SPS=2175
# 2nd loop
# ---
#
# bl=318 pos[1]=[6.4 -5.5 2.4] dr=0.75 t=0.0ps kin=1.48 pot=19.80 Rg=7.851 SPS=2046
# 2nd loop
# ---
#
# bl=319 pos[1]=[5.4 -5.1 2.4] dr=0.73 t=0.0ps kin=1.47 pot=19.76 Rg=7.837 SPS=2135
# 2nd loop
# ---
#
# bl=320 pos[1]=[5.9 -4.0 3.4] dr=0.73 t=0.0ps kin=1.46 pot=19.77 Rg=7.834 SPS=1966
# 2nd loop
# ---
#
# bl=321 pos[1]=[5.5 -3.5 4.3] dr=0.73 t=0.0ps kin=1.47 pot=19.78 Rg=7.823 SPS=1912
# 2nd loop
# ---
#
# bl=322 pos[1]=[5.0 -3.5 4.1] dr=0.74 t=0.0ps kin=1.51 pot=19.80 Rg=7.803 SPS=1896
# 2nd loop
# ---
#
# bl=323 pos[1]=[5.1 -3.4 5.0] dr=0.74 t=0.0ps kin=1.53 pot=19.77 Rg=7.808 SPS=1947
# 2nd loop
# ---
#
# bl=324 pos[1]=[5.2 -4.3 5.2] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=7.840 SPS=1960
# 2nd loop
# ---
#
# bl=325 pos[1]=[4.3 -4.9 5.0] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=7.867 SPS=2251
# 2nd loop
# ---
#
# bl=326 pos[1]=[4.1 -4.4 5.2] dr=0.74 t=0.0ps kin=1.48 pot=19.81 Rg=7.883 SPS=2166
# 2nd loop
# ---
#
# bl=327 pos[1]=[4.1 -3.9 4.3] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.886 SPS=2167
# 2nd loop
# ---
#
# bl=328 pos[1]=[4.2 -4.1 4.8] dr=0.74 t=0.0ps kin=1.47 pot=19.79 Rg=7.885 SPS=1990
# 2nd loop
# ---
#
# bl=329 pos[1]=[4.8 -4.4 5.2] dr=0.73 t=0.0ps kin=1.48 pot=19.76 Rg=7.881 SPS=2251
# 2nd loop
# ---
#
# bl=330 pos[1]=[4.5 -4.6 5.4] dr=0.73 t=0.0ps kin=1.51 pot=19.77 Rg=7.886 SPS=2037
# 2nd loop
# ---
#
# bl=331 pos[1]=[5.2 -5.0 5.8] dr=0.73 t=0.0ps kin=1.50 pot=19.74 Rg=7.887 SPS=1865
# 2nd loop
# ---
#
# bl=332 pos[1]=[5.9 -4.7 6.0] dr=0.72 t=0.0ps kin=1.50 pot=19.76 Rg=7.867 SPS=2091
# 2nd loop
# ---
#
# bl=333 pos[1]=[4.9 -4.2 5.3] dr=0.72 t=0.0ps kin=1.49 pot=19.74 Rg=7.853 SPS=1976
# 2nd loop
# ---
#
# bl=334 pos[1]=[5.8 -4.2 4.7] dr=0.73 t=0.0ps kin=1.54 pot=19.73 Rg=7.843 SPS=1791
# 2nd loop
# ---
#
# bl=335 pos[1]=[6.3 -4.1 5.1] dr=0.73 t=0.0ps kin=1.45 pot=19.78 Rg=7.847 SPS=1842
# 2nd loop
# ---
#
# bl=336 pos[1]=[6.6 -3.1 5.1] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=7.870 SPS=1843
# 2nd loop
# ---
#
# bl=337 pos[1]=[6.3 -2.3 3.8] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=7.881 SPS=1892
# 2nd loop
# ---
#
# bl=338 pos[1]=[6.3 -2.3 2.9] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=7.889 SPS=1853
# 2nd loop
# ---
#
# bl=339 pos[1]=[6.8 -2.0 3.6] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.878 SPS=2210
# 2nd loop
# ---
#
# bl=340 pos[1]=[6.6 -3.1 3.6] dr=0.74 t=0.0ps kin=1.49 pot=19.75 Rg=7.868 SPS=2617
# 2nd loop
# ---
#
# bl=341 pos[1]=[6.9 -3.5 2.7] dr=0.73 t=0.0ps kin=1.47 pot=19.78 Rg=7.876 SPS=2849
# 2nd loop
# ---
#
# bl=342 pos[1]=[7.0 -4.3 2.8] dr=0.73 t=0.0ps kin=1.48 pot=19.79 Rg=7.881 SPS=2861
# 2nd loop
# ---
#
# bl=343 pos[1]=[7.3 -5.8 4.1] dr=0.73 t=0.0ps kin=1.51 pot=19.75 Rg=7.861 SPS=2929
# 2nd loop
# ---
#
# bl=344 pos[1]=[5.7 -5.7 5.1] dr=0.74 t=0.0ps kin=1.52 pot=19.75 Rg=7.864 SPS=3059
# 2nd loop
# ---
#
# bl=345 pos[1]=[5.7 -4.8 4.9] dr=0.73 t=0.0ps kin=1.50 pot=19.76 Rg=7.870 SPS=3052
# 2nd loop
# ---
#
# bl=346 pos[1]=[6.1 -5.3 3.8] dr=0.73 t=0.0ps kin=1.48 pot=19.73 Rg=7.892 SPS=2937
# 2nd loop
# ---
#
# bl=347 pos[1]=[6.1 -4.2 2.6] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.892 SPS=3015
# 2nd loop
# ---
#
# bl=348 pos[1]=[5.9 -3.4 2.3] dr=0.74 t=0.0ps kin=1.50 pot=19.75 Rg=7.893 SPS=3093
# 2nd loop
# ---
#
# bl=349 pos[1]=[5.7 -3.4 1.8] dr=0.73 t=0.0ps kin=1.48 pot=19.75 Rg=7.903 SPS=3132
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.52691998  1.16727674 -2.42094241]   Rg =  7.902502
#      median bond size is  0.9649125272020943
#      three shortest/longest (<10)/ bonds are  [0.86648794 0.87678868 0.88013043]    [1.08497389 1.08769122 1.09436502]
#      95 percentile of distance to center is:    10.96534364117591
#      density of closest 95% monomers is:    0.4665067603133994
#      density of the core monomers is:    0.7511406392900257
#      min/median/mean/max coordinates are:
#      x: -13.12, -0.65, -0.53, 11.94
#      y: -9.19, 0.88, 1.17, 11.71
#      z: -13.29, -2.43, -2.42, 7.23
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4819739972519015 should be: 1.5
#      fastest particles are (in kT):  [7.37467603 7.50548989 7.51144719 7.51762851 8.7187291 ]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.75292392606932
# bl=350 pos[1]=[6.3 -3.9 1.7] dr=0.73 t=0.0ps kin=1.48 pot=19.75 Rg=7.928 SPS=3115
# 2nd loop
# ---
#
# bl=351 pos[1]=[7.3 -4.3 2.0] dr=0.73 t=0.0ps kin=1.49 pot=19.75 Rg=7.925 SPS=3161
# 2nd loop
# ---
#
# bl=352 pos[1]=[8.1 -4.5 2.4] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=7.938 SPS=3244
# 2nd loop
# ---
#
# bl=353 pos[1]=[8.3 -4.3 2.6] dr=0.73 t=0.0ps kin=1.47 pot=19.77 Rg=7.944 SPS=3090
# 2nd loop
# ---
#
# bl=354 pos[1]=[7.8 -4.5 2.4] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.918 SPS=3070
# 2nd loop
# ---
#
# bl=355 pos[1]=[7.0 -4.6 2.4] dr=0.73 t=0.0ps kin=1.46 pot=19.82 Rg=7.890 SPS=3149
# 2nd loop
# ---
#
# bl=356 pos[1]=[6.9 -4.3 2.3] dr=0.74 t=0.0ps kin=1.52 pot=19.76 Rg=7.871 SPS=3186
# 2nd loop
# ---
#
# bl=357 pos[1]=[6.5 -4.6 3.1] dr=0.73 t=0.0ps kin=1.49 pot=19.79 Rg=7.867 SPS=3142
# 2nd loop
# ---
#
# bl=358 pos[1]=[6.1 -5.5 2.3] dr=0.71 t=0.0ps kin=1.49 pot=19.78 Rg=7.864 SPS=3009
# 2nd loop
# ---
#
# bl=359 pos[1]=[6.8 -5.0 2.1] dr=0.72 t=0.0ps kin=1.49 pot=19.79 Rg=7.836 SPS=3273
# 2nd loop
# ---
#
# bl=360 pos[1]=[5.8 -5.5 2.9] dr=0.72 t=0.0ps kin=1.53 pot=19.74 Rg=7.831 SPS=3126
# 2nd loop
# ---
#
# bl=361 pos[1]=[5.5 -5.8 4.4] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=7.821 SPS=3225
# 2nd loop
# ---
#
# bl=362 pos[1]=[6.4 -5.2 5.2] dr=0.71 t=0.0ps kin=1.50 pot=19.81 Rg=7.809 SPS=2757
# 2nd loop
# ---
#
# bl=363 pos[1]=[7.4 -3.5 5.0] dr=0.75 t=0.0ps kin=1.51 pot=19.75 Rg=7.826 SPS=3193
# 2nd loop
# ---
#
# bl=364 pos[1]=[7.4 -3.0 4.7] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.837 SPS=3196
# 2nd loop
# ---
#
# bl=365 pos[1]=[7.6 -2.9 3.6] dr=0.74 t=0.0ps kin=1.47 pot=19.79 Rg=7.851 SPS=3110
# 2nd loop
# ---
#
# bl=366 pos[1]=[5.7 -3.6 4.7] dr=0.74 t=0.0ps kin=1.52 pot=19.75 Rg=7.857 SPS=3092
# 2nd loop
# ---
#
# bl=367 pos[1]=[5.1 -2.7 5.6] dr=0.75 t=0.0ps kin=1.51 pot=19.77 Rg=7.860 SPS=2473
# 2nd loop
# ---
#
# bl=368 pos[1]=[5.1 -3.7 5.1] dr=0.74 t=0.0ps kin=1.48 pot=19.79 Rg=7.843 SPS=2657
# 2nd loop
# ---
#
# bl=369 pos[1]=[4.8 -4.1 4.0] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.810 SPS=3116
# 2nd loop
# ---
#
# bl=370 pos[1]=[4.9 -3.8 3.5] dr=0.74 t=0.0ps kin=1.51 pot=19.73 Rg=7.770 SPS=2830
# 2nd loop
# ---
#
# bl=371 pos[1]=[5.8 -3.6 2.5] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.750 SPS=2703
# 2nd loop
# ---
#
# bl=372 pos[1]=[5.6 -4.0 3.0] dr=0.74 t=0.0ps kin=1.51 pot=19.74 Rg=7.747 SPS=2386
# 2nd loop
# ---
#
# bl=373 pos[1]=[5.7 -4.1 3.1] dr=0.72 t=0.0ps kin=1.50 pot=19.73 Rg=7.763 SPS=2278
# 2nd loop
# ---
#
# bl=374 pos[1]=[5.0 -4.1 2.8] dr=0.73 t=0.0ps kin=1.46 pot=19.73 Rg=7.773 SPS=1859
# 2nd loop
# ---
#
# bl=375 pos[1]=[5.3 -4.0 3.0] dr=0.73 t=0.0ps kin=1.45 pot=19.77 Rg=7.793 SPS=1995
# 2nd loop
# ---
#
# bl=376 pos[1]=[5.9 -3.2 2.4] dr=0.72 t=0.0ps kin=1.47 pot=19.76 Rg=7.815 SPS=1982
# 2nd loop
# ---
#
# bl=377 pos[1]=[5.9 -2.3 2.3] dr=0.74 t=0.0ps kin=1.51 pot=19.75 Rg=7.819 SPS=2051
# 2nd loop
# ---
#
# bl=378 pos[1]=[5.8 -3.2 2.4] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.826 SPS=2159
# 2nd loop
# ---
#
# bl=379 pos[1]=[6.0 -3.4 3.5] dr=0.74 t=0.0ps kin=1.48 pot=19.81 Rg=7.850 SPS=2145
# 2nd loop
# ---
#
# bl=380 pos[1]=[6.5 -2.7 3.8] dr=0.74 t=0.0ps kin=1.53 pot=19.75 Rg=7.857 SPS=2188
# 2nd loop
# ---
#
# bl=381 pos[1]=[5.5 -2.8 3.2] dr=0.75 t=0.0ps kin=1.52 pot=19.80 Rg=7.841 SPS=1950
# 2nd loop
# ---
#
# bl=382 pos[1]=[4.7 -2.9 3.2] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=7.793 SPS=1824
# 2nd loop
# ---
#
# bl=383 pos[1]=[4.6 -3.2 3.5] dr=0.74 t=0.0ps kin=1.53 pot=19.76 Rg=7.767 SPS=1899
# 2nd loop
# ---
#
# bl=384 pos[1]=[4.1 -3.8 3.7] dr=0.73 t=0.0ps kin=1.53 pot=19.78 Rg=7.752 SPS=1868
# 2nd loop
# ---
#
# bl=385 pos[1]=[3.9 -4.5 3.8] dr=0.72 t=0.0ps kin=1.54 pot=19.74 Rg=7.755 SPS=2500
# 2nd loop
# ---
#
# bl=386 pos[1]=[4.6 -4.3 3.7] dr=0.75 t=0.0ps kin=1.51 pot=19.77 Rg=7.781 SPS=2515
# 2nd loop
# ---
#
# bl=387 pos[1]=[3.9 -5.3 3.9] dr=0.74 t=0.0ps kin=1.47 pot=19.76 Rg=7.784 SPS=2487
# 2nd loop
# ---
#
# bl=388 pos[1]=[2.7 -5.7 3.5] dr=0.74 t=0.0ps kin=1.46 pot=19.77 Rg=7.760 SPS=2619
# 2nd loop
# ---
#
# bl=389 pos[1]=[3.3 -5.7 4.1] dr=0.74 t=0.0ps kin=1.48 pot=19.80 Rg=7.743 SPS=2703
# 2nd loop
# ---
#
# bl=390 pos[1]=[2.9 -6.2 5.2] dr=0.72 t=0.0ps kin=1.51 pot=19.77 Rg=7.720 SPS=2770
# 2nd loop
# ---
#
# bl=391 pos[1]=[1.9 -6.2 5.5] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.702 SPS=2791
# 2nd loop
# ---
#
# bl=392 pos[1]=[1.7 -7.6 4.8] dr=0.73 t=0.0ps kin=1.50 pot=19.73 Rg=7.672 SPS=2789
# 2nd loop
# ---
#
# bl=393 pos[1]=[3.1 -7.9 3.4] dr=0.73 t=0.0ps kin=1.50 pot=19.71 Rg=7.661 SPS=2771
# 2nd loop
# ---
#
# bl=394 pos[1]=[4.1 -7.3 2.7] dr=0.72 t=0.0ps kin=1.47 pot=19.74 Rg=7.668 SPS=2952
# 2nd loop
# ---
#
# bl=395 pos[1]=[4.7 -5.7 3.3] dr=0.72 t=0.0ps kin=1.47 pot=19.73 Rg=7.685 SPS=2855
# 2nd loop
# ---
#
# bl=396 pos[1]=[4.8 -5.3 4.7] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=7.697 SPS=2897
# 2nd loop
# ---
#
# bl=397 pos[1]=[2.5 -5.7 4.4] dr=0.73 t=0.0ps kin=1.55 pot=19.71 Rg=7.695 SPS=2913
# 2nd loop
# ---
#
# bl=398 pos[1]=[2.2 -6.5 4.2] dr=0.73 t=0.0ps kin=1.48 pot=19.77 Rg=7.711 SPS=2818
# 2nd loop
# ---
#
# bl=399 pos[1]=[2.7 -6.5 2.7] dr=0.73 t=0.0ps kin=1.52 pot=19.73 Rg=7.715 SPS=2899
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.87585742  1.36591825 -2.54590362]   Rg =  7.7149262
#      median bond size is  0.9644738696476768
#      three shortest/longest (<10)/ bonds are  [0.83867301 0.88222674 0.8827234 ]    [1.08181758 1.08197192 1.08618598]
#      95 percentile of distance to center is:    10.486919539709488
#      density of closest 95% monomers is:    0.5333114076385858
#      density of the core monomers is:    0.7077861965818871
#      min/median/mean/max coordinates are:
#      x: -12.27, -0.87, -0.88, 10.24
#      y: -9.53, 1.23, 1.37, 11.54
#      z: -13.37, -2.65, -2.55, 7.84
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5241537891980084 should be: 1.5
#      fastest particles are (in kT):  [ 7.70296762  8.13723362  8.64248092  9.17167678 10.61964279]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.73152453217183
# ...
# 2nd loop
# ---
#
# bl=1876 pos[1]=[-1.4 -3.6 -6.5] dr=0.75 t=0.0ps kin=1.48 pot=19.79 Rg=7.716 SPS=2939
# 2nd loop
# ---
#
# bl=1877 pos[1]=[-0.6 -2.7 -5.7] dr=0.73 t=0.0ps kin=1.47 pot=19.78 Rg=7.718 SPS=2892
# 2nd loop
# ---
#
# bl=1878 pos[1]=[-0.3 -2.0 -6.0] dr=0.74 t=0.0ps kin=1.54 pot=19.71 Rg=7.715 SPS=2939
# 2nd loop
# ---
#
# bl=1879 pos[1]=[0.0 -2.1 -6.0] dr=0.73 t=0.0ps kin=1.52 pot=19.72 Rg=7.719 SPS=2834
# 2nd loop
# ---
#
# bl=1880 pos[1]=[0.2 -1.8 -6.3] dr=0.73 t=0.0ps kin=1.48 pot=19.76 Rg=7.736 SPS=2881
# 2nd loop
# ---
#
# bl=1881 pos[1]=[0.4 -2.4 -6.4] dr=0.73 t=0.0ps kin=1.48 pot=19.73 Rg=7.742 SPS=2744
# 2nd loop
# ---
#
# bl=1882 pos[1]=[-0.1 -3.3 -6.4] dr=0.73 t=0.0ps kin=1.46 pot=19.73 Rg=7.728 SPS=2386
# 2nd loop
# ---
#
# bl=1883 pos[1]=[-0.4 -3.4 -6.2] dr=0.72 t=0.0ps kin=1.49 pot=19.71 Rg=7.721 SPS=3004
# 2nd loop
# ---
#
# bl=1884 pos[1]=[-0.5 -3.2 -6.4] dr=0.74 t=0.0ps kin=1.49 pot=19.76 Rg=7.725 SPS=2913
# 2nd loop
# ---
#
# bl=1885 pos[1]=[-1.2 -3.5 -5.8] dr=0.73 t=0.0ps kin=1.48 pot=19.77 Rg=7.720 SPS=2581
# 2nd loop
# ---
#
# bl=1886 pos[1]=[-1.2 -3.4 -6.3] dr=0.73 t=0.0ps kin=1.51 pot=19.75 Rg=7.713 SPS=2924
# 2nd loop
# ---
#
# bl=1887 pos[1]=[-1.5 -3.4 -5.9] dr=0.72 t=0.0ps kin=1.47 pot=19.76 Rg=7.703 SPS=2990
# 2nd loop
# ---
#
# bl=1888 pos[1]=[-1.3 -2.7 -5.2] dr=0.73 t=0.0ps kin=1.47 pot=19.79 Rg=7.692 SPS=2854
# 2nd loop
# ---
#
# bl=1889 pos[1]=[-1.6 -2.1 -5.1] dr=0.74 t=0.0ps kin=1.48 pot=19.77 Rg=7.676 SPS=2826
# 2nd loop
# ---
#
# bl=1890 pos[1]=[-1.3 -1.9 -5.6] dr=0.72 t=0.0ps kin=1.50 pot=19.76 Rg=7.664 SPS=3023
# 2nd loop
# ---
#
# bl=1891 pos[1]=[-1.8 -2.7 -5.3] dr=0.73 t=0.0ps kin=1.48 pot=19.73 Rg=7.672 SPS=2959
# 2nd loop
# ---
#
# bl=1892 pos[1]=[-1.7 -3.1 -5.5] dr=0.70 t=0.0ps kin=1.50 pot=19.72 Rg=7.677 SPS=3137
# 2nd loop
# ---
#
# bl=1893 pos[1]=[-1.6 -3.2 -5.4] dr=0.72 t=0.0ps kin=1.46 pot=19.76 Rg=7.697 SPS=3017
# 2nd loop
# ---
#
# bl=1894 pos[1]=[-0.4 -3.3 -4.4] dr=0.71 t=0.0ps kin=1.47 pot=19.78 Rg=7.720 SPS=2936
# 2nd loop
# ---
#
# bl=1895 pos[1]=[-1.4 -3.6 -4.0] dr=0.72 t=0.0ps kin=1.50 pot=19.74 Rg=7.736 SPS=3133
# 2nd loop
# ---
#
# bl=1896 pos[1]=[-1.3 -3.3 -4.4] dr=0.73 t=0.0ps kin=1.49 pot=19.78 Rg=7.735 SPS=3086
# 2nd loop
# ---
#
# bl=1897 pos[1]=[-1.0 -4.0 -3.5] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.719 SPS=2938
# 2nd loop
# ---
#
# bl=1898 pos[1]=[-0.8 -4.2 -3.2] dr=0.74 t=0.0ps kin=1.52 pot=19.79 Rg=7.721 SPS=3000
# 2nd loop
# ---
#
# bl=1899 pos[1]=[-0.7 -4.4 -2.4] dr=0.74 t=0.0ps kin=1.54 pot=19.76 Rg=7.734 SPS=3223
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.00980511 -1.28899911 -5.16427989]   Rg =  7.733816
#      median bond size is  0.9634241906282519
#      three shortest/longest (<10)/ bonds are  [0.87844618 0.88092532 0.88218626]    [1.09314391 1.09909997 1.10799654]
#      95 percentile of distance to center is:    10.61875097753541
#      density of closest 95% monomers is:    0.5136938574143766
#      density of the core monomers is:    0.7104089777466916
#      min/median/mean/max coordinates are:
#      x: -11.56, -0.87, -1.01, 9.57
#      y: -11.11, -1.32, -1.29, 8.68
#      z: -15.09, -5.25, -5.16, 5.10
#
# Statistics for velocities:
#      mean kinetic energy is:  1.539716241533931 should be: 1.5
#      fastest particles are (in kT):  [ 8.14748952  8.25627629  8.64326089  9.17419135 11.27663098]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.760837251106196
# bl=1900 pos[1]=[-1.0 -4.2 -2.6] dr=0.75 t=0.0ps kin=1.53 pot=19.75 Rg=7.740 SPS=2732
# 2nd loop
# ---
#
# bl=1901 pos[1]=[-1.2 -4.0 -2.5] dr=0.74 t=0.0ps kin=1.50 pot=19.81 Rg=7.748 SPS=3138
# 2nd loop
# ---
#
# bl=1902 pos[1]=[-1.3 -3.3 -2.5] dr=0.74 t=0.0ps kin=1.51 pot=19.80 Rg=7.762 SPS=2970
# 2nd loop
# ---
#
# bl=1903 pos[1]=[-1.2 -3.8 -2.2] dr=0.74 t=0.0ps kin=1.49 pot=19.80 Rg=7.745 SPS=2215
# 2nd loop
# ---
#
# bl=1904 pos[1]=[-1.2 -3.5 -1.7] dr=0.74 t=0.0ps kin=1.54 pot=19.78 Rg=7.737 SPS=2857
# 2nd loop
# ---
#
# bl=1905 pos[1]=[-1.2 -3.7 -1.9] dr=0.72 t=0.0ps kin=1.55 pot=19.77 Rg=7.711 SPS=2975
# 2nd loop
# ---
#
# bl=1906 pos[1]=[-1.1 -4.2 -1.7] dr=0.73 t=0.0ps kin=1.54 pot=19.74 Rg=7.717 SPS=2950
# 2nd loop
# ---
#
# bl=1907 pos[1]=[-1.2 -4.1 -2.3] dr=0.73 t=0.0ps kin=1.53 pot=19.74 Rg=7.732 SPS=3204
# 2nd loop
# ---
#
# bl=1908 pos[1]=[-1.1 -3.7 -2.4] dr=0.74 t=0.0ps kin=1.50 pot=19.77 Rg=7.743 SPS=3215
# 2nd loop
# ---
#
# bl=1909 pos[1]=[-1.1 -4.0 -2.1] dr=0.75 t=0.0ps kin=1.49 pot=19.82 Rg=7.752 SPS=3135
# 2nd loop
# ---
#
# bl=1910 pos[1]=[-1.8 -3.8 -2.9] dr=0.74 t=0.0ps kin=1.53 pot=19.80 Rg=7.752 SPS=3142
# 2nd loop
# ---
#
# bl=1911 pos[1]=[-2.2 -3.9 -2.8] dr=0.72 t=0.0ps kin=1.49 pot=19.77 Rg=7.751 SPS=3257
# 2nd loop
# ---
#
# bl=1912 pos[1]=[-2.1 -4.5 -2.9] dr=0.74 t=0.0ps kin=1.49 pot=19.75 Rg=7.751 SPS=3187
# 2nd loop
# ---
#
# bl=1913 pos[1]=[-2.3 -4.4 -2.7] dr=0.72 t=0.0ps kin=1.50 pot=19.74 Rg=7.742 SPS=3067
# 2nd loop
# ---
#
# bl=1914 pos[1]=[-3.2 -4.2 -2.7] dr=0.73 t=0.0ps kin=1.52 pot=19.77 Rg=7.741 SPS=3062
# 2nd loop
# ---
#
# bl=1915 pos[1]=[-2.9 -3.8 -2.9] dr=0.74 t=0.0ps kin=1.53 pot=19.79 Rg=7.751 SPS=3259
# 2nd loop
# ---
#
# bl=1916 pos[1]=[-2.6 -3.9 -3.3] dr=0.73 t=0.0ps kin=1.54 pot=19.79 Rg=7.756 SPS=3274
# 2nd loop
# ---
#
# bl=1917 pos[1]=[-3.4 -3.9 -3.1] dr=0.74 t=0.0ps kin=1.52 pot=19.82 Rg=7.759 SPS=3218
# 2nd loop
# ---
#
# bl=1918 pos[1]=[-3.2 -4.5 -3.0] dr=0.73 t=0.0ps kin=1.54 pot=19.77 Rg=7.779 SPS=3219
# 2nd loop
# ---
#
# bl=1919 pos[1]=[-3.1 -4.8 -3.2] dr=0.74 t=0.0ps kin=1.52 pot=19.78 Rg=7.774 SPS=3237
# 2nd loop
# ---
#
# bl=1920 pos[1]=[-3.3 -4.4 -3.5] dr=0.74 t=0.0ps kin=1.52 pot=19.78 Rg=7.781 SPS=3203
# 2nd loop
# ---
#
# bl=1921 pos[1]=[-3.7 -4.2 -4.4] dr=0.75 t=0.0ps kin=1.51 pot=19.77 Rg=7.788 SPS=3114
# 2nd loop
# ---
#
# bl=1922 pos[1]=[-3.6 -3.9 -4.2] dr=0.73 t=0.0ps kin=1.49 pot=19.76 Rg=7.791 SPS=3220
# 2nd loop
# ---
#
# bl=1923 pos[1]=[-3.9 -4.1 -4.1] dr=0.74 t=0.0ps kin=1.48 pot=19.79 Rg=7.785 SPS=3218
# 2nd loop
# ---
#
# bl=1924 pos[1]=[-3.6 -4.2 -4.0] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.785 SPS=3271
# 2nd loop
# ---
#
# bl=1925 pos[1]=[-3.6 -4.5 -4.0] dr=0.75 t=0.0ps kin=1.50 pot=19.77 Rg=7.787 SPS=3218
# 2nd loop
# ---
#
# bl=1926 pos[1]=[-3.8 -4.2 -3.7] dr=0.75 t=0.0ps kin=1.52 pot=19.79 Rg=7.784 SPS=3376
# 2nd loop
# ---
#
# bl=1927 pos[1]=[-3.9 -4.1 -3.8] dr=0.74 t=0.0ps kin=1.55 pot=19.77 Rg=7.794 SPS=3405
# 2nd loop
# ---
#
# bl=1928 pos[1]=[-3.8 -4.0 -4.4] dr=0.75 t=0.0ps kin=1.51 pot=19.81 Rg=7.801 SPS=3225
# 2nd loop
# ---
#
# bl=1929 pos[1]=[-3.8 -4.3 -4.8] dr=0.74 t=0.0ps kin=1.51 pot=19.81 Rg=7.808 SPS=2464
# 2nd loop
# ---
#
# bl=1930 pos[1]=[-3.6 -4.2 -4.7] dr=0.74 t=0.0ps kin=1.50 pot=19.78 Rg=7.811 SPS=2456
# 2nd loop
# ---
#
# bl=1931 pos[1]=[-3.5 -3.6 -5.0] dr=0.75 t=0.0ps kin=1.50 pot=19.77 Rg=7.811 SPS=2481
# 2nd loop
# ---
#
# bl=1932 pos[1]=[-3.7 -4.3 -5.6] dr=0.73 t=0.0ps kin=1.51 pot=19.74 Rg=7.809 SPS=2538
# 2nd loop
# ---
#
# bl=1933 pos[1]=[-3.1 -4.9 -5.3] dr=0.73 t=0.0ps kin=1.50 pot=19.77 Rg=7.800 SPS=2465
# 2nd loop
# ---
#
# bl=1934 pos[1]=[-2.8 -4.4 -5.4] dr=0.74 t=0.0ps kin=1.49 pot=19.78 Rg=7.795 SPS=2380
# 2nd loop
# ---
#
# bl=1935 pos[1]=[-2.5 -4.2 -5.7] dr=0.74 t=0.0ps kin=1.51 pot=19.78 Rg=7.793 SPS=2215
# 2nd loop
# ---
#
# bl=1936 pos[1]=[-2.5 -5.3 -5.6] dr=0.75 t=0.0ps kin=1.50 pot=19.76 Rg=7.823 SPS=2141
# 2nd loop
# ---
#
# bl=1937 pos[1]=[-2.7 -5.3 -5.2] dr=0.74 t=0.0ps kin=1.47 pot=19.76 Rg=7.852 SPS=2114
# 2nd loop
# ---
#
# bl=1938 pos[1]=[-2.9 -5.5 -5.2] dr=0.75 t=0.0ps kin=1.51 pot=19.78 Rg=7.848 SPS=2231
# 2nd loop
# ---
#
# bl=1939 pos[1]=[-2.9 -5.0 -5.4] dr=0.75 t=0.0ps kin=1.53 pot=19.82 Rg=7.843 SPS=1952
# 2nd loop
# ---
#
# bl=1940 pos[1]=[-2.5 -5.8 -5.1] dr=0.75 t=0.0ps kin=1.56 pot=19.79 Rg=7.846 SPS=2091
# 2nd loop
# ---
#
# bl=1941 pos[1]=[-3.0 -5.5 -4.2] dr=0.76 t=0.0ps kin=1.53 pot=19.81 Rg=7.831 SPS=2046
# 2nd loop
# ---
#
# bl=1942 pos[1]=[-3.6 -4.7 -5.1] dr=0.75 t=0.0ps kin=1.53 pot=19.80 Rg=7.812 SPS=2100
# 2nd loop
# ---
#
# bl=1943 pos[1]=[-2.5 -4.9 -4.7] dr=0.74 t=0.0ps kin=1.48 pot=19.79 Rg=7.800 SPS=2208
# 2nd loop
# ---
#
# bl=1944 pos[1]=[-3.0 -5.2 -4.2] dr=0.73 t=0.0ps kin=1.49 pot=19.77 Rg=7.805 SPS=1931
# 2nd loop
# ---
#
# bl=1945 pos[1]=[-2.7 -4.1 -4.6] dr=0.72 t=0.0ps kin=1.48 pot=19.79 Rg=7.819 SPS=2033
# 2nd loop
# ---
#
# bl=1946 pos[1]=[-3.1 -3.3 -4.2] dr=0.72 t=0.0ps kin=1.50 pot=19.76 Rg=7.815 SPS=1977
# 2nd loop
# ---
#
# bl=1947 pos[1]=[-2.5 -2.3 -3.9] dr=0.74 t=0.0ps kin=1.56 pot=19.75 Rg=7.825 SPS=2152
# 2nd loop
# ---
#
# bl=1948 pos[1]=[-2.4 -2.5 -4.2] dr=0.75 t=0.0ps kin=1.53 pot=19.73 Rg=7.838 SPS=1963
# 2nd loop
# ---
#
# bl=1949 pos[1]=[-2.3 -3.7 -5.0] dr=0.74 t=0.0ps kin=1.54 pot=19.76 Rg=7.849 SPS=1999
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.53881158 -1.33571592 -5.01501103]   Rg =  7.8493204
#      median bond size is  0.9635835159995252
#      three shortest/longest (<10)/ bonds are  [0.87400794 0.88023943 0.88241321]    [1.08430848 1.08459072 1.08873165]
#      95 percentile of distance to center is:    10.91874060439595
#      density of closest 95% monomers is:    0.4725056819533169
#      density of the core monomers is:    0.7197455733975157
#      min/median/mean/max coordinates are:
#      x: -14.59, -1.44, -1.54, 10.26
#      y: -12.03, -1.25, -1.34, 8.50
#      z: -14.68, -5.18, -5.02, 5.47
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5422468172023507 should be: 1.5
#      fastest particles are (in kT):  [ 8.19572405  8.33785378  9.91266997 10.98126414 12.14266403]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.756884909660766
# bl=1950 pos[1]=[-2.4 -3.4 -3.7] dr=0.74 t=0.0ps kin=1.48 pot=19.79 Rg=7.873 SPS=1908
# 2nd loop
# ---
#
# bl=1951 pos[1]=[-2.0 -3.8 -3.5] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.890 SPS=1989
# 2nd loop
# ---
#
# bl=1952 pos[1]=[-2.4 -4.0 -3.9] dr=0.74 t=0.0ps kin=1.51 pot=19.77 Rg=7.890 SPS=1908
# 2nd loop
# ---
#
# bl=1953 pos[1]=[-1.9 -4.2 -3.5] dr=0.74 t=0.0ps kin=1.48 pot=19.78 Rg=7.873 SPS=2105
# 2nd loop
# ---
#
# bl=1954 pos[1]=[-2.3 -4.0 -4.0] dr=0.74 t=0.0ps kin=1.49 pot=19.73 Rg=7.855 SPS=1940
# 2nd loop
# ---
#
# bl=1955 pos[1]=[-1.2 -3.8 -4.0] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.838 SPS=2005
# 2nd loop
# ---
#
# bl=1956 pos[1]=[-0.9 -4.0 -4.4] dr=0.74 t=0.0ps kin=1.48 pot=19.78 Rg=7.830 SPS=1948
# 2nd loop
# ---
#
# bl=1957 pos[1]=[-0.4 -4.2 -4.1] dr=0.74 t=0.0ps kin=1.53 pot=19.72 Rg=7.842 SPS=1937
# 2nd loop
# ---
#
# bl=1958 pos[1]=[-0.5 -4.3 -3.3] dr=0.74 t=0.0ps kin=1.50 pot=19.76 Rg=7.857 SPS=1874
# 2nd loop
# ---
#
# bl=1959 pos[1]=[0.1 -4.7 -3.2] dr=0.72 t=0.0ps kin=1.51 pot=19.75 Rg=7.847 SPS=1833
# 2nd loop
# ---
#
# bl=1960 pos[1]=[0.3 -4.3 -3.5] dr=0.73 t=0.0ps kin=1.50 pot=19.75 Rg=7.831 SPS=2631
# 2nd loop
# ---
#
# bl=1961 pos[1]=[0.5 -4.9 -4.0] dr=0.75 t=0.0ps kin=1.51 pot=19.75 Rg=7.829 SPS=2560
# 2nd loop
# ---
#
# bl=1962 pos[1]=[0.9 -4.9 -3.9] dr=0.74 t=0.0ps kin=1.47 pot=19.78 Rg=7.847 SPS=2358
# 2nd loop
# ---
#
# bl=1963 pos[1]=[0.8 -5.0 -3.3] dr=0.73 t=0.0ps kin=1.47 pot=19.78 Rg=7.840 SPS=2962
# 2nd loop
# ---
#
# bl=1964 pos[1]=[1.1 -4.3 -3.9] dr=0.73 t=0.0ps kin=1.46 pot=19.76 Rg=7.828 SPS=2881
# 2nd loop
# ---
#
# bl=1965 pos[1]=[1.0 -4.2 -3.4] dr=0.72 t=0.0ps kin=1.49 pot=19.76 Rg=7.825 SPS=2893
# 2nd loop
# ---
#
# bl=1966 pos[1]=[1.0 -4.6 -3.3] dr=0.72 t=0.0ps kin=1.48 pot=19.75 Rg=7.849 SPS=2854
# 2nd loop
# ---
#
# bl=1967 pos[1]=[1.1 -4.1 -3.2] dr=0.73 t=0.0ps kin=1.46 pot=19.79 Rg=7.876 SPS=3050
# 2nd loop
# ---
#
# bl=1968 pos[1]=[1.2 -4.6 -2.7] dr=0.74 t=0.0ps kin=1.49 pot=19.78 Rg=7.911 SPS=3026
# 2nd loop
# ---
#
# bl=1969 pos[1]=[0.7 -4.3 -2.7] dr=0.73 t=0.0ps kin=1.48 pot=19.76 Rg=7.903 SPS=2969
# 2nd loop
# ---
#
# bl=1970 pos[1]=[0.6 -4.5 -2.6] dr=0.76 t=0.0ps kin=1.51 pot=19.78 Rg=7.874 SPS=3070
# 2nd loop
# ---
#
# bl=1971 pos[1]=[0.7 -4.6 -3.3] dr=0.75 t=0.0ps kin=1.53 pot=19.78 Rg=7.843 SPS=3146
# 2nd loop
# ---
#
# bl=1972 pos[1]=[1.2 -4.3 -3.0] dr=0.75 t=0.0ps kin=1.55 pot=19.79 Rg=7.811 SPS=3096
# 2nd loop
# ---
#
# bl=1973 pos[1]=[1.0 -4.9 -2.6] dr=0.74 t=0.0ps kin=1.54 pot=19.81 Rg=7.807 SPS=3082
# 2nd loop
# ---
#
# bl=1974 pos[1]=[0.6 -4.4 -1.8] dr=0.74 t=0.0ps kin=1.55 pot=19.78 Rg=7.822 SPS=3132
# 2nd loop
# ---
#
# bl=1975 pos[1]=[0.5 -4.4 -1.5] dr=0.74 t=0.0ps kin=1.54 pot=19.77 Rg=7.833 SPS=3097
# 2nd loop
# ---
#
# bl=1976 pos[1]=[-0.2 -4.9 -2.0] dr=0.75 t=0.0ps kin=1.52 pot=19.81 Rg=7.859 SPS=3064
# 2nd loop
# ---
#
# bl=1977 pos[1]=[-0.3 -4.5 -1.8] dr=0.74 t=0.0ps kin=1.52 pot=19.80 Rg=7.866 SPS=3017
# 2nd loop
# ---
#
# bl=1978 pos[1]=[0.4 -4.6 -2.3] dr=0.74 t=0.0ps kin=1.55 pot=19.81 Rg=7.859 SPS=3004
# 2nd loop
# ---
#
# bl=1979 pos[1]=[-0.0 -4.6 -2.2] dr=0.75 t=0.0ps kin=1.52 pot=19.82 Rg=7.848 SPS=3101
# 2nd loop
# ---
#
# bl=1980 pos[1]=[0.4 -4.8 -1.7] dr=0.74 t=0.0ps kin=1.50 pot=19.82 Rg=7.844 SPS=3074
# 2nd loop
# ---
#
# bl=1981 pos[1]=[0.5 -4.9 -2.2] dr=0.75 t=0.0ps kin=1.51 pot=19.82 Rg=7.845 SPS=3166
# 2nd loop
# ---
#
# bl=1982 pos[1]=[0.8 -4.8 -2.2] dr=0.74 t=0.0ps kin=1.54 pot=19.79 Rg=7.843 SPS=3196
# 2nd loop
# ---
#
# bl=1983 pos[1]=[0.6 -4.6 -2.5] dr=0.73 t=0.0ps kin=1.51 pot=19.76 Rg=7.847 SPS=3106
# 2nd loop
# ---
#
# bl=1984 pos[1]=[0.5 -4.2 -2.6] dr=0.73 t=0.0ps kin=1.46 pot=19.75 Rg=7.861 SPS=2980
# 2nd loop
# ---
#
# bl=1985 pos[1]=[0.1 -3.6 -2.3] dr=0.74 t=0.0ps kin=1.46 pot=19.77 Rg=7.853 SPS=2998
# 2nd loop
# ---
#
# bl=1986 pos[1]=[-0.2 -4.1 -2.6] dr=0.73 t=0.0ps kin=1.49 pot=19.74 Rg=7.834 SPS=3092
# 2nd loop
# ---
#
# bl=1987 pos[1]=[0.1 -3.9 -2.7] dr=0.73 t=0.0ps kin=1.52 pot=19.74 Rg=7.835 SPS=2825
# 2nd loop
# ---
#
# bl=1988 pos[1]=[-0.7 -4.5 -2.6] dr=0.72 t=0.0ps kin=1.47 pot=19.76 Rg=7.838 SPS=3000
# 2nd loop
# ---
#
# bl=1989 pos[1]=[-0.3 -3.9 -3.1] dr=0.75 t=0.0ps kin=1.52 pot=19.69 Rg=7.833 SPS=2980
# 2nd loop
# ---
#
# bl=1990 pos[1]=[0.6 -3.7 -3.2] dr=0.72 t=0.0ps kin=1.51 pot=19.71 Rg=7.833 SPS=3006
# 2nd loop
# ---
#
# bl=1991 pos[1]=[0.2 -5.0 -2.7] dr=0.74 t=0.0ps kin=1.51 pot=19.71 Rg=7.850 SPS=2836
# 2nd loop
# ---
#
# bl=1992 pos[1]=[0.4 -5.0 -2.6] dr=0.74 t=0.0ps kin=1.45 pot=19.75 Rg=7.882 SPS=3060
# 2nd loop
# ---
#
# bl=1993 pos[1]=[0.6 -5.5 -2.4] dr=0.74 t=0.0ps kin=1.48 pot=19.76 Rg=7.923 SPS=2997
# 2nd loop
# ---
#
# bl=1994 pos[1]=[0.5 -5.6 -2.0] dr=0.73 t=0.0ps kin=1.48 pot=19.74 Rg=7.957 SPS=3014
# 2nd loop
# ---
#
# bl=1995 pos[1]=[0.0 -5.5 -2.0] dr=0.73 t=0.0ps kin=1.44 pot=19.75 Rg=7.981 SPS=3034
# 2nd loop
# ---
#
# bl=1996 pos[1]=[1.0 -5.4 -1.7] dr=0.72 t=0.0ps kin=1.45 pot=19.73 Rg=7.994 SPS=2907
# 2nd loop
# ---
#
# bl=1997 pos[1]=[0.4 -4.9 -2.0] dr=0.73 t=0.0ps kin=1.43 pot=19.77 Rg=7.971 SPS=2968
# 2nd loop
# ---
#
# bl=1998 pos[1]=[1.1 -4.7 -1.9] dr=0.73 t=0.0ps kin=1.48 pot=19.73 Rg=7.952 SPS=3034
# 2nd loop
# ---
#
# bl=1999 pos[1]=[0.7 -4.6 -1.6] dr=0.74 t=0.0ps kin=1.46 pot=19.76 Rg=7.932 SPS=3112
# 2nd loop
# ---
#
#
# Statistics for the simulation Chromosome, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.42320932 -1.27844713 -4.63886182]   Rg =  7.932322
#      median bond size is  0.9641862128422628
#      three shortest/longest (<10)/ bonds are  [0.87436197 0.87998131 0.88381277]    [1.09387473 1.10867139 1.13767832]
#      95 percentile of distance to center is:    11.0263412480086
#      density of closest 95% monomers is:    0.4588073788724728
#      density of the core monomers is:    0.7434023174139135
#      min/median/mean/max coordinates are:
#      x: -13.89, -1.39, -1.42, 11.01
#      y: -12.24, -1.15, -1.28, 8.34
#      z: -14.97, -4.65, -4.64, 5.35
#
# Statistics for velocities:
#      mean kinetic energy is:  1.460379144436483 should be: 1.5
#      fastest particles are (in kT):  [ 7.20146334  7.44429169  7.6433964   7.65729362 10.30878309]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'TypetoType', 'IdealChromosome', 'FlatBottomHarmonic']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.757871554664455
# bl=2000 pos[1]=[0.9 -4.3 -1.9] dr=0.73 t=0.0ps kin=1.48 pot=19.78 Rg=7.923 SPS=3024
# 2nd loop
# ---

# %%
sim.storage[0].close()
