# %%
import pydicom
import matplotlib.pyplot as plt

# %% [markdown]
# ***steps in lung nodule segmentation using optical flow***
# 1. preprocessing
# 2. frame selection (reference and current)
# 3. optical flow
# 4. post processing

# %%
p01f01 = "../../APP/archive/images/images/LIDC-IDRI-0001-000001.dcm"
p01f01 = pydicom.read_file(p01f01)
p01f01Arr = p01f01.pixel_array
plt.imshow(p01f01Arr)

# %%
path = "../../APP/archive/images/images/LIDC-IDRI-0001-000001.dcm"
ds = pydicom.dcmread(path)
ds.file_meta.MediaStorageSOPClassUID.name
# Out:
# 'Digital X-Ray Image Storage - For Presentation'

# %%
from pydicom import dcmread
from pydicom.data import get_testdata_file, get_testdata_files
from pydicom.fileset import FileSet

# %%
path01 = get_testdata_file("DICOMDIR")
ds01 = dcmread(path)
ds01.file_meta.MediaStorageSOPClassUID.name
# Out:
# 'Digital X-Ray Image Storage - For Presentation'

# %%
ds02 = get_testdata_files("CT_small.dcm")
