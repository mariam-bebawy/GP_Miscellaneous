# %%
import pydicom, pickle
import numpy as np

# %%
with open("../outputs/segCT.pickle", "rb") as f:
    arr = pickle.load(f)

# %%
arr.shape
# Out:
# (133, 512, 512)

# %%
itrCT = []
for i in range(arr.shape[0]):
    itrCT.append(arr[i])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
with open("../outputs/segCT.npy", "wb") as f:
    np.save("../outputs/segCT.npy", arr, f)

# %%
with open("../outputs/segCT.npy", "wb") as f:
    np.savetxt("../outputs/segCT.txt", arr[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 with open("../outputs/segCT.npy", "wb") as f:
# ----> 2     np.savetxt("../outputs/segCT.txt", arr[0], f)
#
# File <__array_function__ internals>:200, in savetxt(*args, **kwargs)
#
# File c:\MARS\program_setups\anaconda3\envs\GP\Lib\site-packages\numpy\lib\npyio.py:1592, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1590         format = fmt
#    1591 else:
# -> 1592     raise ValueError('invalid fmt: %r' % (fmt,))
#    1594 if len(header) > 0:
#    1595     header = header.replace('\n', '\n' + comments)
#
# ValueError: invalid fmt: <_io.BufferedWriter name='../outputs/segCT.npy'>

# %%
np.savetxt("../outputs/segCT.txt", arr[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from Applications.code import preprocessing
#
# ModuleNotFoundError: No module named 'Applications'
